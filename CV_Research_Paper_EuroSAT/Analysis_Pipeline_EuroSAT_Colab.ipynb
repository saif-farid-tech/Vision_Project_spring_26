# %% [markdown]
# # Analysis Pipeline — EuroSAT / SHViT vs Baselines
#
# Runs the full analysis after all 6 models are trained. Everything stays on
# Colab's local SSD (`/content/`) for fast iteration; final artifacts are
# mirrored into `<OUT_ROOT>/Stage 4: Benchmarking and Demo/analysis/` (and
# optionally to Drive) so the project root layout matches the rest of the
# experiment.
#
# Default `OUT_ROOT` is `/content/CV_Research_Paper_EuroSAT` (or
# `/content/drive/MyDrive/CV_Research_Paper_EuroSAT` when Drive is mounted).

# %% [markdown]
# ## 0. GPU check

# %%
import torch
print('PyTorch :', torch.__version__)
print('CUDA    :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU     :', torch.cuda.get_device_name(0))
# Out:
# PyTorch : 2.11.0+cu128
# CUDA    : True
# GPU     : NVIDIA A100-SXM4-40GB

# %% [markdown]
# ## 1. Mount Drive (read-only access to checkpoints + dataset source)

# %%
from google.colab import drive
drive.mount('/content/drive')

# Source paths on Drive (where Stage 2 + Stage 3 saved checkpoints and dataset)
DRIVE_OUT_ROOT      = '/content/drive/MyDrive/CV_Research_Paper_EuroSAT'
DRIVE_DATA          = '/content/drive/MyDrive/eurosat_data'

# Mirror the same layout locally under CV_Research_Paper_EuroSAT/.
OUT_ROOT            = '/content/CV_Research_Paper_EuroSAT'
ANALYSIS_ROOT       = f'{OUT_ROOT}/Stage 4: Benchmarking and Demo/analysis'

LOCAL_DATA          = '/content/eurosat_local'  # large(-ish), kept separate
LOCAL_CHECKPOINTS   = OUT_ROOT
LOCAL_RESULTS       = f'{ANALYSIS_ROOT}/results'
LOCAL_FIGURES       = f'{ANALYSIS_ROOT}/figures'
LOCAL_EDA           = f'{ANALYSIS_ROOT}/eda_outputs'
LOCAL_ERROR         = f'{ANALYSIS_ROOT}/error_analysis_outputs'
LOCAL_DEMO          = f'{ANALYSIS_ROOT}/demo_output'

import os
for p in [ANALYSIS_ROOT, LOCAL_RESULTS, LOCAL_FIGURES,
          LOCAL_EDA, LOCAL_ERROR, LOCAL_DEMO]:
    os.makedirs(p, exist_ok=True)

print('Output root        :', OUT_ROOT)
print('Local analysis root:', ANALYSIS_ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Output root        : /content/CV_Research_Paper_EuroSAT
# Local analysis root: /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis

# %% [markdown]
# ## 2. Copy dataset to local SSD
#
# If `/content/eurosat_local` already exists from an earlier session, this skips the copy.

# %%
import shutil, time

if not os.path.exists(LOCAL_DATA):
    if os.path.isdir(DRIVE_DATA):
        print('Copying EuroSAT from Drive to local SSD...')
        t0 = time.time()
        shutil.copytree(DRIVE_DATA, LOCAL_DATA)
        print(f'Done in {time.time()-t0:.0f}s')
    else:
        # No cached copy in Drive — let prepare_eurosat.py download it locally.
        os.makedirs(LOCAL_DATA, exist_ok=True)
else:
    img_root = os.path.join(LOCAL_DATA, 'eurosat', 'jpg')
    if os.path.isdir(img_root):
        classes = len(os.listdir(img_root))
        print(f'Already copied — {classes} class folders present')

# %% [markdown]
# ## 3. Copy trained checkpoints from Drive to the local output root
#
# Mirrors the `<OUT_ROOT>/Stage 2|3/<model>/best.pth` layout that
# `evaluate_all.py` and `make_figures.py` expect.

# %%
# Layout matches what evaluate_all.py expects:
#   <OUT_ROOT>/Stage 2: baseline models/<model>/best.pth
#   <OUT_ROOT>/Stage 3: fine-tuning SHViT/<model>/best.pth
STAGE2_LOCAL = f'{LOCAL_CHECKPOINTS}/Stage 2: baseline models'
STAGE3_LOCAL = f'{LOCAL_CHECKPOINTS}/Stage 3: fine-tuning SHViT'
os.makedirs(STAGE2_LOCAL, exist_ok=True)
os.makedirs(STAGE3_LOCAL, exist_ok=True)

DRIVE_STAGE2 = f'{DRIVE_OUT_ROOT}/Stage 2: baseline models'
DRIVE_STAGE3 = f'{DRIVE_OUT_ROOT}/Stage 3: fine-tuning SHViT'

for model in ['resnet50', 'mobilenet_v2']:
    src_dir = f'{DRIVE_STAGE2}/{model}'
    dst_dir = f'{STAGE2_LOCAL}/{model}'
    if os.path.isdir(src_dir) and not os.path.isdir(dst_dir):
        shutil.copytree(src_dir, dst_dir)
        print(f'copied {model}: {os.path.getsize(f"{dst_dir}/best.pth")/1e6:.1f} MB')
    elif os.path.isdir(dst_dir):
        print(f'{model}: already present')
    else:
        print(f'WARNING: {model} not found at {src_dir}')

for model in ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']:
    src_dir = f'{DRIVE_STAGE3}/{model}'
    dst_dir = f'{STAGE3_LOCAL}/{model}'
    if os.path.isdir(src_dir) and not os.path.isdir(dst_dir):
        shutil.copytree(src_dir, dst_dir)
        print(f'copied {model}: {os.path.getsize(f"{dst_dir}/best.pth")/1e6:.1f} MB')
    elif os.path.isdir(dst_dir):
        print(f'{model}: already present')
    else:
        print(f'WARNING: {model} not found at {src_dir}')
# Out:
# resnet50: already present
# mobilenet_v2: already present
# copied shvit_s1: 24.4 MB
# copied shvit_s2: 44.5 MB
# copied shvit_s3: 55.6 MB
# copied shvit_s4: 65.1 MB

# %% [markdown]
# ## 4. Clone repos and install dependencies
#
# Pulls the latest analysis scripts from your branch. If the repo already exists, `git pull` updates it.

# %%
REPO_DIR  = '/content/Vision_Project_spring_26'
REPO_URL  = 'https://github.com/saif-farid-tech/Vision_Project_spring_26.git'
BRANCH    = 'Vision_Project_spring_26_EuroSAT'
SHVIT_DIR = '/content/SHViT'

import os, shutil

if os.path.isdir(REPO_DIR):
    shutil.rmtree(REPO_DIR)

# !git clone -b {BRANCH} {REPO_URL} {REPO_DIR}

if not os.path.isdir(SHVIT_DIR):
    # !git clone https://github.com/ysj9909/SHViT.git {SHVIT_DIR}

# Copy analysis scripts to /content for clean invocation
for fname in ['eda.py', 'evaluate_all.py', 'make_figures.py',
              'error_analysis.py', 'demo.py',
              'augmentation.py', 'metrics.py', 'splits.py',
              'prepare_eurosat.py']:
    s = f'{REPO_DIR}/{fname}'
    if os.path.exists(s):
        shutil.copy(s, f'/content/{fname}')
        print(f'copied {fname}')
    else:
        print(f'MISSING: {fname} (push it to your branch first)')

DATASETS_DST = '/content/datasets'
if os.path.isdir(DATASETS_DST):
    shutil.rmtree(DATASETS_DST)
shutil.copytree(f'{REPO_DIR}/datasets', DATASETS_DST)
print('Vendored datasets/ package.')
# Out:
# Cloning into '/content/Vision_Project_spring_26'...
# remote: Enumerating objects: 1061, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 1061 (delta 117), reused 99 (delta 92), pack-reused 902 (from 2)
# Receiving objects: 100% (1061/1061), 516.58 MiB | 16.96 MiB/s, done.
# Resolving deltas: 100% (549/549), done.
# copied eda.py
# copied evaluate_all.py
# copied make_figures.py
# copied error_analysis.py
# copied demo.py
# copied augmentation.py
# copied metrics.py
# copied splits.py
# copied prepare_eurosat.py
# Vendored datasets/ package.

# %%
# Dependencies: timm pinned, fvcore for GFLOPs, seaborn for heatmaps, gdown for split
# !pip install -q timm==0.5.4 --no-deps
# !pip install -q einops==0.4.1 easydict fvcore seaborn gdown
print('Deps installed.')
# Out:
# Deps installed.

# %% [markdown]
# ## 5. EDA — sample grid, class distribution, image sizes
#
# Quick (~2 min). No GPU needed.

# %%
# !python /content/eda.py \
    --data-root  {LOCAL_DATA} \
    --output-dir "{LOCAL_EDA}"

print('\nEDA outputs:')
for f in sorted(os.listdir(LOCAL_EDA)):
    sz = os.path.getsize(f'{LOCAL_EDA}/{f}') / 1024
    print(f'  {f}  ({sz:.0f} KB)')
# Out:
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Train: 13,500  Test: 8,100  Classes: 10
# Wrote eda_samples.png
# Wrote eda_image_sizes.png
# Wrote eda_class_distribution.png
# Wrote eda_summary.txt
#
# EDA outputs:
#   eda_class_distribution.png  (132 KB)
#   eda_image_sizes.png  (78 KB)
#   eda_samples.png  (526 KB)
#   eda_summary.txt  (1 KB)

# %% [markdown]
# ## 6. Full evaluation + benchmarks on the test set
#
# Runs all 6 models on the EuroSAT test split from the Tip-Adapter
# `split_zhou_EuroSAT.json`, plus parameter / FLOPs / throughput / latency
# benchmarks.

# %%
# !python /content/evaluate_all.py \
    --checkpoints-dir "{LOCAL_CHECKPOINTS}" \
    --shvit-dir       {SHVIT_DIR} \
    --data-root       {LOCAL_DATA} \
    --output-dir      "{LOCAL_RESULTS}"

print('\nResults outputs:')
for root, dirs, files in os.walk(LOCAL_RESULTS):
    for f in files:
        full = os.path.join(root, f)
        rel  = os.path.relpath(full, LOCAL_RESULTS)
        sz   = os.path.getsize(full) / 1024
        print(f'  {rel}  ({sz:.0f} KB)')
# Out:
# Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Test set: 8,100 images   classes: 10
#
# === resnet50 ===
# Evaluating on 8100 images...
#   Batch 0/127
#   Batch 50/127
#   Batch 100/127
# Top-1: 98.83%  |  Top-5: 99.94%
#   GPU throughput @bs64: 2905 img/s
#   CPU latency @bs1   : 39.28 ms
#   -> /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/resnet50/results.json
#
# === mobilenet_v2 ===
# Evaluating on 8100 images...
#   Batch 0/127
#   Batch 50/127
#   Batch 100/127
# Top-1: 98.0%  |  Top-5: 100.0%
#   GPU throughput @bs64: 6559 img/s
#   CPU latency @bs1   : 16.94 ms
#   -> /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/mobilenet_v2/results.json
#
# === shvit_s1 ===
# Evaluating on 8100 images...
#   Batch 0/127
#   Batch 50/127
#   Batch 100/127
# Top-1: 97.51%  |  Top-5: 99.98%
#   GPU throughput @bs64: 4844 img/s
#   CPU latency @bs1   : 19.51 ms
#   -> /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/shvit_s1/results.json
#
# === shvit_s2 ===
# Evaluating on 8100 images...
#   Batch 0/127
#   Batch 50/127
#   Batch 100/127
# Top-1: 98.0%  |  Top-5: 99.99%
#   GPU throughput @bs64: 4644 img/s
#   CPU latency @bs1   : 20.78 ms
#   -> /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/shvit_s2/results.json
#
# === shvit_s3 ===
# Evaluating on 8100 images...
#   Batch 0/127
#   Batch 50/127
#   Batch 100/127
# Top-1: 98.14%  |  Top-5: 99.99%
#   GPU throughput @bs64: 4316 img/s
#   CPU latency @bs1   : 25.03 ms
#   -> /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/shvit_s3/results.json
#
# === shvit_s4 ===
# Evaluating on 8100 images...
#   Batch 0/127
#   Batch 50/127
#   Batch 100/127
# Top-1: 98.06%  |  Top-5: 99.99%
#   GPU throughput @bs64: 3431 img/s
#   CPU latency @bs1   : 30.99 ms
#   -> /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/shvit_s4/results.json
#
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/results_table.md
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/results/results_table.tex
#
# Results outputs:
#   results_table.md  (0 KB)
#   results_table.tex  (0 KB)
#   shvit_s1/results.json  (112 KB)
#   mobilenet_v2/results.json  (112 KB)
#   shvit_s4/results.json  (112 KB)
#   shvit_s3/results.json  (112 KB)
#   resnet50/results.json  (112 KB)
#   shvit_s2/results.json  (112 KB)

# %%
# Quick peek at the headline table
table_path = f'{LOCAL_RESULTS}/results_table.md'
if os.path.exists(table_path):
    with open(table_path) as f:
        print(f.read())
# Out:
# | Model | Params (M) | GFLOPs | Top-1 (%) | Top-5 (%) | GPU (img/s) | CPU (ms) |
# |---|---|---|---|---|---|---|
# | shvit_s1 | 6.01 | 0.24 | 97.51 | 99.98 | 4844 | 19.51 |
# | mobilenet_v2 | 2.24 | 0.31 | 98.00 | 100.00 | 6559 | 16.94 |
# | shvit_s2 | 11.04 | 0.37 | 98.00 | 99.99 | 4644 | 20.78 |
# | shvit_s3 | 13.80 | 0.60 | 98.14 | 99.99 | 4316 | 25.03 |
# | shvit_s4 | 16.14 | 0.79 | 98.06 | 99.99 | 3431 | 30.99 |
# | resnet50 | 23.53 | 4.11 | 98.83 | 99.94 | 2905 | 39.28 |

# %% [markdown]
# ## 7. Generate report figures
#
# Reads training logs (from the checkpoint dirs) + `results.json` files. Produces the speed-vs-accuracy headline figure, training curves, train loss, accuracy bars.

# %%
# !python /content/make_figures.py \
    --results-dir "{LOCAL_RESULTS}" \
    --logs-dir    "{LOCAL_CHECKPOINTS}" \
    --output-dir  "{LOCAL_FIGURES}"

print('\nFigures:')
for f in sorted(os.listdir(LOCAL_FIGURES)):
    sz = os.path.getsize(f'{LOCAL_FIGURES}/{f}') / 1024
    print(f'  {f}  ({sz:.0f} KB)')
# Out:
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/figures/fig_training_curves.png
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/figures/fig_train_loss.png
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/figures/fig_speed_vs_accuracy.png
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/figures/fig_accuracy_bars.png
#
# Figures:
#   fig_accuracy_bars.png  (105 KB)
#   fig_speed_vs_accuracy.png  (151 KB)
#   fig_train_loss.png  (269 KB)
#   fig_training_curves.png  (213 KB)

# %%
# Inline preview
from IPython.display import Image, display
for f in ['fig_speed_vs_accuracy.png', 'fig_training_curves.png',
          'fig_accuracy_bars.png', 'fig_train_loss.png']:
    p = f'{LOCAL_FIGURES}/{f}'
    if os.path.exists(p):
        print(f)
        display(Image(p, width=700))
# Out:
# fig_speed_vs_accuracy.png
# fig_training_curves.png
# fig_accuracy_bars.png
# fig_train_loss.png

# %% [markdown]
# ## 8. Error analysis on SHViT-S4
#
# Worst-15 categories, top-10 confused class pairs, confusion heatmap, misclassified image grid.

# %%
S4_CKPT = f'{STAGE3_LOCAL}/shvit_s4/best.pth'

# !python /content/error_analysis.py \
    --results-dir "{LOCAL_RESULTS}" \
    --data-root   {LOCAL_DATA} \
    --shvit-dir   {SHVIT_DIR} \
    --checkpoint  "{S4_CKPT}" \
    --output-dir  "{LOCAL_ERROR}"

print('\nError analysis outputs:')
for f in sorted(os.listdir(LOCAL_ERROR)):
    sz = os.path.getsize(f'{LOCAL_ERROR}/{f}') / 1024
    print(f'  {f}  ({sz:.0f} KB)')
# Out:
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
#
# Worst-10 classes:
#   Permanent Crop Land           94.67%
#   Pasture Land                  96.00%
#   Annual Crop Land              97.78%
#   Highway or Road               97.87%
#   Herbaceous Vegetation Land    98.33%
#   River                         98.67%
#   Sea or Lake                   98.89%
#   Industrial Buildings          98.93%
#   Forest                        99.00%
#   Residential Buildings         99.44%
#
# Best-10 classes:
#   Residential Buildings         99.44%
#   Forest                        99.00%
#   Industrial Buildings          98.93%
#   Sea or Lake                   98.89%
#   River                         98.67%
#   Herbaceous Vegetation Land    98.33%
#   Highway or Road               97.87%
#   Annual Crop Land              97.78%
#   Pasture Land                  96.00%
#   Permanent Crop Land           94.67%
#
# Top-10 most confused class pairs (true -> predicted):
#   Permanent Crop Land          -> Herbaceous Vegetation Land     2.80%  (n=21)
#   Permanent Crop Land          -> Annual Crop Land               2.13%  (n=16)
#   Pasture Land                 -> Herbaceous Vegetation Land     1.67%  (n=10)
#   Annual Crop Land             -> Permanent Crop Land            1.44%  (n=13)
#   Pasture Land                 -> Annual Crop Land               1.33%  (n=8)
#   Highway or Road              -> River                          1.07%  (n=8)
#   River                        -> Highway or Road                0.67%  (n=5)
#   Industrial Buildings         -> Residential Buildings          0.67%  (n=5)
#   Forest                       -> Herbaceous Vegetation Land     0.56%  (n=5)
#   Annual Crop Land             -> Pasture Land                   0.56%  (n=5)
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/error_analysis_outputs/confusion_top20.png
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/error_analysis_outputs/worst_15_categories.png
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/error_analysis_outputs/misclassified_grid.png
# Wrote /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/error_analysis_outputs/error_analysis_summary.txt
#
# Error analysis outputs:
#   confusion_top20.png  (363 KB)
#   error_analysis_summary.txt  (2 KB)
#   misclassified_grid.png  (527 KB)
#   worst_15_categories.png  (181 KB)

# %%
# Inline preview of error figures + summary text
for f in ['confusion_top20.png', 'misclassified_grid.png', 'worst_15_categories.png']:
    p = f'{LOCAL_ERROR}/{f}'
    if os.path.exists(p):
        print(f)
        display(Image(p, width=700))

summary = f'{LOCAL_ERROR}/error_analysis_summary.txt'
if os.path.exists(summary):
    with open(summary) as f:
        print(f.read())
# Out:
# confusion_top20.png
# misclassified_grid.png
# worst_15_categories.png
# SHViT-S4 Error Analysis Summary (EuroSAT)
# ================================================
#
# Overall:
#   - Test set size       : 8,100 images
#   - Test top-1 accuracy : 98.06%
#   - Test top-5 accuracy : 99.99%
#
# Worst-10 classes by per-class accuracy:
#    1. Permanent Crop Land           94.67%
#    2. Pasture Land                  96.00%
#    3. Annual Crop Land              97.78%
#    4. Highway or Road               97.87%
#    5. Herbaceous Vegetation Land    98.33%
#    6. River                         98.67%
#    7. Sea or Lake                   98.89%
#    8. Industrial Buildings          98.93%
#    9. Forest                        99.00%
#   10. Residential Buildings         99.44%
#
# Best-10 classes (for context):
#    1. Residential Buildings         99.44%
#    2. Forest                        99.00%
#    3. Industrial Buildings          98.93%
#    4. Sea or Lake                   98.89%
#    5. River                         98.67%
#    6. Herbaceous Vegetation Land    98.33%
#    7. Highway or Road               97.87%
#    8. Annual Crop Land              97.78%
#    9. Pasture Land                  96.00%
#   10. Permanent Crop Land           94.67%
#
# Top-10 most confused class pairs (true -> predicted):
#    1. Permanent Crop Land          -> Herbaceous Vegetation Land     2.80%  (n=21)
#    2. Permanent Crop Land          -> Annual Crop Land               2.13%  (n=16)
#    3. Pasture Land                 -> Herbaceous Vegetation Land     1.67%  (n=10)
#    4. Annual Crop Land             -> Permanent Crop Land            1.44%  (n=13)
#    5. Pasture Land                 -> Annual Crop Land               1.33%  (n=8)
#    6. Highway or Road              -> River                          1.07%  (n=8)
#    7. River                        -> Highway or Road                0.67%  (n=5)
#    8. Industrial Buildings         -> Residential Buildings          0.67%  (n=5)
#    9. Forest                       -> Herbaceous Vegetation Land     0.56%  (n=5)
#   10. Annual Crop Land             -> Pasture Land                   0.56%  (n=5)

# %% [markdown]
# ## 9. Demo on a single image
#
# Smoke test for `demo.py`. By default this grabs the first scene image
# found under `eurosat/2750/`; edit `DEMO_IMAGE` to try any other scene.

# %%
import glob
# EuroSAT images are organized in class subfolders.
candidates = sorted(glob.glob(f'{LOCAL_DATA}/eurosat/2750/*/*.jpg'))
DEMO_IMAGE = candidates[0]
print('Using image:', DEMO_IMAGE)

DEMO_OUT = f'{LOCAL_DEMO}/demo_output.png'

# !python /content/demo.py \
    --image       "{DEMO_IMAGE}" \
    --checkpoint  "{S4_CKPT}" \
    --shvit-dir   {SHVIT_DIR} \
    --data-root   {LOCAL_DATA} \
    --output      "{DEMO_OUT}"

if os.path.exists(DEMO_OUT):
    display(Image(DEMO_OUT, width=600))
# Out:
# Using image: /content/eurosat_local/eurosat/2750/AnnualCrop/AnnualCrop_1.jpg
# Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
#
# Top-5 predictions for AnnualCrop_1.jpg:
#   1. Annual Crop Land              76.91%
#   2. Sea or Lake                    5.49%
#   3. Permanent Crop Land            4.04%
#   4. Forest                         3.15%
#   5. Herbaceous Vegetation Land     2.68%
#
# Saved /content/CV_Research_Paper_EuroSAT/Stage 4: Benchmarking and Demo/analysis/demo_output/demo_output.png

# %% [markdown]
# ## 10. Bundle everything for download
#
# Zips the entire `<OUT_ROOT>/Stage 4: Benchmarking and Demo/analysis/`
# folder so you can download it from the Colab file browser
# (right-click `analysis.zip` → Download).

# %%
ZIP_PATH = '/content/CV_Research_Paper_EuroSAT_analysis.zip'
if os.path.exists(ZIP_PATH):
    os.remove(ZIP_PATH)

# Zip the analysis subtree (results, figures, EDA, error analysis, demo)
# !cd "{ANALYSIS_ROOT}" && zip -rq {ZIP_PATH} \
    results figures eda_outputs error_analysis_outputs demo_output

size_mb = os.path.getsize(ZIP_PATH) / 1e6
print(f'Bundle ready: {ZIP_PATH}  ({size_mb:.1f} MB)')
print('Right-click in the file browser to download.')
# Out:
# Bundle ready: /content/CV_Research_Paper_EuroSAT_analysis.zip  (2.1 MB)
# Right-click in the file browser to download.

# %%
# Optional: also copy the bundle to Drive for safety
DRIVE_BUNDLE = '/content/drive/MyDrive/CV_Research_Paper_EuroSAT_analysis.zip'
shutil.copy(ZIP_PATH, DRIVE_BUNDLE)
print(f'Also saved to: {DRIVE_BUNDLE}')
# Out:
# Also saved to: /content/drive/MyDrive/CV_Research_Paper_EuroSAT_analysis.zip

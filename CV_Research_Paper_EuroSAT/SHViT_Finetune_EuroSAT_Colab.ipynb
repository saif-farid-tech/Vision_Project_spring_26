# %% [markdown]
# # Stage 3 — Fine-tuning SHViT on EuroSAT
#
# This notebook fine-tunes pretrained SHViT models (S1..S4) on EuroSAT
# using `finetune_shvit_eurosat.py`. Data preprocessing follows
# Tip-Adapter (`splits.py`, CLIP normalization, bicubic resize).
#
# **Before running:** `Runtime → Change runtime type → T4 GPU`
#
# ### What this notebook does
# 1. Verifies GPU, mounts Drive (optional), prepares paths
# 2. Clones SHViT + this project repo, installs deps
# 3. Downloads SHViT pretrained weights (S1..S4)
# 4. Runs `finetune_shvit_eurosat.py` for each variant
# 5. Plots training curves
#
# All outputs land under `<OUT_ROOT>/Stage 3: fine-tuning SHViT/<variant>/`.

# %% [markdown]
# ## 0. GPU check

# %%
import torch
print('PyTorch :', torch.__version__)
print('CUDA    :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU     :', torch.cuda.get_device_name(0))
# Out:
# PyTorch : 2.11.0+cu128
# CUDA    : True
# GPU     : NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## 1. (Optional) Mount Drive
#
# Persist the dataset, weights, and checkpoints across sessions.

# %%
USE_DRIVE = True

OUT_ROOT = '/content/CV_Research_Paper_EuroSAT'

if USE_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_ROOT   = '/content/drive/MyDrive/eurosat_data'
    WEIGHTS_DIR = '/content/drive/MyDrive/shvit_weights'
    OUT_ROOT    = '/content/drive/MyDrive/CV_Research_Paper_EuroSAT'
else:
    DATA_ROOT   = '/content/eurosat_data'
    WEIGHTS_DIR = '/content/weights'

OUTPUT_DIR = f'{OUT_ROOT}/Stage 3: fine-tuning SHViT'
WEIGHTS_PATH = f'{WEIGHTS_DIR}/shvit_s4.pth'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)
os.makedirs(WEIGHTS_DIR, exist_ok=True)

print('Data       :', DATA_ROOT)
print('Weights    :', WEIGHTS_PATH)
print('Output root:', OUT_ROOT)
print('Output dir :', OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Data       : /content/drive/MyDrive/eurosat_data
# Weights    : /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# Output root: /content/drive/MyDrive/CV_Research_Paper_EuroSAT
# Output dir : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT

# %%
# Optional: copy the dataset to local SSD for faster I/O.
import shutil, os, time
src = '/content/drive/MyDrive/eurosat_data'
dst = '/content/eurosat_local'

if USE_DRIVE and not os.path.exists(dst) and os.path.isdir(src):
    print('Copying dataset to local SSD...')
    t0 = time.time()
    shutil.copytree(src, dst)
    print(f'done in {time.time()-t0:.0f}s')
    DATA_ROOT = dst
elif os.path.exists(dst):
    DATA_ROOT = dst
print('DATA_ROOT now:', DATA_ROOT)
# Out:
# Copying dataset to local SSD...
# done in 0s
# DATA_ROOT now: /content/eurosat_local

# %% [markdown]
# ## 2. Clone repos and install dependencies

# %%
import os, shutil

if not os.path.isdir('/content/SHViT'):
    # !git clone https://github.com/ysj9909/SHViT.git /content/SHViT

REPO = '/content/Vision_Project_spring_26'
if not os.path.isdir(REPO):
    # !git clone -b Vision_Project_spring_26_EuroSAT \
        https://github.com/saif-farid-tech/Vision_Project_spring_26.git {REPO}

for fname in [
    'Stage 3: fine-tuning SHViT/finetune_shvit_eurosat.py',
    'splits.py',
    'metrics.py',
    'augmentation.py',
    'prepare_eurosat.py',
]:
    shutil.copy(f'{REPO}/{fname}', f'/content/{os.path.basename(fname)}')
    print('Copied:', os.path.basename(fname))

DATASETS_DST = '/content/datasets'
if os.path.isdir(DATASETS_DST):
    shutil.rmtree(DATASETS_DST)
shutil.copytree(f'{REPO}/datasets', DATASETS_DST)
print('Vendored datasets/ package.')
# Out:
# Cloning into '/content/SHViT'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 183 (delta 84), reused 82 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 168.52 KiB | 11.23 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Cloning into '/content/Vision_Project_spring_26'...
# remote: Enumerating objects: 1034, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 1034 (delta 103), reused 98 (delta 92), pack-reused 902 (from 2)
# Receiving objects: 100% (1034/1034), 512.57 MiB | 19.33 MiB/s, done.
# Resolving deltas: 100% (535/535), done.
# Copied: finetune_shvit_eurosat.py
# Copied: splits.py
# Copied: metrics.py
# Copied: augmentation.py
# Copied: prepare_eurosat.py
# Vendored datasets/ package.

# %%
# Install SHViT deps (timm pinned, --no-deps so torch isn't downgraded).
# gdown is used by prepare_eurosat.py to fetch the CoOp split.
# !pip install -q timm==0.5.4 --no-deps
# !pip install -q einops==0.4.1 easydict gdown
print('Dependencies installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 22.1 MB/s eta 0:00:00
# Dependencies installed.

# %% [markdown]
# ## 3. Download SHViT-S4 pretrained weights

# %%
os.makedirs(WEIGHTS_DIR, exist_ok=True)
if not os.path.exists(WEIGHTS_PATH):
    # !wget -q --show-progress \
        https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s4.pth \
        -O {WEIGHTS_PATH}
size_mb = os.path.getsize(WEIGHTS_PATH) / 1e6
print(f'Checkpoint: {size_mb:.1f} MB  ->  {WEIGHTS_PATH}')

# Also pre-download the EuroSAT split + images so the first training run is fast
# !python /content/prepare_eurosat.py --root {DATA_ROOT}
# Out:
# Checkpoint: 266.7 MB  ->  /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# [eurosat] downloading EuroSAT via torchvision into /content/eurosat_local ...
# 100% 94.3M/94.3M [00:00<00:00, 217MB/s]
# [eurosat] trying official split download via gdown: https://drive.google.com/uc?id=1Ip7yaCWFi0eaOFUGga0lUdVi_DDQth1o
# Downloading...
# From: https://drive.google.com/uc?id=1Ip7yaCWFi0eaOFUGga0lUdVi_DDQth1o
# To: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# 100% 3.01M/3.01M [00:00<00:00, 90.4MB/s]
# [eurosat] official split saved to /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
#
# Done. Dataset root: /content/eurosat_local/eurosat
#   classes : 10
#   train   : 13,500
#   val     : 5,400
#   test    : 8,100

# %% [markdown]
# ## 4. Fine-tune SHViT on EuroSAT
#
# EuroSAT-RGB is moderate (~2 GB unpacked, 27,000 images across 10
# land-cover classes). Each epoch on a T4 takes ~1 minute with batch 64 —
# 30 epochs ≈ 30 min per SHViT variant.

# %%
# Quick smoke-test: 2 epochs to verify everything runs
# !python /content/finetune_shvit_eurosat.py \
    --shvit-dir  /content/SHViT \
    --finetune   {WEIGHTS_PATH} \
    --data-root  {DATA_ROOT} \
    --output-dir "{OUTPUT_DIR}/shvit_s4_smoke" \
    --epochs 2 \
    --batch-size 64 \
    --lr 1e-4 \
    --num-workers 8
# Out:
# Model: shvit_s4   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,143,974
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 2 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/2] lr=2.00e-05  train=2.2515  val=2.0636  top1=41.41%  top5=85.83%  (73s)
#   -> new best (41.41%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
# [  2/2] lr=4.00e-05  train=2.0737  val=1.5494  top1=56.93%  top5=97.78%  (24s)
#   -> new best (56.93%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
#
# Done.  Best val top-1: 56.93%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4_smoke/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth

# %%
# Train all 4 SHViT variants sequentially.
MODELS = ['shvit_s4', 'shvit_s3', 'shvit_s2', 'shvit_s1']

# Per-variant weight decay from the SHViT paper (Table 7).
WEIGHT_DECAY = {
    'shvit_s1': 0.025,
    'shvit_s2': 0.032,
    'shvit_s3': 0.035,
    'shvit_s4': 0.050,
}

for model_name in MODELS:
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'

    if not os.path.exists(weights_path):
        print(f'\n=== Downloading {model_name} pretrained weights ===')
        # !wget -q --show-progress \
            https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth \
            -O {weights_path}

    print(f'\n{"="*60}')
    print(f'Training {model_name}  (wd={WEIGHT_DECAY[model_name]})')
    print(f'{"="*60}')

    # !python /content/finetune_shvit_eurosat.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir "{model_output_dir}" \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8

    print(f'\n=== Finished {model_name} ===\n')

print('All 4 SHViT variants done.')
# Out:
# ============================================================
# Training shvit_s4  (wd=0.05)
# ============================================================
# Model: shvit_s4   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,143,974
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.2578  val=2.0977  top1=41.24%  top5=84.31%  (77s)
#   -> new best (41.24%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  2/30] lr=4.00e-05  train=2.0938  val=1.5968  top1=56.81%  top5=97.70%  (21s)
#   -> new best (56.81%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  3/30] lr=6.00e-05  train=1.8142  val=0.9137  top1=83.57%  top5=99.72%  (23s)
#   -> new best (83.57%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  4/30] lr=8.00e-05  train=1.5366  val=0.5363  top1=91.65%  top5=99.93%  (24s)
#   -> new best (91.65%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  5/30] lr=1.00e-04  train=1.4432  val=0.4940  top1=93.19%  top5=99.96%  (23s)
#   -> new best (93.19%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  6/30] lr=1.00e-04  train=1.3942  val=0.4430  top1=94.33%  top5=99.96%  (23s)
#   -> new best (94.33%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  7/30] lr=9.96e-05  train=1.3724  val=0.4649  top1=94.50%  top5=100.00%  (21s)
#   -> new best (94.50%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  8/30] lr=9.84e-05  train=1.2800  val=0.3816  top1=95.67%  top5=99.96%  (21s)
#   -> new best (95.67%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  9/30] lr=9.65e-05  train=1.2974  val=0.3969  top1=95.67%  top5=99.96%  (23s)
# [ 10/30] lr=9.39e-05  train=1.2514  val=0.3625  top1=96.72%  top5=99.96%  (23s)
#   -> new best (96.72%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 11/30] lr=9.05e-05  train=1.2564  val=0.3298  top1=96.85%  top5=99.96%  (24s)
#   -> new best (96.85%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 12/30] lr=8.66e-05  train=1.2656  val=0.3693  top1=96.56%  top5=99.98%  (22s)
# [ 13/30] lr=8.21e-05  train=1.2886  val=0.4211  top1=96.26%  top5=99.96%  (20s)
# [ 14/30] lr=7.70e-05  train=1.2033  val=0.3903  top1=97.24%  top5=99.96%  (22s)
#   -> new best (97.24%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 15/30] lr=7.16e-05  train=1.2019  val=0.3393  top1=96.93%  top5=99.94%  (24s)
# [ 16/30] lr=6.58e-05  train=1.2331  val=0.3395  top1=97.43%  top5=99.94%  (24s)
#   -> new best (97.43%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 17/30] lr=5.98e-05  train=1.2075  val=0.3586  top1=97.65%  top5=99.98%  (23s)
#   -> new best (97.65%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 18/30] lr=5.36e-05  train=1.2332  val=0.3280  top1=97.69%  top5=99.96%  (21s)
#   -> new best (97.69%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 19/30] lr=4.74e-05  train=1.1933  val=0.3463  top1=97.41%  top5=99.96%  (21s)
# [ 20/30] lr=4.12e-05  train=1.1866  val=0.3244  top1=97.78%  top5=99.98%  (24s)
#   -> new best (97.78%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 21/30] lr=3.52e-05  train=1.1789  val=0.3420  top1=97.87%  top5=99.98%  (24s)
#   -> new best (97.87%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 22/30] lr=2.94e-05  train=1.2000  val=0.3616  top1=97.57%  top5=99.98%  (23s)
# [ 23/30] lr=2.40e-05  train=1.2134  val=0.3018  top1=97.87%  top5=99.98%  (23s)
# [ 24/30] lr=1.89e-05  train=1.1853  val=0.3106  top1=98.06%  top5=99.98%  (20s)
#   -> new best (98.06%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 25/30] lr=1.44e-05  train=1.1957  val=0.3421  top1=97.91%  top5=99.96%  (21s)
# [ 26/30] lr=1.05e-05  train=1.1890  val=0.3303  top1=97.94%  top5=99.96%  (24s)
# [ 27/30] lr=7.12e-06  train=1.1797  val=0.2961  top1=98.11%  top5=99.98%  (23s)
#   -> new best (98.11%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 28/30] lr=4.48e-06  train=1.2009  val=0.3871  top1=97.93%  top5=99.96%  (23s)
# [ 29/30] lr=2.56e-06  train=1.1960  val=0.3552  top1=97.89%  top5=99.96%  (22s)
# [ 30/30] lr=1.39e-06  train=1.1969  val=0.3693  top1=98.02%  top5=99.96%  (21s)
#
# Done.  Best val top-1: 98.11%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#
# === Finished shvit_s4 ===
#
#
# ============================================================
# Training shvit_s3  (wd=0.035)
# ============================================================
# Model: shvit_s3   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s3.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 13,800,763
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.2386  val=1.9418  top1=51.39%  top5=91.09%  (73s)
#   -> new best (51.39%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  2/30] lr=4.00e-05  train=1.9660  val=1.2367  top1=71.74%  top5=98.94%  (19s)
#   -> new best (71.74%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  3/30] lr=6.00e-05  train=1.7047  val=0.7706  top1=85.02%  top5=99.70%  (19s)
#   -> new best (85.02%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  4/30] lr=8.00e-05  train=1.5111  val=0.5197  top1=92.24%  top5=99.93%  (20s)
#   -> new best (92.24%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  5/30] lr=1.00e-04  train=1.4219  val=0.4940  top1=93.76%  top5=99.89%  (22s)
#   -> new best (93.76%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  6/30] lr=1.00e-04  train=1.3820  val=0.4206  top1=95.41%  top5=99.98%  (21s)
#   -> new best (95.41%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  7/30] lr=9.96e-05  train=1.3770  val=0.4366  top1=95.83%  top5=100.00%  (21s)
#   -> new best (95.83%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  8/30] lr=9.84e-05  train=1.2840  val=0.4286  top1=94.61%  top5=99.98%  (21s)
# [  9/30] lr=9.65e-05  train=1.2917  val=0.3710  top1=96.31%  top5=100.00%  (18s)
#   -> new best (96.31%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 10/30] lr=9.39e-05  train=1.2548  val=0.3605  top1=96.98%  top5=99.98%  (19s)
#   -> new best (96.98%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 11/30] lr=9.05e-05  train=1.2530  val=0.3638  top1=96.67%  top5=100.00%  (21s)
# [ 12/30] lr=8.66e-05  train=1.2636  val=0.3878  top1=96.41%  top5=99.98%  (21s)
# [ 13/30] lr=8.21e-05  train=1.2768  val=0.4103  top1=97.35%  top5=99.98%  (20s)
#   -> new best (97.35%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 14/30] lr=7.70e-05  train=1.1981  val=0.3736  top1=97.43%  top5=99.98%  (21s)
#   -> new best (97.43%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 15/30] lr=7.16e-05  train=1.1995  val=0.3517  top1=96.80%  top5=99.98%  (19s)
# [ 16/30] lr=6.58e-05  train=1.2372  val=0.3691  top1=97.00%  top5=99.98%  (19s)
# [ 17/30] lr=5.98e-05  train=1.2094  val=0.3450  top1=97.57%  top5=100.00%  (20s)
#   -> new best (97.57%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 18/30] lr=5.36e-05  train=1.2325  val=0.3216  top1=97.67%  top5=100.00%  (21s)
#   -> new best (97.67%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 19/30] lr=4.74e-05  train=1.2022  val=0.3581  top1=97.61%  top5=99.98%  (21s)
# [ 20/30] lr=4.12e-05  train=1.1866  val=0.2993  top1=97.98%  top5=99.98%  (21s)
#   -> new best (97.98%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 21/30] lr=3.52e-05  train=1.1766  val=0.3239  top1=97.94%  top5=99.98%  (21s)
# [ 22/30] lr=2.94e-05  train=1.2022  val=0.3615  top1=97.74%  top5=99.96%  (18s)
# [ 23/30] lr=2.40e-05  train=1.1980  val=0.3225  top1=97.81%  top5=99.96%  (18s)
# [ 24/30] lr=1.89e-05  train=1.1818  val=0.3244  top1=98.00%  top5=100.00%  (20s)
#   -> new best (98.00%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 25/30] lr=1.44e-05  train=1.1929  val=0.3471  top1=97.83%  top5=99.98%  (19s)
# [ 26/30] lr=1.05e-05  train=1.1847  val=0.3431  top1=97.93%  top5=99.98%  (19s)
# [ 27/30] lr=7.12e-06  train=1.1754  val=0.3050  top1=97.94%  top5=100.00%  (19s)
# [ 28/30] lr=4.48e-06  train=1.2064  val=0.3941  top1=97.85%  top5=99.96%  (18s)
# [ 29/30] lr=2.56e-06  train=1.1960  val=0.3572  top1=98.09%  top5=99.98%  (19s)
#   -> new best (98.09%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 30/30] lr=1.39e-06  train=1.1953  val=0.3580  top1=98.09%  top5=100.00%  (18s)
#
# Done.  Best val top-1: 98.09%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#
# === Finished shvit_s3 ===
#
#
# ============================================================
# Training shvit_s2  (wd=0.032)
# ============================================================
# Model: shvit_s2   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s2.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 11,038,562
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.2321  val=1.9014  top1=45.30%  top5=89.57%  (66s)
#   -> new best (45.30%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  2/30] lr=4.00e-05  train=1.9881  val=1.2486  top1=72.41%  top5=98.69%  (18s)
#   -> new best (72.41%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  3/30] lr=6.00e-05  train=1.7370  val=0.7629  top1=83.59%  top5=99.63%  (18s)
#   -> new best (83.59%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  4/30] lr=8.00e-05  train=1.5283  val=0.5506  top1=89.69%  top5=99.85%  (18s)
#   -> new best (89.69%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  5/30] lr=1.00e-04  train=1.4658  val=0.5792  top1=89.39%  top5=99.96%  (18s)
# [  6/30] lr=1.00e-04  train=1.4157  val=0.4461  top1=93.72%  top5=99.98%  (18s)
#   -> new best (93.72%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  7/30] lr=9.96e-05  train=1.4010  val=0.4198  top1=94.87%  top5=99.98%  (18s)
#   -> new best (94.87%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  8/30] lr=9.84e-05  train=1.3119  val=0.3828  top1=95.28%  top5=100.00%  (18s)
#   -> new best (95.28%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  9/30] lr=9.65e-05  train=1.3261  val=0.3779  top1=95.37%  top5=99.98%  (17s)
#   -> new best (95.37%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 10/30] lr=9.39e-05  train=1.2855  val=0.4328  top1=93.20%  top5=100.00%  (18s)
# [ 11/30] lr=9.05e-05  train=1.2839  val=0.4452  top1=92.15%  top5=99.98%  (17s)
# [ 12/30] lr=8.66e-05  train=1.2906  val=0.3471  top1=96.24%  top5=99.98%  (18s)
#   -> new best (96.24%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 13/30] lr=8.21e-05  train=1.3150  val=0.3742  top1=96.61%  top5=99.98%  (18s)
#   -> new best (96.61%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 14/30] lr=7.70e-05  train=1.2359  val=0.3392  top1=97.30%  top5=99.98%  (17s)
#   -> new best (97.30%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 15/30] lr=7.16e-05  train=1.2301  val=0.2965  top1=97.41%  top5=99.98%  (18s)
#   -> new best (97.41%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 16/30] lr=6.58e-05  train=1.2646  val=0.3421  top1=96.87%  top5=99.98%  (18s)
# [ 17/30] lr=5.98e-05  train=1.2296  val=0.3379  top1=96.83%  top5=99.98%  (17s)
# [ 18/30] lr=5.36e-05  train=1.2500  val=0.3042  top1=97.13%  top5=99.96%  (18s)
# [ 19/30] lr=4.74e-05  train=1.2285  val=0.3257  top1=97.09%  top5=99.96%  (18s)
# [ 20/30] lr=4.12e-05  train=1.2139  val=0.3093  top1=97.31%  top5=99.98%  (17s)
# [ 21/30] lr=3.52e-05  train=1.2021  val=0.2961  top1=97.33%  top5=99.98%  (18s)
# [ 22/30] lr=2.94e-05  train=1.2201  val=0.3378  top1=97.37%  top5=99.96%  (18s)
# [ 23/30] lr=2.40e-05  train=1.2246  val=0.2800  top1=97.70%  top5=99.96%  (18s)
#   -> new best (97.70%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 24/30] lr=1.89e-05  train=1.1947  val=0.2911  top1=97.72%  top5=99.96%  (18s)
#   -> new best (97.72%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 25/30] lr=1.44e-05  train=1.2261  val=0.3133  top1=97.61%  top5=99.96%  (18s)
# [ 26/30] lr=1.05e-05  train=1.2076  val=0.3051  top1=97.63%  top5=99.96%  (18s)
# [ 27/30] lr=7.12e-06  train=1.2105  val=0.2819  top1=97.78%  top5=99.96%  (18s)
#   -> new best (97.78%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 28/30] lr=4.48e-06  train=1.2343  val=0.3429  top1=97.57%  top5=99.96%  (18s)
# [ 29/30] lr=2.56e-06  train=1.2273  val=0.3079  top1=97.69%  top5=99.98%  (18s)
# [ 30/30] lr=1.39e-06  train=1.2202  val=0.3245  top1=97.69%  top5=99.98%  (18s)
#
# Done.  Best val top-1: 97.78%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#
# === Finished shvit_s2 ===
#
#
# ============================================================
# Training shvit_s1  (wd=0.025)
# ============================================================
# Model: shvit_s1   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s1.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 6,013,018
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.2424  val=1.9740  top1=40.98%  top5=87.41%  (65s)
#   -> new best (40.98%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  2/30] lr=4.00e-05  train=2.0522  val=1.4974  top1=58.96%  top5=97.61%  (18s)
#   -> new best (58.96%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  3/30] lr=6.00e-05  train=1.8454  val=1.0418  top1=74.02%  top5=99.20%  (18s)
#   -> new best (74.02%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  4/30] lr=8.00e-05  train=1.6255  val=0.6609  top1=88.81%  top5=99.81%  (18s)
#   -> new best (88.81%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  5/30] lr=1.00e-04  train=1.5191  val=0.5195  top1=91.72%  top5=99.94%  (18s)
#   -> new best (91.72%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  6/30] lr=1.00e-04  train=1.4421  val=0.4644  top1=93.48%  top5=99.96%  (18s)
#   -> new best (93.48%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  7/30] lr=9.96e-05  train=1.4445  val=0.4648  top1=94.15%  top5=99.94%  (18s)
#   -> new best (94.15%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  8/30] lr=9.84e-05  train=1.3410  val=0.4212  top1=93.98%  top5=99.94%  (18s)
# [  9/30] lr=9.65e-05  train=1.3635  val=0.4061  top1=94.74%  top5=99.98%  (18s)
#   -> new best (94.74%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 10/30] lr=9.39e-05  train=1.3077  val=0.4064  top1=95.11%  top5=99.96%  (18s)
#   -> new best (95.11%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 11/30] lr=9.05e-05  train=1.3069  val=0.3677  top1=95.80%  top5=99.98%  (18s)
#   -> new best (95.80%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 12/30] lr=8.66e-05  train=1.3175  val=0.3585  top1=95.89%  top5=99.98%  (18s)
#   -> new best (95.89%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 13/30] lr=8.21e-05  train=1.3404  val=0.3875  top1=95.87%  top5=99.98%  (18s)
# [ 14/30] lr=7.70e-05  train=1.2545  val=0.3558  top1=96.20%  top5=99.98%  (18s)
#   -> new best (96.20%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 15/30] lr=7.16e-05  train=1.2403  val=0.3264  top1=96.89%  top5=99.98%  (18s)
#   -> new best (96.89%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 16/30] lr=6.58e-05  train=1.2889  val=0.3302  top1=96.83%  top5=99.98%  (18s)
# [ 17/30] lr=5.98e-05  train=1.2568  val=0.3551  top1=96.78%  top5=99.98%  (18s)
# [ 18/30] lr=5.36e-05  train=1.2808  val=0.3334  top1=97.00%  top5=100.00%  (18s)
#   -> new best (97.00%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 19/30] lr=4.74e-05  train=1.2523  val=0.3624  top1=96.74%  top5=99.98%  (18s)
# [ 20/30] lr=4.12e-05  train=1.2422  val=0.3202  top1=96.93%  top5=99.98%  (18s)
# [ 21/30] lr=3.52e-05  train=1.2271  val=0.3213  top1=97.22%  top5=100.00%  (18s)
#   -> new best (97.22%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 22/30] lr=2.94e-05  train=1.2592  val=0.3620  top1=96.72%  top5=99.96%  (18s)
# [ 23/30] lr=2.40e-05  train=1.2576  val=0.3105  top1=97.15%  top5=99.98%  (18s)
# [ 24/30] lr=1.89e-05  train=1.2303  val=0.3174  top1=97.13%  top5=100.00%  (18s)
# [ 25/30] lr=1.44e-05  train=1.2496  val=0.3367  top1=97.11%  top5=99.98%  (18s)
# [ 26/30] lr=1.05e-05  train=1.2341  val=0.3211  top1=97.06%  top5=100.00%  (19s)
# [ 27/30] lr=7.12e-06  train=1.2379  val=0.3098  top1=97.30%  top5=100.00%  (18s)
#   -> new best (97.30%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 28/30] lr=4.48e-06  train=1.2535  val=0.3580  top1=97.11%  top5=99.98%  (18s)
# [ 29/30] lr=2.56e-06  train=1.2397  val=0.3378  top1=97.37%  top5=99.98%  (18s)
#   -> new best (97.37%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 30/30] lr=1.39e-06  train=1.2459  val=0.3396  top1=97.20%  top5=99.98%  (18s)
#
# Done.  Best val top-1: 97.37%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#
# === Finished shvit_s1 ===
#
# All 4 SHViT variants done.

# %%
# Resume from a checkpoint if the session was interrupted
# !python /content/finetune_shvit_eurosat.py \
#     --shvit-dir  /content/SHViT \
#     --data-root  {DATA_ROOT} \
#     --output-dir "{OUTPUT_DIR}/shvit_s4" \
#     --resume     "{OUTPUT_DIR}/shvit_s4/checkpoint_010.pth" \
#     --epochs 30 \
#     --batch-size 64 \
#     --lr 1e-4 \
#     --num-workers 8

# %%
import os, urllib.request

# Recovery cell for the SHViT pretrained weights (shvit_s1..s4).
# Re-downloads ONLY variants whose file is missing or truncated (the
# original failure mode was a 0-byte file; genuine checkpoints are
# 100-300 MB, so anything under 100 MB is treated as broken).
#
# Side-effect: populates MODELS_TO_REDO with every variant we actually had
# to recover, so the next cell only retrains those. A healthy file leaves
# MODELS_TO_REDO empty, making the retrain cell a no-op.
MODELS_TO_REDO = []
MIN_VALID_MB = 100  # genuine file is ~229 MB

def _recover(model_name):
    path = f'{WEIGHTS_DIR}/{model_name}.pth'
    url  = f'https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth'

    if os.path.exists(path):
        size_mb = os.path.getsize(path) / 1e6
        if size_mb >= MIN_VALID_MB:
            print(f'{model_name}.pth looks healthy ({size_mb:.2f} MB) - skipping recovery.')
            return False
        print(f'{model_name}.pth looks broken ({size_mb:.2f} MB) - re-downloading.')
        os.remove(path)
    else:
        print(f'{model_name}.pth not found - downloading.')

    os.makedirs(WEIGHTS_DIR, exist_ok=True)
    print(f'  from {url}')
    urllib.request.urlretrieve(url, path)
    print(f'  done: {os.path.getsize(path)/1e6:.2f} MB')
    return True

# Check all four SHViT variants
for _name in ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']:
    if _recover(_name):
        MODELS_TO_REDO.append(_name)

print('\nMODELS_TO_REDO =', MODELS_TO_REDO)
# Out:
# shvit_s1.pth looks healthy (102.12 MB) - skipping recovery.
# shvit_s2.pth looks healthy (184.67 MB) - skipping recovery.
# shvit_s3.pth looks healthy (229.01 MB) - skipping recovery.
# shvit_s4.pth looks healthy (266.73 MB) - skipping recovery.
#
# MODELS_TO_REDO = []

# %%
# Retrain every variant that the recovery cell (Cell 15) actually had to
# re-download. If MODELS_TO_REDO is empty, nothing happens.
if not MODELS_TO_REDO:
    print('No variants need retraining (MODELS_TO_REDO is empty).')

for model_name in MODELS_TO_REDO:
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'

    # !python /content/finetune_shvit_food101.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir {model_output_dir} \
        --split-file /content/train_val_split_seed42.json \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8
# Out:
# No variants need retraining (MODELS_TO_REDO is empty).

# %% [markdown]
# ## 5. Evaluate the best checkpoint

# %%
MODEL = 'shvit_s4'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s4   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 16,143,974
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 98.11%   top-5: 99.98%

# %%
MODEL = 'shvit_s3'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s3   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 13,800,763
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 98.09%   top-5: 99.98%

# %%
MODEL = 'shvit_s2'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s2   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 11,038,562
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 97.78%   top-5: 99.96%

# %%
MODEL = 'shvit_s1'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s1   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 6,013,018
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 97.37%   top-5: 99.98%

# %% [markdown]
# ## 6. Plot training curves

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

MODELS = ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']
COLORS = {'shvit_s1': 'tab:blue', 'shvit_s2': 'tab:orange',
          'shvit_s3': 'tab:green', 'shvit_s4': 'tab:red'}

fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))

summary = []
for model_name in MODELS:
    csv_path = f'{OUTPUT_DIR}/{model_name}/training_log.csv'
    if not os.path.exists(csv_path):
        print(f'[skip] no log for {model_name}')
        continue

    df = pd.read_csv(csv_path)
    color = COLORS[model_name]

    axes[0].plot(df['epoch'], df['train_loss'], label=f'{model_name} train', color=color)
    axes[0].plot(df['epoch'], df['val_loss'],   label=f'{model_name} val',
                 color=color, linestyle='--', alpha=0.7)

    axes[1].plot(df['epoch'], df['val_top1'] * 100, label=f'{model_name} top-1', color=color)
    axes[1].plot(df['epoch'], df['val_top5'] * 100, label=f'{model_name} top-5',
                 color=color, linestyle='--', alpha=0.7)

    axes[2].plot(df['epoch'], df['lr'].astype(float), label=model_name, color=color)

    best = df.loc[df['val_top1'].idxmax()]
    summary.append((model_name, best['val_top1']*100, best['val_top5']*100, int(best['epoch'])))

axes[0].set_title('Loss');           axes[0].set_xlabel('epoch')
axes[0].legend(fontsize=8, ncol=2);  axes[0].grid(True)

axes[1].set_title('Val Accuracy (%)'); axes[1].set_xlabel('epoch')
axes[1].legend(fontsize=8, ncol=2);    axes[1].grid(True)

axes[2].set_title('Learning Rate');    axes[2].set_xlabel('epoch')
axes[2].set_yscale('log');             axes[2].legend(fontsize=8); axes[2].grid(True)

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/training_curves_all.png', dpi=120)
plt.show()

print('\nBest val accuracy per model:')
print(f'{"model":<12} {"top-1":>8} {"top-5":>8} {"epoch":>6}')
for name, t1, t5, ep in summary:
    print(f'{name:<12} {t1:>7.2f}% {t5:>7.2f}% {ep:>6}')
# Out:
# Best val accuracy per model:
# model           top-1    top-5  epoch
# shvit_s1       97.37%   99.98%     29
# shvit_s2       97.78%   99.96%     27
# shvit_s3       98.09%   99.98%     29
# shvit_s4       98.11%   99.98%     27

# %% [markdown]
# # Stage 3 — Fine-tuning SHViT on EuroSAT
#
# This notebook fine-tunes pretrained SHViT models (S1..S4) on EuroSAT
# using `finetune_shvit_eurosat.py`. Data preprocessing follows
# Tip-Adapter (`splits.py`, CLIP normalization, bicubic resize).
#
# **Before running:** `Runtime → Change runtime type → T4 GPU`
#
# ### What this notebook does
# 1. Verifies GPU, mounts Drive (optional), prepares paths
# 2. Clones SHViT + this project repo, installs deps
# 3. Downloads SHViT pretrained weights (S1..S4)
# 4. Runs `finetune_shvit_eurosat.py` for each variant
# 5. Plots training curves
#
# All outputs land under `<OUT_ROOT>/Stage 3: fine-tuning SHViT/<variant>/`.

# %% [markdown]
# ## 0. GPU check

# %%
import torch
print('PyTorch :', torch.__version__)
print('CUDA    :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU     :', torch.cuda.get_device_name(0))
# Out:
# PyTorch : 2.11.0+cu128
# CUDA    : True
# GPU     : NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## 1. (Optional) Mount Drive
#
# Persist the dataset, weights, and checkpoints across sessions.

# %%
USE_DRIVE = True

OUT_ROOT = '/content/CV_Research_Paper_EuroSAT'

if USE_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_ROOT   = '/content/drive/MyDrive/eurosat_data'
    WEIGHTS_DIR = '/content/drive/MyDrive/shvit_weights'
    OUT_ROOT    = '/content/drive/MyDrive/CV_Research_Paper_EuroSAT'
else:
    DATA_ROOT   = '/content/eurosat_data'
    WEIGHTS_DIR = '/content/weights'

OUTPUT_DIR = f'{OUT_ROOT}/Stage 3: fine-tuning SHViT'
WEIGHTS_PATH = f'{WEIGHTS_DIR}/shvit_s4.pth'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)
os.makedirs(WEIGHTS_DIR, exist_ok=True)

print('Data       :', DATA_ROOT)
print('Weights    :', WEIGHTS_PATH)
print('Output root:', OUT_ROOT)
print('Output dir :', OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Data       : /content/drive/MyDrive/eurosat_data
# Weights    : /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# Output root: /content/drive/MyDrive/CV_Research_Paper_EuroSAT
# Output dir : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT

# %%
# Optional: copy the dataset to local SSD for faster I/O.
import shutil, os, time
src = '/content/drive/MyDrive/eurosat_data'
dst = '/content/eurosat_local'

if USE_DRIVE and not os.path.exists(dst) and os.path.isdir(src):
    print('Copying dataset to local SSD...')
    t0 = time.time()
    shutil.copytree(src, dst)
    print(f'done in {time.time()-t0:.0f}s')
    DATA_ROOT = dst
elif os.path.exists(dst):
    DATA_ROOT = dst
print('DATA_ROOT now:', DATA_ROOT)
# Out:
# Copying dataset to local SSD...
# done in 0s
# DATA_ROOT now: /content/eurosat_local

# %% [markdown]
# ## 2. Clone repos and install dependencies

# %%
import os, shutil

if not os.path.isdir('/content/SHViT'):
    # !git clone https://github.com/ysj9909/SHViT.git /content/SHViT

REPO = '/content/Vision_Project_spring_26'
if not os.path.isdir(REPO):
    # !git clone -b Vision_Project_spring_26_EuroSAT \
        https://github.com/saif-farid-tech/Vision_Project_spring_26.git {REPO}

for fname in [
    'Stage 3: fine-tuning SHViT/finetune_shvit_eurosat.py',
    'splits.py',
    'metrics.py',
    'augmentation.py',
    'prepare_eurosat.py',
]:
    shutil.copy(f'{REPO}/{fname}', f'/content/{os.path.basename(fname)}')
    print('Copied:', os.path.basename(fname))

DATASETS_DST = '/content/datasets'
if os.path.isdir(DATASETS_DST):
    shutil.rmtree(DATASETS_DST)
shutil.copytree(f'{REPO}/datasets', DATASETS_DST)
print('Vendored datasets/ package.')
# Out:
# Cloning into '/content/SHViT'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 183 (delta 84), reused 82 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 168.52 KiB | 8.02 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Cloning into '/content/Vision_Project_spring_26'...
# remote: Enumerating objects: 983, done.
# remote: Counting objects: 100% (414/414), done.
# remote: Compressing objects: 100% (248/248), done.
# remote: Total 983 (delta 271), reused 209 (delta 160), pack-reused 569 (from 1)
# Receiving objects: 100% (983/983), 512.11 MiB | 39.77 MiB/s, done.
# Resolving deltas: 100% (514/514), done.
# Copied: finetune_shvit_eurosat.py
# Copied: splits.py
# Copied: metrics.py
# Copied: augmentation.py
# Copied: prepare_eurosat.py
# Vendored datasets/ package.

# %%
# Install SHViT deps (timm pinned, --no-deps so torch isn't downgraded).
# gdown is used by prepare_eurosat.py to fetch the CoOp split.
# !pip install -q timm==0.5.4 --no-deps
# !pip install -q einops==0.4.1 easydict gdown
print('Dependencies installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 21.5 MB/s eta 0:00:00
# Dependencies installed.

# %% [markdown]
# ## 3. Download SHViT-S4 pretrained weights

# %%
os.makedirs(WEIGHTS_DIR, exist_ok=True)
if not os.path.exists(WEIGHTS_PATH):
    # !wget -q --show-progress \
        https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s4.pth \
        -O {WEIGHTS_PATH}
size_mb = os.path.getsize(WEIGHTS_PATH) / 1e6
print(f'Checkpoint: {size_mb:.1f} MB  ->  {WEIGHTS_PATH}')

# Also pre-download the EuroSAT split + images so the first training run is fast
# !python /content/prepare_eurosat.py --root {DATA_ROOT}
# Out:
# Checkpoint: 266.7 MB  ->  /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# [eurosat] downloading EuroSAT via torchvision into /content/eurosat_local ...
# 100% 94.3M/94.3M [00:00<00:00, 389MB/s]
# [eurosat] trying official split download via gdown: https://drive.google.com/uc?id=1Ip7yaCWFi0eaOFUGga0lUdVi_DDQth1o
# Downloading...
# From: https://drive.google.com/uc?id=1Ip7yaCWFi0eaOFUGga0lUdVi_DDQth1o
# To: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# 100% 3.01M/3.01M [00:00<00:00, 266MB/s]
# [eurosat] official split saved to /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
#
# Done. Dataset root: /content/eurosat_local/eurosat
#   classes : 10
#   train   : 13,500
#   val     : 5,400
#   test    : 8,100

# %% [markdown]
# ## 4. Fine-tune SHViT on EuroSAT
#
# EuroSAT-RGB is moderate (~2 GB unpacked, 27,000 images across 10
# land-cover classes). Each epoch on a T4 takes ~1 minute with batch 64 —
# 30 epochs ≈ 30 min per SHViT variant.

# %%
# Quick smoke-test: 2 epochs to verify everything runs
# !python /content/finetune_shvit_eurosat.py \
    --shvit-dir  /content/SHViT \
    --finetune   {WEIGHTS_PATH} \
    --data-root  {DATA_ROOT} \
    --output-dir "{OUTPUT_DIR}/shvit_s4_smoke" \
    --epochs 2 \
    --batch-size 64 \
    --lr 1e-4 \
    --num-workers 8
# Out:
# Model: shvit_s4   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1579, in load
#     return _load(
#            ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 2190, in _load
#     result = unpickler.load()
#              ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 2154, in persistent_load
#     typed_storage = load_tensor(
#                     ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 2097, in load_tensor
#     zip_file.get_storage_from_record(name, nbytes, torch.UntypedStorage)
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/finetune_shvit_eurosat.py", line 351, in <module>
#     main()
#   File "/content/finetune_shvit_eurosat.py", line 264, in main
#     load_pretrained(model, args.finetune)
#   File "/content/finetune_shvit_eurosat.py", line 134, in load_pretrained
#     ckpt = torch.load(ckpt_path, map_location="cpu", weights_only=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1530, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 779, in __exit__
#     self.file_like.close()
# OSError: [Errno 107] Transport endpoint is not connected

# %%
# Train all 4 SHViT variants sequentially.
MODELS = ['shvit_s4', 'shvit_s3', 'shvit_s2', 'shvit_s1']

# Per-variant weight decay from the SHViT paper (Table 7).
WEIGHT_DECAY = {
    'shvit_s1': 0.025,
    'shvit_s2': 0.032,
    'shvit_s3': 0.035,
    'shvit_s4': 0.050,
}

for model_name in MODELS:
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'

    if not os.path.exists(weights_path):
        print(f'\n=== Downloading {model_name} pretrained weights ===')
        # !wget -q --show-progress \
            https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth \
            -O {weights_path}

    print(f'\n{"="*60}')
    print(f'Training {model_name}  (wd={WEIGHT_DECAY[model_name]})')
    print(f'{"="*60}')

    # !python /content/finetune_shvit_eurosat.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir "{model_output_dir}" \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8

    print(f'\n=== Finished {model_name} ===\n')

print('All 4 SHViT variants done.')
# Out:
# === Downloading shvit_s4 pretrained weights ===
# /content/drive/MyDrive/shvit_weights/shvit_s4.pth: No such file or directory
#
# ============================================================
# Training shvit_s4  (wd=0.05)
# ============================================================
# Model: shvit_s4   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Trainable parameters: 16,143,974
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.0947  val=1.3684  top1=56.02%  top5=94.28%  (70s)
#   -> new best (56.02%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  2/30] lr=4.00e-05  train=1.9806  val=1.2419  top1=58.17%  top5=95.54%  (21s)
#   -> new best (58.17%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  3/30] lr=6.00e-05  train=1.9568  val=1.1151  top1=64.98%  top5=97.85%  (21s)
#   -> new best (64.98%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  4/30] lr=8.00e-05  train=1.8847  val=1.0013  top1=69.20%  top5=97.89%  (21s)
#   -> new best (69.20%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  5/30] lr=1.00e-04  train=1.8609  val=0.9673  top1=68.26%  top5=97.39%  (21s)
# [  6/30] lr=1.00e-04  train=1.8499  val=0.8864  top1=73.06%  top5=98.11%  (21s)
#   -> new best (73.06%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  7/30] lr=9.96e-05  train=1.8457  val=0.8799  top1=74.33%  top5=98.39%  (21s)
#   -> new best (74.33%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  8/30] lr=9.84e-05  train=1.7620  val=0.9151  top1=72.20%  top5=98.57%  (21s)
# [  9/30] lr=9.65e-05  train=1.7829  val=0.9073  top1=72.22%  top5=98.74%  (21s)
# [ 10/30] lr=9.39e-05  train=1.7333  val=0.8069  top1=77.07%  top5=99.06%  (21s)
#   -> new best (77.07%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 11/30] lr=9.05e-05  train=1.7258  val=0.7213  top1=78.93%  top5=99.26%  (21s)
#   -> new best (78.93%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 12/30] lr=8.66e-05  train=1.7245  val=0.7535  top1=76.19%  top5=99.11%  (21s)
# [ 13/30] lr=8.21e-05  train=1.7428  val=0.7421  top1=79.56%  top5=99.15%  (21s)
#   -> new best (79.56%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 14/30] lr=7.70e-05  train=1.6625  val=0.6426  top1=81.94%  top5=99.35%  (21s)
#   -> new best (81.94%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 15/30] lr=7.16e-05  train=1.6639  val=0.6508  top1=82.30%  top5=99.26%  (22s)
#   -> new best (82.30%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 16/30] lr=6.58e-05  train=1.6734  val=0.6485  top1=81.37%  top5=99.43%  (21s)
# [ 17/30] lr=5.98e-05  train=1.6443  val=0.6330  top1=83.04%  top5=99.31%  (21s)
#   -> new best (83.04%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 18/30] lr=5.36e-05  train=1.6680  val=0.5987  top1=84.65%  top5=99.57%  (21s)
#   -> new best (84.65%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 19/30] lr=4.74e-05  train=1.6169  val=0.5514  top1=85.56%  top5=99.69%  (21s)
#   -> new best (85.56%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 20/30] lr=4.12e-05  train=1.6177  val=0.5751  top1=85.48%  top5=99.56%  (21s)
# [ 21/30] lr=3.52e-05  train=1.5951  val=0.5375  top1=86.26%  top5=99.74%  (21s)
#   -> new best (86.26%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 22/30] lr=2.94e-05  train=1.6159  val=0.5854  top1=86.02%  top5=99.63%  (21s)
# [ 23/30] lr=2.40e-05  train=1.6147  val=0.5405  top1=86.83%  top5=99.78%  (21s)
#   -> new best (86.83%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 24/30] lr=1.89e-05  train=1.5907  val=0.5283  top1=87.19%  top5=99.80%  (21s)
#   -> new best (87.19%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 25/30] lr=1.44e-05  train=1.6040  val=0.5418  top1=86.78%  top5=99.78%  (21s)
# [ 26/30] lr=1.05e-05  train=1.5956  val=0.5221  top1=87.50%  top5=99.78%  (21s)
#   -> new best (87.50%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 27/30] lr=7.12e-06  train=1.5743  val=0.5177  top1=87.85%  top5=99.72%  (21s)
#   -> new best (87.85%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 28/30] lr=4.48e-06  train=1.5991  val=0.5478  top1=87.33%  top5=99.70%  (21s)
# [ 29/30] lr=2.56e-06  train=1.5940  val=0.5214  top1=87.41%  top5=99.72%  (21s)
# [ 30/30] lr=1.39e-06  train=1.5899  val=0.5180  top1=87.78%  top5=99.76%  (21s)
#
# Done.  Best val top-1: 87.85%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#
# === Finished shvit_s4 ===
#
#
# === Downloading shvit_s3 pretrained weights ===
# /content/drive/MyDrive/shvit_weights/shvit_s3.pth: No such file or directory
#
# ============================================================
# Training shvit_s3  (wd=0.035)
# ============================================================
# Model: shvit_s3   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Trainable parameters: 13,800,763
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.1027  val=1.3590  top1=55.93%  top5=94.94%  (64s)
#   -> new best (55.93%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  2/30] lr=4.00e-05  train=1.9807  val=1.2224  top1=60.31%  top5=96.04%  (19s)
#   -> new best (60.31%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  3/30] lr=6.00e-05  train=1.9240  val=1.0764  top1=67.19%  top5=96.67%  (19s)
#   -> new best (67.19%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  4/30] lr=8.00e-05  train=1.8931  val=0.9882  top1=68.06%  top5=97.50%  (18s)
#   -> new best (68.06%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  5/30] lr=1.00e-04  train=1.8642  val=1.0601  top1=65.54%  top5=97.52%  (18s)
# [  6/30] lr=1.00e-04  train=1.8550  val=0.8940  top1=71.02%  top5=97.89%  (18s)
#   -> new best (71.02%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  7/30] lr=9.96e-05  train=1.8453  val=0.9142  top1=72.04%  top5=97.93%  (18s)
#   -> new best (72.04%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  8/30] lr=9.84e-05  train=1.7815  val=0.8928  top1=74.67%  top5=98.22%  (19s)
#   -> new best (74.67%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  9/30] lr=9.65e-05  train=1.7847  val=0.8739  top1=73.11%  top5=98.43%  (18s)
# [ 10/30] lr=9.39e-05  train=1.7383  val=0.8029  top1=77.46%  top5=98.41%  (19s)
#   -> new best (77.46%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 11/30] lr=9.05e-05  train=1.7302  val=0.7077  top1=80.11%  top5=99.19%  (18s)
#   -> new best (80.11%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 12/30] lr=8.66e-05  train=1.7413  val=0.7666  top1=76.83%  top5=98.57%  (19s)
# [ 13/30] lr=8.21e-05  train=1.7432  val=0.7698  top1=77.72%  top5=98.81%  (18s)
# [ 14/30] lr=7.70e-05  train=1.6767  val=0.6617  top1=80.94%  top5=99.26%  (19s)
#   -> new best (80.94%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 15/30] lr=7.16e-05  train=1.6596  val=0.6439  top1=81.57%  top5=99.46%  (18s)
#   -> new best (81.57%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 16/30] lr=6.58e-05  train=1.6934  val=0.6584  top1=80.81%  top5=99.17%  (19s)
# [ 17/30] lr=5.98e-05  train=1.6558  val=0.6477  top1=82.94%  top5=99.50%  (19s)
#   -> new best (82.94%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 18/30] lr=5.36e-05  train=1.6769  val=0.6203  top1=84.00%  top5=99.57%  (19s)
#   -> new best (84.00%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 19/30] lr=4.74e-05  train=1.6409  val=0.6127  top1=84.11%  top5=99.65%  (19s)
#   -> new best (84.11%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 20/30] lr=4.12e-05  train=1.6299  val=0.5871  top1=84.57%  top5=99.61%  (19s)
#   -> new best (84.57%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 21/30] lr=3.52e-05  train=1.6191  val=0.5794  top1=83.69%  top5=99.67%  (19s)
# [ 22/30] lr=2.94e-05  train=1.6295  val=0.5950  top1=84.76%  top5=99.67%  (18s)
#   -> new best (84.76%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 23/30] lr=2.40e-05  train=1.6296  val=0.5597  top1=85.26%  top5=99.61%  (18s)
#   -> new best (85.26%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 24/30] lr=1.89e-05  train=1.6055  val=0.5646  top1=85.83%  top5=99.67%  (18s)
#   -> new best (85.83%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 25/30] lr=1.44e-05  train=1.6125  val=0.5586  top1=86.30%  top5=99.67%  (19s)
#   -> new best (86.30%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 26/30] lr=1.05e-05  train=1.6008  val=0.5460  top1=86.57%  top5=99.69%  (19s)
#   -> new best (86.57%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 27/30] lr=7.12e-06  train=1.5968  val=0.5328  top1=87.06%  top5=99.67%  (19s)
#   -> new best (87.06%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 28/30] lr=4.48e-06  train=1.6170  val=0.5607  top1=86.41%  top5=99.63%  (19s)
# [ 29/30] lr=2.56e-06  train=1.6083  val=0.5238  top1=87.20%  top5=99.70%  (19s)
#   -> new best (87.20%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 30/30] lr=1.39e-06  train=1.6038  val=0.5262  top1=86.94%  top5=99.69%  (19s)
#
# Done.  Best val top-1: 87.20%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#
# === Finished shvit_s3 ===
#
#
# === Downloading shvit_s2 pretrained weights ===
# /content/drive/MyDrive/shvit_weights/shvit_s2.pth: No such file or directory
#
# ============================================================
# Training shvit_s2  (wd=0.032)
# ============================================================
# Model: shvit_s2   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Trainable parameters: 11,038,562
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.1421  val=1.4949  top1=51.44%  top5=92.91%  (66s)
#   -> new best (51.44%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  2/30] lr=4.00e-05  train=2.0102  val=1.2766  top1=58.19%  top5=96.63%  (18s)
#   -> new best (58.19%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  3/30] lr=6.00e-05  train=1.9860  val=1.1620  top1=60.20%  top5=97.30%  (18s)
#   -> new best (60.20%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  4/30] lr=8.00e-05  train=1.9112  val=1.0738  top1=66.44%  top5=97.04%  (18s)
#   -> new best (66.44%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  5/30] lr=1.00e-04  train=1.8900  val=0.9993  top1=67.81%  top5=98.04%  (18s)
#   -> new best (67.81%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  6/30] lr=1.00e-04  train=1.8735  val=0.9726  top1=68.26%  top5=98.04%  (18s)
#   -> new best (68.26%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  7/30] lr=9.96e-05  train=1.8613  val=0.9373  top1=71.94%  top5=98.57%  (18s)
#   -> new best (71.94%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  8/30] lr=9.84e-05  train=1.8039  val=0.8827  top1=72.69%  top5=98.20%  (18s)
#   -> new best (72.69%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  9/30] lr=9.65e-05  train=1.8056  val=0.8807  top1=74.22%  top5=98.43%  (18s)
#   -> new best (74.22%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 10/30] lr=9.39e-05  train=1.7709  val=0.8635  top1=74.76%  top5=98.70%  (18s)
#   -> new best (74.76%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 11/30] lr=9.05e-05  train=1.7733  val=0.8147  top1=74.33%  top5=98.81%  (18s)
# [ 12/30] lr=8.66e-05  train=1.7671  val=0.7853  top1=77.54%  top5=98.96%  (18s)
#   -> new best (77.54%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 13/30] lr=8.21e-05  train=1.7893  val=0.7887  top1=76.54%  top5=98.91%  (18s)
# [ 14/30] lr=7.70e-05  train=1.7125  val=0.7209  top1=79.89%  top5=98.98%  (18s)
#   -> new best (79.89%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 15/30] lr=7.16e-05  train=1.7090  val=0.7213  top1=79.24%  top5=99.30%  (18s)
# [ 16/30] lr=6.58e-05  train=1.7269  val=0.7305  top1=79.98%  top5=99.04%  (18s)
#   -> new best (79.98%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 17/30] lr=5.98e-05  train=1.6936  val=0.6982  top1=80.20%  top5=99.30%  (18s)
#   -> new best (80.20%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 18/30] lr=5.36e-05  train=1.7134  val=0.7134  top1=78.83%  top5=99.24%  (17s)
# [ 19/30] lr=4.74e-05  train=1.6851  val=0.6581  top1=82.19%  top5=99.39%  (18s)
#   -> new best (82.19%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 20/30] lr=4.12e-05  train=1.6704  val=0.6677  top1=81.48%  top5=99.50%  (17s)
# [ 21/30] lr=3.52e-05  train=1.6610  val=0.6375  top1=81.67%  top5=99.37%  (18s)
# [ 22/30] lr=2.94e-05  train=1.6783  val=0.6714  top1=82.56%  top5=99.24%  (18s)
#   -> new best (82.56%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 23/30] lr=2.40e-05  train=1.6741  val=0.6321  top1=81.74%  top5=99.46%  (18s)
# [ 24/30] lr=1.89e-05  train=1.6435  val=0.6235  top1=83.35%  top5=99.54%  (18s)
#   -> new best (83.35%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 25/30] lr=1.44e-05  train=1.6610  val=0.6402  top1=83.26%  top5=99.46%  (18s)
# [ 26/30] lr=1.05e-05  train=1.6506  val=0.6120  top1=83.94%  top5=99.54%  (18s)
#   -> new best (83.94%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 27/30] lr=7.12e-06  train=1.6455  val=0.6022  top1=84.52%  top5=99.61%  (17s)
#   -> new best (84.52%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 28/30] lr=4.48e-06  train=1.6722  val=0.6422  top1=83.19%  top5=99.48%  (17s)
# [ 29/30] lr=2.56e-06  train=1.6648  val=0.6178  top1=83.98%  top5=99.59%  (17s)
# [ 30/30] lr=1.39e-06  train=1.6553  val=0.6208  top1=83.41%  top5=99.54%  (18s)
#
# Done.  Best val top-1: 84.52%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#
# === Finished shvit_s2 ===
#
#
# === Downloading shvit_s1 pretrained weights ===
# /content/drive/MyDrive/shvit_weights/shvit_s1.pth: No such file or directory
#
# ============================================================
# Training shvit_s1  (wd=0.025)
# ============================================================
# Model: shvit_s1   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Trainable parameters: 6,013,018
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=2.1589  val=1.5683  top1=49.54%  top5=93.06%  (65s)
#   -> new best (49.54%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  2/30] lr=4.00e-05  train=2.0173  val=1.2753  top1=58.67%  top5=95.85%  (17s)
#   -> new best (58.67%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  3/30] lr=6.00e-05  train=1.9701  val=1.1773  top1=62.17%  top5=96.63%  (18s)
#   -> new best (62.17%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  4/30] lr=8.00e-05  train=1.9145  val=1.0843  top1=65.54%  top5=97.46%  (18s)
#   -> new best (65.54%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  5/30] lr=1.00e-04  train=1.8983  val=1.0334  top1=67.26%  top5=97.93%  (18s)
#   -> new best (67.26%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  6/30] lr=1.00e-04  train=1.8744  val=0.9785  top1=69.31%  top5=97.67%  (18s)
#   -> new best (69.31%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  7/30] lr=9.96e-05  train=1.8673  val=0.9520  top1=70.74%  top5=98.06%  (18s)
#   -> new best (70.74%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  8/30] lr=9.84e-05  train=1.8035  val=0.9462  top1=71.52%  top5=97.85%  (17s)
#   -> new best (71.52%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  9/30] lr=9.65e-05  train=1.8213  val=0.9274  top1=72.61%  top5=98.50%  (18s)
#   -> new best (72.61%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 10/30] lr=9.39e-05  train=1.7793  val=0.8659  top1=76.67%  top5=98.91%  (17s)
#   -> new best (76.67%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 11/30] lr=9.05e-05  train=1.7823  val=0.8227  top1=76.33%  top5=98.76%  (18s)
# [ 12/30] lr=8.66e-05  train=1.7699  val=0.7888  top1=75.78%  top5=98.81%  (18s)
# [ 13/30] lr=8.21e-05  train=1.7975  val=0.8030  top1=77.56%  top5=98.83%  (18s)
#   -> new best (77.56%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 14/30] lr=7.70e-05  train=1.7207  val=0.7531  top1=78.28%  top5=98.89%  (18s)
#   -> new best (78.28%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 15/30] lr=7.16e-05  train=1.7200  val=0.7591  top1=77.67%  top5=99.02%  (18s)
# [ 16/30] lr=6.58e-05  train=1.7299  val=0.7353  top1=78.41%  top5=99.24%  (18s)
#   -> new best (78.41%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 17/30] lr=5.98e-05  train=1.7114  val=0.7252  top1=80.56%  top5=99.07%  (17s)
#   -> new best (80.56%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 18/30] lr=5.36e-05  train=1.7336  val=0.7244  top1=79.98%  top5=99.19%  (18s)
# [ 19/30] lr=4.74e-05  train=1.6886  val=0.6946  top1=80.85%  top5=99.39%  (18s)
#   -> new best (80.85%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 20/30] lr=4.12e-05  train=1.6896  val=0.6752  top1=82.31%  top5=99.39%  (18s)
#   -> new best (82.31%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 21/30] lr=3.52e-05  train=1.6712  val=0.6516  top1=80.70%  top5=99.26%  (18s)
# [ 22/30] lr=2.94e-05  train=1.6982  val=0.6974  top1=81.06%  top5=99.15%  (18s)
# [ 23/30] lr=2.40e-05  train=1.6860  val=0.6459  top1=82.22%  top5=99.44%  (17s)
# [ 24/30] lr=1.89e-05  train=1.6613  val=0.6298  top1=82.65%  top5=99.48%  (18s)
#   -> new best (82.65%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 25/30] lr=1.44e-05  train=1.6746  val=0.6556  top1=81.81%  top5=99.33%  (17s)
# [ 26/30] lr=1.05e-05  train=1.6632  val=0.6345  top1=82.44%  top5=99.50%  (18s)
# [ 27/30] lr=7.12e-06  train=1.6626  val=0.6429  top1=82.63%  top5=99.43%  (17s)
# [ 28/30] lr=4.48e-06  train=1.6746  val=0.6555  top1=82.43%  top5=99.33%  (18s)
# [ 29/30] lr=2.56e-06  train=1.6672  val=0.6309  top1=82.89%  top5=99.35%  (18s)
#   -> new best (82.89%), saved to /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 30/30] lr=1.39e-06  train=1.6604  val=0.6245  top1=82.74%  top5=99.44%  (17s)
#
# Done.  Best val top-1: 82.89%
# Log  : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#
# === Finished shvit_s1 ===
#
# All 4 SHViT variants done.

# %%
# Resume from a checkpoint if the session was interrupted
# !python /content/finetune_shvit_eurosat.py \
#     --shvit-dir  /content/SHViT \
#     --data-root  {DATA_ROOT} \
#     --output-dir "{OUTPUT_DIR}/shvit_s4" \
#     --resume     "{OUTPUT_DIR}/shvit_s4/checkpoint_010.pth" \
#     --epochs 30 \
#     --batch-size 64 \
#     --lr 1e-4 \
#     --num-workers 8

# %%
import os, urllib.request

# Recovery cell for the SHViT pretrained weights (shvit_s1..s4).
# Re-downloads ONLY variants whose file is missing or truncated (the
# original failure mode was a 0-byte file; genuine checkpoints are
# 100-300 MB, so anything under 100 MB is treated as broken).
#
# Side-effect: populates MODELS_TO_REDO with every variant we actually had
# to recover, so the next cell only retrains those. A healthy file leaves
# MODELS_TO_REDO empty, making the retrain cell a no-op.
MODELS_TO_REDO = []
MIN_VALID_MB = 100  # genuine file is ~229 MB

def _recover(model_name):
    path = f'{WEIGHTS_DIR}/{model_name}.pth'
    url  = f'https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth'

    if os.path.exists(path):
        size_mb = os.path.getsize(path) / 1e6
        if size_mb >= MIN_VALID_MB:
            print(f'{model_name}.pth looks healthy ({size_mb:.2f} MB) - skipping recovery.')
            return False
        print(f'{model_name}.pth looks broken ({size_mb:.2f} MB) - re-downloading.')
        os.remove(path)
    else:
        print(f'{model_name}.pth not found - downloading.')

    os.makedirs(WEIGHTS_DIR, exist_ok=True)
    print(f'  from {url}')
    urllib.request.urlretrieve(url, path)
    print(f'  done: {os.path.getsize(path)/1e6:.2f} MB')
    return True

# Check all four SHViT variants
for _name in ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']:
    if _recover(_name):
        MODELS_TO_REDO.append(_name)

print('\nMODELS_TO_REDO =', MODELS_TO_REDO)
# Out:
# shvit_s1.pth not found - downloading.
#   from https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s1.pth
#   done: 102.12 MB
# shvit_s2.pth not found - downloading.
#   from https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s2.pth
#   done: 184.67 MB
# shvit_s3.pth not found - downloading.
#   from https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s3.pth
#   done: 229.01 MB
# shvit_s4.pth not found - downloading.
#   from https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s4.pth
#   done: 266.73 MB
#
# MODELS_TO_REDO = ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']

# %%
# Retrain every variant that the recovery cell (Cell 15) actually had to
# re-download. If MODELS_TO_REDO is empty, nothing happens.
if not MODELS_TO_REDO:
    print('No variants need retraining (MODELS_TO_REDO is empty).')

for model_name in MODELS_TO_REDO:
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'

    # !python /content/finetune_shvit_food101.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir {model_output_dir} \
        --split-file /content/train_val_split_seed42.json \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8
# Out:
# python3: can't open file '/content/finetune_shvit_food101.py': [Errno 2] No such file or directory
# python3: can't open file '/content/finetune_shvit_food101.py': [Errno 2] No such file or directory
# python3: can't open file '/content/finetune_shvit_food101.py': [Errno 2] No such file or directory
# python3: can't open file '/content/finetune_shvit_food101.py': [Errno 2] No such file or directory

# %% [markdown]
# ## 5. Evaluate the best checkpoint

# %%
MODEL = 'shvit_s4'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s4   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 16,143,974
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 87.83%   top-5: 99.72%

# %%
MODEL = 'shvit_s3'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s3   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 13,800,763
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 87.20%   top-5: 99.70%

# %%
MODEL = 'shvit_s2'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s2   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 11,038,562
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 84.52%   top-5: 99.61%

# %%
MODEL = 'shvit_s1'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_eurosat.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s1   Device: cuda
# [eurosat] images already present: /content/eurosat_local/eurosat/2750
# [eurosat] split already present: /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# Reading split from /content/eurosat_local/eurosat/split_zhou_EuroSAT.json
# EuroSAT split: 13,500 train  5,400 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_EuroSAT/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 6,013,018
# /content/finetune_shvit_eurosat.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_eurosat.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 82.89%   top-5: 99.35%

# %% [markdown]
# ## 6. Plot training curves

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

MODELS = ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']
COLORS = {'shvit_s1': 'tab:blue', 'shvit_s2': 'tab:orange',
          'shvit_s3': 'tab:green', 'shvit_s4': 'tab:red'}

fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))

summary = []
for model_name in MODELS:
    csv_path = f'{OUTPUT_DIR}/{model_name}/training_log.csv'
    if not os.path.exists(csv_path):
        print(f'[skip] no log for {model_name}')
        continue

    df = pd.read_csv(csv_path)
    color = COLORS[model_name]

    axes[0].plot(df['epoch'], df['train_loss'], label=f'{model_name} train', color=color)
    axes[0].plot(df['epoch'], df['val_loss'],   label=f'{model_name} val',
                 color=color, linestyle='--', alpha=0.7)

    axes[1].plot(df['epoch'], df['val_top1'] * 100, label=f'{model_name} top-1', color=color)
    axes[1].plot(df['epoch'], df['val_top5'] * 100, label=f'{model_name} top-5',
                 color=color, linestyle='--', alpha=0.7)

    axes[2].plot(df['epoch'], df['lr'].astype(float), label=model_name, color=color)

    best = df.loc[df['val_top1'].idxmax()]
    summary.append((model_name, best['val_top1']*100, best['val_top5']*100, int(best['epoch'])))

axes[0].set_title('Loss');           axes[0].set_xlabel('epoch')
axes[0].legend(fontsize=8, ncol=2);  axes[0].grid(True)

axes[1].set_title('Val Accuracy (%)'); axes[1].set_xlabel('epoch')
axes[1].legend(fontsize=8, ncol=2);    axes[1].grid(True)

axes[2].set_title('Learning Rate');    axes[2].set_xlabel('epoch')
axes[2].set_yscale('log');             axes[2].legend(fontsize=8); axes[2].grid(True)

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/training_curves_all.png', dpi=120)
plt.show()

print('\nBest val accuracy per model:')
print(f'{"model":<12} {"top-1":>8} {"top-5":>8} {"epoch":>6}')
for name, t1, t5, ep in summary:
    print(f'{name:<12} {t1:>7.2f}% {t5:>7.2f}% {ep:>6}')
# Out:
# Best val accuracy per model:
# model           top-1    top-5  epoch
# shvit_s1       82.89%   99.35%     29
# shvit_s2       84.52%   99.61%     27
# shvit_s3       87.20%   99.70%     29
# shvit_s4       87.85%   99.72%     27

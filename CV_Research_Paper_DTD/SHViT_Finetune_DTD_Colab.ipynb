# %% [markdown]
# # Stage 3 — Fine-tuning SHViT on DTD
#
# This notebook fine-tunes pretrained SHViT models (S1..S4) on DTD
# using `finetune_shvit_dtd.py`. Data preprocessing follows
# Tip-Adapter (`splits.py`, CLIP normalization, bicubic resize).
#
# **Before running:** `Runtime → Change runtime type → T4 GPU`
#
# ### What this notebook does
# 1. Verifies GPU, mounts Drive (optional), prepares paths
# 2. Clones SHViT + this project repo, installs deps
# 3. Downloads SHViT pretrained weights (S1..S4)
# 4. Runs `finetune_shvit_dtd.py` for each variant
# 5. Plots training curves
#
# All outputs land under `<OUT_ROOT>/Stage 3: fine-tuning SHViT/<variant>/`.

# %% [markdown]
# ## 0. GPU check

# %%
import torch
print('PyTorch :', torch.__version__)
print('CUDA    :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU     :', torch.cuda.get_device_name(0))
# Out:
# PyTorch : 2.11.0+cu128
# CUDA    : True
# GPU     : NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## 1. (Optional) Mount Drive
#
# Persist the dataset, weights, and checkpoints across sessions.

# %%
USE_DRIVE = True

OUT_ROOT = '/content/CV_Research_Paper_DTD'

if USE_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_ROOT   = '/content/drive/MyDrive/dtd_data'
    WEIGHTS_DIR = '/content/drive/MyDrive/shvit_weights'
    OUT_ROOT    = '/content/drive/MyDrive/CV_Research_Paper_DTD'
else:
    DATA_ROOT   = '/content/dtd_data'
    WEIGHTS_DIR = '/content/weights'

OUTPUT_DIR = f'{OUT_ROOT}/Stage 3: fine-tuning SHViT'
WEIGHTS_PATH = f'{WEIGHTS_DIR}/shvit_s4.pth'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)
os.makedirs(WEIGHTS_DIR, exist_ok=True)

print('Data       :', DATA_ROOT)
print('Weights    :', WEIGHTS_PATH)
print('Output root:', OUT_ROOT)
print('Output dir :', OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Data       : /content/drive/MyDrive/dtd_data
# Weights    : /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# Output root: /content/drive/MyDrive/CV_Research_Paper_DTD
# Output dir : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT

# %%
# Optional: copy the dataset to local SSD for faster I/O.
import shutil, os, time
src = '/content/drive/MyDrive/dtd_data'
dst = '/content/dtd_local'

if USE_DRIVE and not os.path.exists(dst) and os.path.isdir(src):
    print('Copying dataset to local SSD...')
    t0 = time.time()
    shutil.copytree(src, dst)
    print(f'done in {time.time()-t0:.0f}s')
    DATA_ROOT = dst
elif os.path.exists(dst):
    DATA_ROOT = dst
print('DATA_ROOT now:', DATA_ROOT)
# Out:
# Copying dataset to local SSD...
# done in 0s
# DATA_ROOT now: /content/dtd_local

# %% [markdown]
# ## 2. Clone repos and install dependencies

# %%
import os, shutil

if not os.path.isdir('/content/SHViT'):
    # !git clone https://github.com/ysj9909/SHViT.git /content/SHViT

REPO = '/content/Vision_Project_spring_26'
if not os.path.isdir(REPO):
    # !git clone -b Vision_Project_spring_26_DTD \
        https://github.com/saif-farid-tech/Vision_Project_spring_26.git {REPO}

for fname in [
    'Stage 3: fine-tuning SHViT/finetune_shvit_dtd.py',
    'splits.py',
    'metrics.py',
    'augmentation.py',
    'prepare_dtd.py',
]:
    shutil.copy(f'{REPO}/{fname}', f'/content/{os.path.basename(fname)}')
    print('Copied:', os.path.basename(fname))

DATASETS_DST = '/content/datasets'
if os.path.isdir(DATASETS_DST):
    shutil.rmtree(DATASETS_DST)
shutil.copytree(f'{REPO}/datasets', DATASETS_DST)
print('Vendored datasets/ package.')
# Out:
# Cloning into '/content/SHViT'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 183 (delta 84), reused 82 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 168.52 KiB | 14.04 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Cloning into '/content/Vision_Project_spring_26'...
# remote: Enumerating objects: 927, done.
# remote: Counting objects: 100% (358/358), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 927 (delta 243), reused 208 (delta 160), pack-reused 569 (from 1)
# Receiving objects: 100% (927/927), 474.54 MiB | 17.55 MiB/s, done.
# Resolving deltas: 100% (486/486), done.
# Copied: finetune_shvit_dtd.py
# Copied: splits.py
# Copied: metrics.py
# Copied: augmentation.py
# Copied: prepare_dtd.py
# Vendored datasets/ package.

# %%
# Install SHViT deps (timm pinned, --no-deps so torch isn't downgraded).
# gdown is used by prepare_dtd.py to fetch the CoOp split.
# !pip install -q timm==0.5.4 --no-deps
# !pip install -q einops==0.4.1 easydict gdown
print('Dependencies installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 35.4 MB/s eta 0:00:00
# Dependencies installed.

# %% [markdown]
# ## 3. Download SHViT-S4 pretrained weights

# %%
os.makedirs(WEIGHTS_DIR, exist_ok=True)
if not os.path.exists(WEIGHTS_PATH):
    # !wget -q --show-progress \
        https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s4.pth \
        -O {WEIGHTS_PATH}
size_mb = os.path.getsize(WEIGHTS_PATH) / 1e6
print(f'Checkpoint: {size_mb:.1f} MB  ->  {WEIGHTS_PATH}')

# Also pre-download the DTD split + images so the first training run is fast
# !python /content/prepare_dtd.py --root {DATA_ROOT}
# Out:
# Checkpoint: 266.7 MB  ->  /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# [dtd] downloading DTD via torchvision into /content/dtd_local ...
# 100% 625M/625M [00:28<00:00, 21.9MB/s]
# [dtd] moving /content/dtd_local/dtd/dtd/images -> /content/dtd_local/dtd/images
# [dtd] trying official split download via gdown: https://drive.google.com/uc?id=1u3_QfB467jqHgNXC00UIzbLZRQCg2S7x
# Downloading...
# From: https://drive.google.com/uc?id=1u3_QfB467jqHgNXC00UIzbLZRQCg2S7x
# To: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# 100% 564k/564k [00:00<00:00, 130MB/s]
# [dtd] official split saved to /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
#
# Done. Dataset root: /content/dtd_local/dtd
#   classes : 47
#   train   : 2,820
#   val     : 1,128
#   test    : 1,692

# %% [markdown]
# ## 4. Fine-tune SHViT on DTD
#
# DTD is small (~600 MB unpacked, 5,640 images across 47 texture
# categories). Each epoch on a T4 takes ~15–25 sec with batch 64 — 30
# epochs ≈ 10 min per SHViT variant.

# %%
# Quick smoke-test: 2 epochs to verify everything runs
# !python /content/finetune_shvit_dtd.py \
    --shvit-dir  /content/SHViT \
    --finetune   {WEIGHTS_PATH} \
    --data-root  {DATA_ROOT} \
    --output-dir "{OUTPUT_DIR}/shvit_s4_smoke" \
    --epochs 2 \
    --batch-size 64 \
    --lr 1e-4 \
    --num-workers 8
# Out:
# Model: shvit_s4   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,160,587
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 2 epochs (starting at 0)
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/2] lr=2.00e-05  train=3.8575  val=3.8361  top1=2.75%  top5=12.68%  (54s)
#   -> new best (2.75%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
# [  2/2] lr=4.00e-05  train=3.8321  val=3.7899  top1=5.50%  top5=22.25%  (7s)
#   -> new best (5.50%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
#
# Done.  Best val top-1: 5.50%
# Log  : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4_smoke/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth

# %%
# Train all 4 SHViT variants sequentially.
MODELS = ['shvit_s4', 'shvit_s3', 'shvit_s2', 'shvit_s1']

# Per-variant weight decay from the SHViT paper (Table 7).
WEIGHT_DECAY = {
    'shvit_s1': 0.025,
    'shvit_s2': 0.032,
    'shvit_s3': 0.035,
    'shvit_s4': 0.050,
}

for model_name in MODELS:
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'

    if not os.path.exists(weights_path):
        print(f'\n=== Downloading {model_name} pretrained weights ===')
        # !wget -q --show-progress \
            https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth \
            -O {weights_path}

    print(f'\n{"="*60}')
    print(f'Training {model_name}  (wd={WEIGHT_DECAY[model_name]})')
    print(f'{"="*60}')

    # !python /content/finetune_shvit_dtd.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir "{model_output_dir}" \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8

    print(f'\n=== Finished {model_name} ===\n')

print('All 4 SHViT variants done.')
# Out:
# ============================================================
# Training shvit_s4  (wd=0.05)
# ============================================================
# Model: shvit_s4   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,160,587
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.8576  val=3.8357  top1=2.93%  top5=12.94%  (53s)
#   -> new best (2.93%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  2/30] lr=4.00e-05  train=3.8321  val=3.7898  top1=6.03%  top5=22.61%  (7s)
#   -> new best (6.03%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  3/30] lr=6.00e-05  train=3.8017  val=3.7411  top1=12.68%  top5=34.84%  (7s)
#   -> new best (12.68%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  4/30] lr=8.00e-05  train=3.7471  val=3.6324  top1=25.71%  top5=53.10%  (7s)
#   -> new best (25.71%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  5/30] lr=1.00e-04  train=3.6493  val=3.4491  top1=37.85%  top5=69.06%  (7s)
#   -> new best (37.85%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  6/30] lr=1.00e-04  train=3.5081  val=3.2042  top1=44.86%  top5=75.18%  (7s)
#   -> new best (44.86%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  7/30] lr=9.96e-05  train=3.3502  val=2.9371  top1=47.43%  top5=79.43%  (7s)
#   -> new best (47.43%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  8/30] lr=9.84e-05  train=3.2533  val=2.6949  top1=49.11%  top5=81.56%  (7s)
#   -> new best (49.11%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  9/30] lr=9.65e-05  train=3.0525  val=2.4971  top1=51.77%  top5=83.33%  (7s)
#   -> new best (51.77%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 10/30] lr=9.39e-05  train=2.9829  val=2.3561  top1=55.05%  top5=85.46%  (7s)
#   -> new best (55.05%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 11/30] lr=9.05e-05  train=2.7893  val=2.1606  top1=56.56%  top5=86.08%  (7s)
#   -> new best (56.56%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 12/30] lr=8.66e-05  train=2.7424  val=2.0685  top1=58.24%  top5=87.50%  (7s)
#   -> new best (58.24%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 13/30] lr=8.21e-05  train=2.7383  val=2.0020  top1=59.22%  top5=88.03%  (7s)
#   -> new best (59.22%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 14/30] lr=7.70e-05  train=2.6479  val=1.9107  top1=60.28%  top5=88.21%  (7s)
#   -> new best (60.28%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 15/30] lr=7.16e-05  train=2.5675  val=1.8306  top1=62.32%  top5=88.65%  (7s)
#   -> new best (62.32%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 16/30] lr=6.58e-05  train=2.5379  val=1.7836  top1=62.41%  top5=89.10%  (7s)
#   -> new best (62.41%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 17/30] lr=5.98e-05  train=2.4927  val=1.7651  top1=62.06%  top5=89.72%  (7s)
# [ 18/30] lr=5.36e-05  train=2.4560  val=1.7180  top1=62.85%  top5=89.80%  (7s)
#   -> new best (62.85%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 19/30] lr=4.74e-05  train=2.3539  val=1.6304  top1=64.36%  top5=90.16%  (7s)
#   -> new best (64.36%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 20/30] lr=4.12e-05  train=2.3859  val=1.6196  top1=63.92%  top5=89.89%  (7s)
# [ 21/30] lr=3.52e-05  train=2.4274  val=1.6666  top1=64.54%  top5=90.16%  (7s)
#   -> new best (64.54%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 22/30] lr=2.94e-05  train=2.3478  val=1.6399  top1=64.80%  top5=90.16%  (7s)
#   -> new best (64.80%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 23/30] lr=2.40e-05  train=2.4091  val=1.6558  top1=64.72%  top5=90.78%  (7s)
# [ 24/30] lr=1.89e-05  train=2.3480  val=1.6101  top1=64.98%  top5=90.78%  (7s)
#   -> new best (64.98%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 25/30] lr=1.44e-05  train=2.3103  val=1.5662  top1=65.51%  top5=90.43%  (7s)
#   -> new best (65.51%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 26/30] lr=1.05e-05  train=2.3829  val=1.5812  top1=65.07%  top5=91.22%  (7s)
# [ 27/30] lr=7.12e-06  train=2.4078  val=1.6300  top1=64.98%  top5=90.34%  (7s)
# [ 28/30] lr=4.48e-06  train=2.3109  val=1.5702  top1=65.69%  top5=90.43%  (7s)
#   -> new best (65.69%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 29/30] lr=2.56e-06  train=2.3678  val=1.6083  top1=65.16%  top5=90.43%  (7s)
# [ 30/30] lr=1.39e-06  train=2.3478  val=1.5278  top1=65.69%  top5=91.13%  (7s)
#
# Done.  Best val top-1: 65.69%
# Log  : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#
# === Finished shvit_s4 ===
#
#
# ============================================================
# Training shvit_s3  (wd=0.035)
# ============================================================
# Model: shvit_s3   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s3.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 13,817,376
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.8552  val=3.8383  top1=2.66%  top5=14.36%  (51s)
#   -> new best (2.66%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  2/30] lr=4.00e-05  train=3.8300  val=3.7784  top1=7.27%  top5=23.40%  (6s)
#   -> new best (7.27%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  3/30] lr=6.00e-05  train=3.7788  val=3.6848  top1=15.43%  top5=39.89%  (7s)
#   -> new best (15.43%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  4/30] lr=8.00e-05  train=3.6921  val=3.5458  top1=28.19%  top5=58.24%  (7s)
#   -> new best (28.19%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  5/30] lr=1.00e-04  train=3.5713  val=3.3648  top1=37.41%  top5=68.00%  (7s)
#   -> new best (37.41%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  6/30] lr=1.00e-04  train=3.4515  val=3.1459  top1=44.50%  top5=75.09%  (6s)
#   -> new best (44.50%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  7/30] lr=9.96e-05  train=3.3122  val=2.8754  top1=48.85%  top5=78.55%  (7s)
#   -> new best (48.85%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  8/30] lr=9.84e-05  train=3.2222  val=2.6347  top1=51.77%  top5=80.14%  (6s)
#   -> new best (51.77%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  9/30] lr=9.65e-05  train=3.0173  val=2.3772  top1=53.81%  top5=83.07%  (7s)
#   -> new best (53.81%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 10/30] lr=9.39e-05  train=2.9620  val=2.2608  top1=54.61%  top5=84.57%  (6s)
#   -> new best (54.61%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 11/30] lr=9.05e-05  train=2.7773  val=2.1085  top1=57.00%  top5=85.82%  (7s)
#   -> new best (57.00%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 12/30] lr=8.66e-05  train=2.7422  val=1.9921  top1=58.87%  top5=86.52%  (6s)
#   -> new best (58.87%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 13/30] lr=8.21e-05  train=2.7369  val=1.9449  top1=59.31%  top5=88.03%  (7s)
#   -> new best (59.31%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 14/30] lr=7.70e-05  train=2.6468  val=1.8501  top1=60.82%  top5=88.03%  (7s)
#   -> new best (60.82%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 15/30] lr=7.16e-05  train=2.5609  val=1.7543  top1=62.15%  top5=89.27%  (7s)
#   -> new best (62.15%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 16/30] lr=6.58e-05  train=2.5234  val=1.7379  top1=62.50%  top5=89.18%  (7s)
#   -> new best (62.50%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 17/30] lr=5.98e-05  train=2.4667  val=1.7304  top1=62.32%  top5=88.92%  (7s)
# [ 18/30] lr=5.36e-05  train=2.4945  val=1.6836  top1=63.83%  top5=89.72%  (7s)
#   -> new best (63.83%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 19/30] lr=4.74e-05  train=2.3173  val=1.6226  top1=64.10%  top5=89.89%  (7s)
#   -> new best (64.10%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 20/30] lr=4.12e-05  train=2.3465  val=1.6097  top1=64.72%  top5=90.34%  (7s)
#   -> new best (64.72%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 21/30] lr=3.52e-05  train=2.4415  val=1.6477  top1=63.56%  top5=90.34%  (7s)
# [ 22/30] lr=2.94e-05  train=2.2995  val=1.6137  top1=64.80%  top5=90.43%  (7s)
#   -> new best (64.80%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 23/30] lr=2.40e-05  train=2.3692  val=1.6375  top1=64.72%  top5=90.60%  (7s)
# [ 24/30] lr=1.89e-05  train=2.3318  val=1.5961  top1=65.51%  top5=90.69%  (7s)
#   -> new best (65.51%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 25/30] lr=1.44e-05  train=2.2830  val=1.5713  top1=66.31%  top5=91.13%  (7s)
#   -> new best (66.31%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 26/30] lr=1.05e-05  train=2.3565  val=1.5819  top1=66.31%  top5=90.60%  (6s)
# [ 27/30] lr=7.12e-06  train=2.4045  val=1.6087  top1=65.43%  top5=90.87%  (7s)
# [ 28/30] lr=4.48e-06  train=2.3107  val=1.5573  top1=65.78%  top5=91.31%  (6s)
# [ 29/30] lr=2.56e-06  train=2.3415  val=1.5821  top1=66.67%  top5=90.60%  (7s)
#   -> new best (66.67%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 30/30] lr=1.39e-06  train=2.3263  val=1.5211  top1=66.31%  top5=90.96%  (6s)
#
# Done.  Best val top-1: 66.67%
# Log  : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#
# === Finished shvit_s3 ===
#
#
# ============================================================
# Training shvit_s2  (wd=0.032)
# ============================================================
# Model: shvit_s2   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s2.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 11,055,175
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.8499  val=3.8319  top1=3.37%  top5=13.12%  (53s)
#   -> new best (3.37%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  2/30] lr=4.00e-05  train=3.8194  val=3.7723  top1=6.74%  top5=23.32%  (6s)
#   -> new best (6.74%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  3/30] lr=6.00e-05  train=3.7741  val=3.6863  top1=13.21%  top5=38.65%  (7s)
#   -> new best (13.21%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  4/30] lr=8.00e-05  train=3.7071  val=3.5529  top1=26.51%  top5=57.80%  (6s)
#   -> new best (26.51%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  5/30] lr=1.00e-04  train=3.5802  val=3.3362  top1=39.63%  top5=71.37%  (6s)
#   -> new best (39.63%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  6/30] lr=1.00e-04  train=3.4493  val=3.1461  top1=45.92%  top5=76.33%  (6s)
#   -> new best (45.92%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  7/30] lr=9.96e-05  train=3.3192  val=2.8671  top1=49.65%  top5=81.38%  (6s)
#   -> new best (49.65%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  8/30] lr=9.84e-05  train=3.2145  val=2.6547  top1=52.39%  top5=83.33%  (7s)
#   -> new best (52.39%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  9/30] lr=9.65e-05  train=3.0577  val=2.4911  top1=54.34%  top5=84.49%  (6s)
#   -> new best (54.34%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 10/30] lr=9.39e-05  train=3.0140  val=2.3623  top1=56.21%  top5=84.49%  (6s)
#   -> new best (56.21%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 11/30] lr=9.05e-05  train=2.8308  val=2.2073  top1=57.00%  top5=85.64%  (6s)
#   -> new best (57.00%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 12/30] lr=8.66e-05  train=2.7874  val=2.0859  top1=59.04%  top5=86.79%  (7s)
#   -> new best (59.04%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 13/30] lr=8.21e-05  train=2.7772  val=2.0240  top1=60.11%  top5=87.68%  (6s)
#   -> new best (60.11%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 14/30] lr=7.70e-05  train=2.6969  val=1.9176  top1=60.82%  top5=87.85%  (7s)
#   -> new best (60.82%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 15/30] lr=7.16e-05  train=2.6037  val=1.8527  top1=61.35%  top5=88.21%  (6s)
#   -> new best (61.35%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 16/30] lr=6.58e-05  train=2.5688  val=1.7801  top1=61.97%  top5=88.12%  (7s)
#   -> new best (61.97%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 17/30] lr=5.98e-05  train=2.5482  val=1.7562  top1=63.03%  top5=89.27%  (6s)
#   -> new best (63.03%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 18/30] lr=5.36e-05  train=2.5494  val=1.7401  top1=63.48%  top5=89.10%  (6s)
#   -> new best (63.48%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 19/30] lr=4.74e-05  train=2.4000  val=1.6896  top1=63.65%  top5=89.72%  (6s)
#   -> new best (63.65%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 20/30] lr=4.12e-05  train=2.4358  val=1.6722  top1=64.18%  top5=90.07%  (7s)
#   -> new best (64.18%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 21/30] lr=3.52e-05  train=2.4858  val=1.6781  top1=63.74%  top5=90.16%  (6s)
# [ 22/30] lr=2.94e-05  train=2.3851  val=1.6622  top1=65.07%  top5=91.22%  (7s)
#   -> new best (65.07%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 23/30] lr=2.40e-05  train=2.4662  val=1.6565  top1=64.98%  top5=90.51%  (6s)
# [ 24/30] lr=1.89e-05  train=2.4112  val=1.6494  top1=65.60%  top5=90.78%  (7s)
#   -> new best (65.60%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 25/30] lr=1.44e-05  train=2.3686  val=1.6116  top1=65.16%  top5=90.87%  (6s)
# [ 26/30] lr=1.05e-05  train=2.4256  val=1.6329  top1=65.60%  top5=90.60%  (7s)
# [ 27/30] lr=7.12e-06  train=2.4770  val=1.6547  top1=65.69%  top5=90.34%  (6s)
#   -> new best (65.69%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 28/30] lr=4.48e-06  train=2.3803  val=1.6258  top1=65.25%  top5=90.78%  (7s)
# [ 29/30] lr=2.56e-06  train=2.4260  val=1.6215  top1=65.60%  top5=90.78%  (6s)
# [ 30/30] lr=1.39e-06  train=2.3904  val=1.5889  top1=64.80%  top5=91.05%  (7s)
#
# Done.  Best val top-1: 65.69%
# Log  : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#
# === Finished shvit_s2 ===
#
#
# ============================================================
# Training shvit_s1  (wd=0.025)
# ============================================================
# Model: shvit_s1   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s1.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 6,024,895
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.8501  val=3.8312  top1=4.08%  top5=14.98%  (51s)
#   -> new best (4.08%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  2/30] lr=4.00e-05  train=3.8279  val=3.7851  top1=6.91%  top5=21.99%  (6s)
#   -> new best (6.91%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  3/30] lr=6.00e-05  train=3.7982  val=3.7300  top1=10.90%  top5=31.21%  (7s)
#   -> new best (10.90%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  4/30] lr=8.00e-05  train=3.7566  val=3.6423  top1=17.29%  top5=42.64%  (6s)
#   -> new best (17.29%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  5/30] lr=1.00e-04  train=3.6910  val=3.5324  top1=24.91%  top5=53.55%  (7s)
#   -> new best (24.91%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  6/30] lr=1.00e-04  train=3.6220  val=3.4056  top1=31.29%  top5=59.66%  (6s)
#   -> new best (31.29%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  7/30] lr=9.96e-05  train=3.5318  val=3.2474  top1=38.03%  top5=68.53%  (7s)
#   -> new best (38.03%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  8/30] lr=9.84e-05  train=3.4704  val=3.0666  top1=39.89%  top5=71.10%  (6s)
#   -> new best (39.89%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  9/30] lr=9.65e-05  train=3.3331  val=2.9256  top1=43.26%  top5=74.02%  (7s)
#   -> new best (43.26%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 10/30] lr=9.39e-05  train=3.3032  val=2.7849  top1=46.63%  top5=77.48%  (6s)
#   -> new best (46.63%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 11/30] lr=9.05e-05  train=3.1384  val=2.6310  top1=49.11%  top5=79.61%  (7s)
#   -> new best (49.11%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 12/30] lr=8.66e-05  train=3.0894  val=2.5043  top1=50.71%  top5=81.74%  (6s)
#   -> new best (50.71%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 13/30] lr=8.21e-05  train=3.0438  val=2.3935  top1=51.60%  top5=82.80%  (6s)
#   -> new best (51.60%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 14/30] lr=7.70e-05  train=2.9499  val=2.2832  top1=53.81%  top5=83.95%  (6s)
#   -> new best (53.81%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 15/30] lr=7.16e-05  train=2.8596  val=2.1809  top1=54.96%  top5=85.11%  (7s)
#   -> new best (54.96%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 16/30] lr=6.58e-05  train=2.8026  val=2.1248  top1=55.85%  top5=85.02%  (7s)
#   -> new best (55.85%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 17/30] lr=5.98e-05  train=2.7692  val=2.0705  top1=57.00%  top5=86.17%  (7s)
#   -> new best (57.00%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 18/30] lr=5.36e-05  train=2.7479  val=2.0173  top1=56.56%  top5=86.97%  (6s)
# [ 19/30] lr=4.74e-05  train=2.6414  val=1.9714  top1=57.36%  top5=86.44%  (6s)
#   -> new best (57.36%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 20/30] lr=4.12e-05  train=2.6296  val=1.9375  top1=57.89%  top5=87.15%  (6s)
#   -> new best (57.89%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 21/30] lr=3.52e-05  train=2.6879  val=1.9179  top1=58.07%  top5=87.23%  (7s)
#   -> new best (58.07%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 22/30] lr=2.94e-05  train=2.6001  val=1.9140  top1=57.89%  top5=87.68%  (6s)
# [ 23/30] lr=2.40e-05  train=2.6563  val=1.9060  top1=58.42%  top5=87.41%  (7s)
#   -> new best (58.42%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 24/30] lr=1.89e-05  train=2.6093  val=1.8913  top1=58.95%  top5=88.03%  (6s)
#   -> new best (58.95%), saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 25/30] lr=1.44e-05  train=2.5854  val=1.8679  top1=57.80%  top5=88.12%  (7s)
# [ 26/30] lr=1.05e-05  train=2.6579  val=1.8747  top1=58.51%  top5=87.68%  (6s)
# [ 27/30] lr=7.12e-06  train=2.6547  val=1.8735  top1=58.24%  top5=87.68%  (7s)
# [ 28/30] lr=4.48e-06  train=2.5921  val=1.8619  top1=58.69%  top5=88.21%  (6s)
# [ 29/30] lr=2.56e-06  train=2.6287  val=1.8703  top1=58.60%  top5=87.50%  (7s)
# [ 30/30] lr=1.39e-06  train=2.6060  val=1.8407  top1=57.98%  top5=88.03%  (7s)
#
# Done.  Best val top-1: 58.95%
# Log  : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#
# === Finished shvit_s1 ===
#
# All 4 SHViT variants done.

# %%
# Resume from a checkpoint if the session was interrupted
# !python /content/finetune_shvit_dtd.py \
#     --shvit-dir  /content/SHViT \
#     --data-root  {DATA_ROOT} \
#     --output-dir "{OUTPUT_DIR}/shvit_s4" \
#     --resume     "{OUTPUT_DIR}/shvit_s4/checkpoint_010.pth" \
#     --epochs 30 \
#     --batch-size 64 \
#     --lr 1e-4 \
#     --num-workers 8

# %%
import os, urllib.request

# Recovery cell for the SHViT pretrained weights (shvit_s1..s4).
# Re-downloads ONLY variants whose file is missing or truncated (the
# original failure mode was a 0-byte file; genuine checkpoints are
# 100-300 MB, so anything under 100 MB is treated as broken).
#
# Side-effect: populates MODELS_TO_REDO with every variant we actually had
# to recover, so the next cell only retrains those. A healthy file leaves
# MODELS_TO_REDO empty, making the retrain cell a no-op.
MODELS_TO_REDO = []
MIN_VALID_MB = 100  # genuine file is ~229 MB

def _recover(model_name):
    path = f'{WEIGHTS_DIR}/{model_name}.pth'
    url  = f'https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth'

    if os.path.exists(path):
        size_mb = os.path.getsize(path) / 1e6
        if size_mb >= MIN_VALID_MB:
            print(f'{model_name}.pth looks healthy ({size_mb:.2f} MB) - skipping recovery.')
            return False
        print(f'{model_name}.pth looks broken ({size_mb:.2f} MB) - re-downloading.')
        os.remove(path)
    else:
        print(f'{model_name}.pth not found - downloading.')

    os.makedirs(WEIGHTS_DIR, exist_ok=True)
    print(f'  from {url}')
    urllib.request.urlretrieve(url, path)
    print(f'  done: {os.path.getsize(path)/1e6:.2f} MB')
    return True

# Check all four SHViT variants
for _name in ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']:
    if _recover(_name):
        MODELS_TO_REDO.append(_name)

print('\nMODELS_TO_REDO =', MODELS_TO_REDO)
# Out:
# shvit_s1.pth looks healthy (102.12 MB) - skipping recovery.
# shvit_s2.pth looks healthy (184.67 MB) - skipping recovery.
# shvit_s3.pth looks healthy (229.01 MB) - skipping recovery.
# shvit_s4.pth looks healthy (266.73 MB) - skipping recovery.
#
# MODELS_TO_REDO = []

# %%
# Retrain every variant that the recovery cell (Cell 15) actually had to
# re-download. If MODELS_TO_REDO is empty, nothing happens.
if not MODELS_TO_REDO:
    print('No variants need retraining (MODELS_TO_REDO is empty).')

for model_name in MODELS_TO_REDO:
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'

    # !python /content/finetune_shvit_food101.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir {model_output_dir} \
        --split-file /content/train_val_split_seed42.json \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8
# Out:
# No variants need retraining (MODELS_TO_REDO is empty).

# %% [markdown]
# ## 5. Evaluate the best checkpoint

# %%
MODEL = 'shvit_s4'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_dtd.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s4   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 16,160,587
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 65.69%   top-5: 90.43%

# %%
MODEL = 'shvit_s3'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_dtd.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s3   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 13,817,376
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 66.67%   top-5: 90.60%

# %%
MODEL = 'shvit_s2'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_dtd.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s2   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 11,055,175
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 65.69%   top-5: 90.34%

# %%
MODEL = 'shvit_s1'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_dtd.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s1   Device: cuda
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 6,024,895
# /content/finetune_shvit_dtd.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_dtd.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 58.95%   top-5: 88.03%

# %% [markdown]
# ## 6. Plot training curves

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

MODELS = ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']
COLORS = {'shvit_s1': 'tab:blue', 'shvit_s2': 'tab:orange',
          'shvit_s3': 'tab:green', 'shvit_s4': 'tab:red'}

fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))

summary = []
for model_name in MODELS:
    csv_path = f'{OUTPUT_DIR}/{model_name}/training_log.csv'
    if not os.path.exists(csv_path):
        print(f'[skip] no log for {model_name}')
        continue

    df = pd.read_csv(csv_path)
    color = COLORS[model_name]

    axes[0].plot(df['epoch'], df['train_loss'], label=f'{model_name} train', color=color)
    axes[0].plot(df['epoch'], df['val_loss'],   label=f'{model_name} val',
                 color=color, linestyle='--', alpha=0.7)

    axes[1].plot(df['epoch'], df['val_top1'] * 100, label=f'{model_name} top-1', color=color)
    axes[1].plot(df['epoch'], df['val_top5'] * 100, label=f'{model_name} top-5',
                 color=color, linestyle='--', alpha=0.7)

    axes[2].plot(df['epoch'], df['lr'].astype(float), label=model_name, color=color)

    best = df.loc[df['val_top1'].idxmax()]
    summary.append((model_name, best['val_top1']*100, best['val_top5']*100, int(best['epoch'])))

axes[0].set_title('Loss');           axes[0].set_xlabel('epoch')
axes[0].legend(fontsize=8, ncol=2);  axes[0].grid(True)

axes[1].set_title('Val Accuracy (%)'); axes[1].set_xlabel('epoch')
axes[1].legend(fontsize=8, ncol=2);    axes[1].grid(True)

axes[2].set_title('Learning Rate');    axes[2].set_xlabel('epoch')
axes[2].set_yscale('log');             axes[2].legend(fontsize=8); axes[2].grid(True)

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/training_curves_all.png', dpi=120)
plt.show()

print('\nBest val accuracy per model:')
print(f'{"model":<12} {"top-1":>8} {"top-5":>8} {"epoch":>6}')
for name, t1, t5, ep in summary:
    print(f'{name:<12} {t1:>7.2f}% {t5:>7.2f}% {ep:>6}')
# Out:
# Best val accuracy per model:
# model           top-1    top-5  epoch
# shvit_s1       58.95%   88.03%     24
# shvit_s2       65.69%   90.34%     27
# shvit_s3       66.67%   90.60%     29
# shvit_s4       65.69%   90.43%     28

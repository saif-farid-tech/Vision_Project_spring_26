# %% [markdown]
# # Stage 2 — ResNet-50 & MobileNetV2 baselines on DTD
#
# Fine-tunes two ImageNet-pretrained baselines on DTD for comparison
# with SHViT. Data preprocessing follows Tip-Adapter (`splits.py`,
# CLIP normalization, bicubic resize).
#
# **Setup:** `Runtime → Change runtime type → T4 GPU` before running.
#
# Per model, the training script writes
# `<output-root>/Stage 2: baseline models/<model>/{training_log.csv, best.pth}`.
# By default the output root is `/content/CV_Research_Paper_DTD`.

# %% [markdown]
# ## 0. Verify GPU

# %%
import torch
print('PyTorch     :', torch.__version__)
print('CUDA avail  :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU         :', torch.cuda.get_device_name(0))
# Out:
# PyTorch     : 2.11.0+cu128
# CUDA avail  : True
# GPU         : NVIDIA A100-SXM4-40GB

# %% [markdown]
# ## 1. (Optional) Mount Drive
#
# Persist the dataset and checkpoints across Colab sessions.

# %%
USE_DRIVE = True

OUT_ROOT = '/content/CV_Research_Paper_DTD'

if USE_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_ROOT = '/content/drive/MyDrive/dtd_data'
    OUT_ROOT  = '/content/drive/MyDrive/CV_Research_Paper_DTD'
else:
    DATA_ROOT = '/content/dtd_data'

OUTPUT_DIR = f'{OUT_ROOT}/Stage 2: baseline models'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)

print('Dataset    :', DATA_ROOT)
print('Output root:', OUT_ROOT)
print('Checkpoints:', OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Dataset    : /content/drive/MyDrive/dtd_data
# Output root: /content/drive/MyDrive/CV_Research_Paper_DTD
# Checkpoints: /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models

# %%
# Optional: copy the dataset to local SSD for faster I/O.
# DTD is small (~150 MB), so this is usually quick.
import shutil, os, time

src = '/content/drive/MyDrive/dtd_data'
dst = '/content/dtd_local'

if USE_DRIVE and not os.path.exists(dst) and os.path.isdir(src):
    print('Copying dataset to local SSD...')
    t0 = time.time()
    shutil.copytree(src, dst)
    print(f'done in {time.time()-t0:.0f}s')
    DATA_ROOT = dst
elif os.path.exists(dst):
    DATA_ROOT = dst
print('DATA_ROOT now:', DATA_ROOT)
# Out:
# Copying dataset to local SSD...
# done in 0s
# DATA_ROOT now: /content/dtd_local

# %% [markdown]
# ## 2. Get the training script + dataset utilities
#
# Clones the project repo to pick up `train_baseline.py`, the Tip-Adapter
# `datasets/` package, and `prepare_dtd.py`.

# %%
import os, shutil

REPO_DIR = '/content/Vision_Project_spring_26'
if not os.path.isdir(REPO_DIR):
    # !git clone -b Vision_Project_spring_26_DTD \
        https://github.com/saif-farid-tech/Vision_Project_spring_26.git {REPO_DIR}

for fname in [
    'Stage 2: baseline models/train_baseline.py',
    'splits.py',
    'metrics.py',
    'augmentation.py',
    'prepare_dtd.py',
]:
    shutil.copy(f'{REPO_DIR}/{fname}', f'/content/{os.path.basename(fname)}')
    print('Copied:', os.path.basename(fname))

DATASETS_DST = '/content/datasets'
if os.path.isdir(DATASETS_DST):
    shutil.rmtree(DATASETS_DST)
shutil.copytree(f'{REPO_DIR}/datasets', DATASETS_DST)
print('Vendored datasets/ package.')

# !pip install -q gdown timm
# Optional: pre-download DTD so the first training run is faster
# !python /content/prepare_dtd.py --root {DATA_ROOT}
# Out:
# Cloning into '/content/Vision_Project_spring_26'...
# remote: Enumerating objects: 920, done.
# remote: Counting objects: 100% (351/351), done.
# remote: Compressing objects: 100% (186/186), done.
# remote: Total 920 (delta 238), reused 209 (delta 160), pack-reused 569 (from 1)
# Receiving objects: 100% (920/920), 474.54 MiB | 16.45 MiB/s, done.
# Resolving deltas: 100% (481/481), done.
# Copied: train_baseline.py
# Copied: splits.py
# Copied: metrics.py
# Copied: augmentation.py
# Copied: prepare_dtd.py
# Vendored datasets/ package.
# [dtd] downloading DTD via torchvision into /content/dtd_local ...
# 100% 625M/625M [00:34<00:00, 18.3MB/s]
# [dtd] moving /content/dtd_local/dtd/dtd/images -> /content/dtd_local/dtd/images
# [dtd] trying official split download via gdown: https://drive.google.com/uc?id=1u3_QfB467jqHgNXC00UIzbLZRQCg2S7x
# Downloading...
# From: https://drive.google.com/uc?id=1u3_QfB467jqHgNXC00UIzbLZRQCg2S7x
# To: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# 100% 564k/564k [00:00<00:00, 157MB/s]
# [dtd] official split saved to /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
#
# Done. Dataset root: /content/dtd_local/dtd
#   classes : 47
#   train   : 2,820
#   val     : 1,128
#   test    : 1,692

# %% [markdown]
# ## 3. Train ResNet-50
#
# Downloads DTD on first run (the prepare cell above also pre-fetches it).

# %%
# !python /content/train_baseline.py \
    --model resnet50 \
    --data-root {DATA_ROOT} \
    --output-dir "{OUTPUT_DIR}" \
    --epochs 50 \
    --batch-size 64 \
    --lr 1e-4 \
    --num-workers 8
# Out:
# Model: resnet50   Device: cuda   Epochs: 50
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Train batches: 44   Val batches: 18
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 
  (7s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/resnet50/best.pth
# [ 30/50] lr=3.45e-05  train_loss=1.6628  val_loss=1.1615  top1=74.47%  top5=93.71%  (7s)
# [ 31/50] lr=3.16e-05  train_loss=1.5324  val_loss=1.1071  top1=72.87%  top5=93.44%  (7s)
# [ 32/50] lr=2.87e-05  train_loss=1.6671  val_loss=1.1205  top1=74.56%  top5=93.71%  (6s)
# [ 33/50] lr=2.59e-05  train_loss=1.5356  val_loss=1.1319  top1=74.56%  top5=94.15%  (7s)
# [ 34/50] lr=2.32e-05  train_loss=1.5444  val_loss=1.0733  top1=75.27%  top5=94.24%  (7s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/resnet50/best.pth
# [ 35/50] lr=2.06e-05  train_loss=1.6249  val_loss=1.0923  top1=74.65%  top5=94.06%  (6s)
# [ 36/50] lr=1.81e-05  train_loss=1.6451  val_loss=1.1636  top1=75.18%  top5=93.97%  (7s)
# [ 37/50] lr=1.58e-05  train_loss=1.4986  val_loss=1.0527  top1=75.44%  top5=94.24%  (6s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/resnet50/best.pth
# [ 38/50] lr=1.36e-05  train_loss=1.5856  val_loss=1.0954  top1=74.91%  top5=94.15%  (6s)
# [ 39/50] lr=1.15e-05  train_loss=1.7489  val_loss=1.1698  top1=74.91%  top5=93.53%  (7s)
# [ 40/50] lr=9.55e-06  train_loss=1.6912  val_loss=1.1086  top1=75.35%  top5=94.06%  (7s)
# [ 41/50] lr=7.78e-06  train_loss=1.5213  val_loss=1.0664  top1=75.00%  top5=93.88%  (7s)
# [ 42/50] lr=6.18e-06  train_loss=1.5940  val_loss=1.1113  top1=75.18%  top5=93.79%  (6s)
# [ 43/50] lr=4.76e-06  train_loss=1.5194  val_loss=1.0951  top1=74.91%  top5=94.06%  (6s)
# [ 44/50] lr=3.51e-06  train_loss=1.5819  val_loss=1.0787  top1=75.18%  top5=93.62%  (6s)
# [ 45/50] lr=2.45e-06  train_loss=1.6669  val_loss=1.1729  top1=74.65%  top5=93.79%  (6s)
# [ 46/50] lr=1.57e-06  train_loss=1.5579  val_loss=1.0796  top1=75.09%  top5=94.33%  (6s)
# [ 47/50] lr=8.86e-07  train_loss=1.5526  val_loss=1.0967  top1=75.98%  top5=94.24%  (7s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/resnet50/best.pth
# [ 48/50] lr=3.94e-07  train_loss=1.6416  val_loss=1.1193  top1=75.27%  top5=94.06%  (7s)
# [ 49/50] lr=9.87e-08  train_loss=1.5284  val_loss=1.0830  top1=75.18%  top5=94.24%  (6s)
# [ 50/50] lr=0.00e+00  train_loss=1.6066  val_loss=1.1345  top1=75.09%  top5=93.88%  (6s)
#
# Done. Best val top-1: 75.98%
# Log:  /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/resnet50/training_log.csv
# Ckpt: /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/resnet50/best.pth

# %% [markdown]
# ## 4. Train MobileNetV2

# %%
# !python /content/train_baseline.py \
    --model mobilenet_v2 \
    --data-root {DATA_ROOT} \
    --output-dir "{OUTPUT_DIR}" \
    --epochs 50 \
    --batch-size 64 \
    --lr 1e-4 \
    --num-workers 8
# Out:
# Model: mobilenet_v2   Device: cuda   Epochs: 50
# [dtd] images already present: /content/dtd_local/dtd/images
# [dtd] split already present: /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# Reading split from /content/dtd_local/dtd/split_zhou_DescribableTextures.json
# DTD split: 2,820 train  1,128 val
# Train batches: 44   Val batches: 18
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-7ebf99e0.pth
# 100% 13.6M/13.6M [00:00<00:00, 66.6MB/s]
# /content/train_baseline.py:175: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/train_baseline.py:124: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/50] lr=9.99e-05  train_loss=3.8000  val_loss=3.6146  top1=22.52%  top5=48.40%  (12s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/mobilenet_v2/best.pth
# [  2/50] lr=9.96e-05  train_loss=3.5778  val_loss=3.1456  top1=41.67%  top5=72.07%  (6s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/mobilenet_v2/best.pth
# [
  (6s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/mobilenet_v2/best.pth
# [ 31/50] lr=3.16e-05  train_loss=2.1295  val_loss=1.3232  top1=68.97%  top5=92.29%  (6s)
# [ 32/50] lr=2.87e-05  train_loss=2.1521  val_loss=1.2997  top1=68.79%  top5=92.73%  (6s)
# [ 33/50] lr=2.59e-05  train_loss=2.2161  val_loss=1.3814  top1=68.35%  top5=92.29%  (6s)
# [ 34/50] lr=2.32e-05  train_loss=2.1714  val_loss=1.3525  top1=68.79%  top5=92.29%  (6s)
# [ 35/50] lr=2.06e-05  train_loss=2.0961  val_loss=1.3660  top1=68.17%  top5=92.46%  (6s)
# [ 36/50] lr=1.81e-05  train_loss=2.1939  val_loss=1.3465  top1=68.88%  top5=92.64%  (6s)
# [ 37/50] lr=1.58e-05  train_loss=2.0756  val_loss=1.2948  top1=69.41%  top5=92.46%  (6s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/mobilenet_v2/best.pth
# [ 38/50] lr=1.36e-05  train_loss=2.1701  val_loss=1.3059  top1=68.88%  top5=92.55%  (6s)
# [ 39/50] lr=1.15e-05  train_loss=2.1790  val_loss=1.3202  top1=69.24%  top5=92.82%  (6s)
# [ 40/50] lr=9.55e-06  train_loss=2.0201  val_loss=1.3056  top1=69.41%  top5=92.55%  (6s)
# [ 41/50] lr=7.78e-06  train_loss=2.1601  val_loss=1.3464  top1=68.71%  top5=92.64%  (6s)
# [ 42/50] lr=6.18e-06  train_loss=2.1261  val_loss=1.3636  top1=69.50%  top5=93.09%  (6s)
#   -> new best, saved to /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/mobilenet_v2/best.pth
# [ 43/50] lr=4.76e-06  train_loss=2.1790  val_loss=1.3460  top1=68.79%  top5=92.91%  (6s)
# [ 44/50] lr=3.51e-06  train_loss=2.1541  val_loss=1.3722  top1=68.79%  top5=92.82%  (6s)
# [ 45/50] lr=2.45e-06  train_loss=2.1851  val_loss=1.3142  top1=68.71%  top5=92.46%  (6s)
# [ 46/50] lr=1.57e-06  train_loss=2.1178  val_loss=1.3201  top1=69.06%  top5=92.82%  (6s)
# [ 47/50] lr=8.86e-07  train_loss=2.1768  val_loss=1.3399  top1=68.88%  top5=92.64%  (6s)
# [ 48/50] lr=3.94e-07  train_loss=2.2015  val_loss=1.3215  top1=69.33%  top5=93.00%  (6s)
# [ 49/50] lr=9.87e-08  train_loss=2.1584  val_loss=1.3438  top1=69.15%  top5=92.82%  (6s)
# [ 50/50] lr=0.00e+00  train_loss=2.1936  val_loss=1.3279  top1=68.97%  top5=92.55%  (6s)
#
# Done. Best val top-1: 69.50%
# Log:  /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/mobilenet_v2/training_log.csv
# Ckpt: /content/drive/MyDrive/CV_Research_Paper_DTD/Stage 2: baseline models/mobilenet_v2/best.pth

# %% [markdown]
# ## 5. Inspect logs

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
for model_name in ['resnet50', 'mobilenet_v2']:
    csv_path = f'{OUTPUT_DIR}/{model_name}/training_log.csv'
    if not os.path.exists(csv_path):
        continue
    df = pd.read_csv(csv_path)
    axes[0].plot(df['epoch'], df['train_loss'], label=f'{model_name} train')
    axes[0].plot(df['epoch'], df['val_loss'],   label=f'{model_name} val', linestyle='--')
    axes[1].plot(df['epoch'], df['val_top1'] * 100, label=f'{model_name} top-1')
    axes[1].plot(df['epoch'], df['val_top5'] * 100, label=f'{model_name} top-5', linestyle='--')
    print(f'{model_name}: best val top-1 = {df["val_top1"].max()*100:.2f}%')

axes[0].set_title('Loss');     axes[0].set_xlabel('epoch'); axes[0].legend(); axes[0].grid(True)
axes[1].set_title('Accuracy (%)'); axes[1].set_xlabel('epoch'); axes[1].legend(); axes[1].grid(True)
plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/training_curves_baselines.png', dpi=120)
plt.show()
# Out:
# resnet50: best val top-1 = 75.98%
# mobilenet_v2: best val top-1 = 69.50%

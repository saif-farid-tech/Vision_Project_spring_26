# %% [markdown]
# # Stage 3 — Fine-tuning SHViT on Oxford Pets
#
# This notebook fine-tunes pretrained SHViT models (S1..S4) on Oxford Pets
# using `finetune_shvit_oxford_pets.py`. Data preprocessing follows
# Tip-Adapter (`splits.py`, CLIP normalization, bicubic resize).
#
# **Before running:** `Runtime → Change runtime type → T4 GPU`
#
# ### What this notebook does
# 1. Verifies GPU, mounts Drive (optional), prepares paths
# 2. Clones SHViT + this project repo, installs deps
# 3. Downloads SHViT pretrained weights (S1..S4)
# 4. Runs `finetune_shvit_oxford_pets.py` for each variant
# 5. Plots training curves
#
# All outputs land under `<OUT_ROOT>/Stage 3: fine-tuning SHViT/<variant>/`.

# %% [markdown]
# ## 0. GPU check

# %%
import torch
print('PyTorch :', torch.__version__)
print('CUDA    :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU     :', torch.cuda.get_device_name(0))
# Out:
# PyTorch : 2.11.0+cu128
# CUDA    : True
# GPU     : NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## 1. (Optional) Mount Drive
#
# Persist the dataset, weights, and checkpoints across sessions.

# %%
USE_DRIVE = True

OUT_ROOT = '/content/CV_Research_Paper_OxfordPets'

if USE_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_ROOT   = '/content/drive/MyDrive/oxford_pets_data'
    WEIGHTS_DIR = '/content/drive/MyDrive/shvit_weights'
    OUT_ROOT    = '/content/drive/MyDrive/CV_Research_Paper_OxfordPets'
else:
    DATA_ROOT   = '/content/oxford_pets_data'
    WEIGHTS_DIR = '/content/weights'

OUTPUT_DIR = f'{OUT_ROOT}/Stage 3: fine-tuning SHViT'
WEIGHTS_PATH = f'{WEIGHTS_DIR}/shvit_s4.pth'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)
os.makedirs(WEIGHTS_DIR, exist_ok=True)

print('Data       :', DATA_ROOT)
print('Weights    :', WEIGHTS_PATH)
print('Output root:', OUT_ROOT)
print('Output dir :', OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Data       : /content/drive/MyDrive/oxford_pets_data
# Weights    : /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# Output root: /content/drive/MyDrive/CV_Research_Paper_OxfordPets
# Output dir : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT

# %%
# Optional: copy the dataset to local SSD for faster I/O.
import shutil, os, time
src = '/content/drive/MyDrive/oxford_pets_data'
dst = '/content/oxford_pets_local'

if USE_DRIVE and not os.path.exists(dst) and os.path.isdir(src):
    print('Copying dataset to local SSD...')
    t0 = time.time()
    shutil.copytree(src, dst)
    print(f'done in {time.time()-t0:.0f}s')
    DATA_ROOT = dst
elif os.path.exists(dst):
    DATA_ROOT = dst
print('DATA_ROOT now:', DATA_ROOT)
# Out:
# Copying dataset to local SSD...
# done in 0s
# DATA_ROOT now: /content/oxford_pets_local

# %% [markdown]
# ## 2. Clone repos and install dependencies

# %%
import os, shutil

if not os.path.isdir('/content/SHViT'):
    # !git clone https://github.com/ysj9909/SHViT.git /content/SHViT

REPO = '/content/Vision_Project_spring_26'
if not os.path.isdir(REPO):
    # !git clone -b Vision_Project_spring_26_OxfordPets \
        https://github.com/saif-farid-tech/Vision_Project_spring_26.git {REPO}

for fname in [
    'Stage 3: fine-tuning SHViT/finetune_shvit_oxford_pets.py',
    'splits.py',
    'metrics.py',
    'augmentation.py',
    'prepare_oxford_pets.py',
]:
    shutil.copy(f'{REPO}/{fname}', f'/content/{os.path.basename(fname)}')
    print('Copied:', os.path.basename(fname))

DATASETS_DST = '/content/datasets'
if os.path.isdir(DATASETS_DST):
    shutil.rmtree(DATASETS_DST)
shutil.copytree(f'{REPO}/datasets', DATASETS_DST)
print('Vendored datasets/ package.')
# Out:
# Cloning into '/content/SHViT'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 183 (delta 84), reused 82 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 168.52 KiB | 8.02 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Cloning into '/content/Vision_Project_spring_26'...
# remote: Enumerating objects: 707, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 707 (delta 99), reused 103 (delta 89), pack-reused 570 (from 1)
# Receiving objects: 100% (707/707), 444.14 MiB | 41.24 MiB/s, done.
# Resolving deltas: 100% (342/342), done.
# Copied: finetune_shvit_oxford_pets.py
# Copied: splits.py
# Copied: metrics.py
# Copied: augmentation.py
# Copied: prepare_oxford_pets.py
# Vendored datasets/ package.

# %%
# Install SHViT deps (timm pinned, --no-deps so torch isn't downgraded)
# plus gdown for the optional CoOp split download.
# !pip install -q timm==0.5.4 --no-deps
# !pip install -q einops==0.4.1 easydict gdown
print('Dependencies installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 18.2 MB/s eta 0:00:00
# Dependencies installed.

# %% [markdown]
# ## 3. Download SHViT-S4 pretrained weights

# %%
os.makedirs(WEIGHTS_DIR, exist_ok=True)
if not os.path.exists(WEIGHTS_PATH):
    # !wget -q --show-progress \
        https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s4.pth \
        -O {WEIGHTS_PATH}
size_mb = os.path.getsize(WEIGHTS_PATH) / 1e6
print(f'Checkpoint: {size_mb:.1f} MB  ->  {WEIGHTS_PATH}')

# Also pre-download the Oxford Pets split + images so the first training run is fast
# !python /content/prepare_oxford_pets.py --root {DATA_ROOT}
# Out:
# Checkpoint: 266.7 MB  ->  /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# [oxford_pets] downloading Oxford-IIIT Pet via torchvision into /content/oxford_pets_local ...
# 100% 792M/792M [00:03<00:00, 236MB/s]
# 100% 19.2M/19.2M [00:00<00:00, 123MB/s]
# [oxford_pets] moving /content/oxford_pets_local/oxford-iiit-pet/images -> /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] moving /content/oxford_pets_local/oxford-iiit-pet/annotations -> /content/oxford_pets_local/oxford_pets/annotations
# [oxford_pets] trying official split download via gdown: https://drive.google.com/uc?id=1501r8Ber4nNKvmlFVQZ8SeUHTcdTTZkw
# [oxford_pets] official split download failed (Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1501r8Ber4nNKvmlFVQZ8SeUHTcdTTZkw
#
# but Gdown can't. Please check connections and permissions.); will generate locally
# [oxford_pets] generating deterministic split (seed=1)
# [oxford_pets] wrote split (37 classes, 3676 train / 1471 val / 2202 test) to /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
#
# Done. Dataset root: /content/oxford_pets_local/oxford_pets
#   classes : 37
#   train   : 3,676
#   val     : 1,471
#   test    : 2,202

# %% [markdown]
# ## 4. Fine-tune SHViT on Oxford Pets
#
# Oxford Pets is small (~800 MB, 7,349 images). Each epoch on a T4 takes
# ~30–45 seconds with batch 64 — 30 epochs ≈ 15–25 minutes per variant.

# %%
# Quick smoke-test: 2 epochs to verify everything runs
# !python /content/finetune_shvit_oxford_pets.py \
    --shvit-dir  /content/SHViT \
    --finetune   {WEIGHTS_PATH} \
    --data-root  {DATA_ROOT} \
    --output-dir "{OUTPUT_DIR}/shvit_s4_smoke" \
    --epochs 2 \
    --batch-size 64 \
    --lr 1e-4 \
    --num-workers 8
# Out:
# Model: shvit_s4   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,156,097
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 2 epochs (starting at 0)
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/2] lr=2.00e-05  train=3.6208  val=3.5825  top1=5.03%  top5=19.85%  (57s)
#   -> new best (5.03%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
# [  2/2] lr=4.00e-05  train=3.5792  val=3.4813  top1=16.86%  top5=46.16%  (8s)
#   -> new best (16.86%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
#
# Done.  Best val top-1: 16.86%
# Log  : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4_smoke/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth

# %%
# Train all 4 SHViT variants sequentially.
MODELS = ['shvit_s4', 'shvit_s3', 'shvit_s2', 'shvit_s1']

# Per-variant weight decay from the SHViT paper (Table 7).
WEIGHT_DECAY = {
    'shvit_s1': 0.025,
    'shvit_s2': 0.032,
    'shvit_s3': 0.035,
    'shvit_s4': 0.050,
}

for model_name in MODELS:
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'

    if not os.path.exists(weights_path):
        print(f'\n=== Downloading {model_name} pretrained weights ===')
        # !wget -q --show-progress \
            https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth \
            -O {weights_path}

    print(f'\n{"="*60}')
    print(f'Training {model_name}  (wd={WEIGHT_DECAY[model_name]})')
    print(f'{"="*60}')

    # !python /content/finetune_shvit_oxford_pets.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir "{model_output_dir}" \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8

    print(f'\n=== Finished {model_name} ===\n')

print('All 4 SHViT variants done.')
# Out:
# ============================================================
# Training shvit_s4  (wd=0.05)
# ============================================================
# Model: shvit_s4   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,156,097
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.6210  val=3.5817  top1=5.44%  top5=20.46%  (55s)
#   -> new best (5.44%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  2/30] lr=4.00e-05  train=3.5826  val=3.4895  top1=15.91%  top5=44.12%  (8s)
#   -> new best (15.91%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  3/30] lr=6.00e-05  train=3.5156  val=3.2919  top1=46.97%  top5=79.13%  (9s)
#   -> new best (46.97%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  4/30] lr=8.00e-05  train=3.3457  val=2.7359  top1=71.92%  top5=95.11%  (8s)
#   -> new best (71.92%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  5/30] lr=1.00e-04  train=3.0291  val=1.9633  top1=80.22%  top5=98.44%  (8s)
#   -> new best (80.22%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  6/30] lr=1.00e-04  train=2.7775  val=1.5322  top1=81.85%  top5=98.98%  (9s)
#   -> new best (81.85%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  7/30] lr=9.96e-05  train=2.5101  val=1.2413  top1=85.59%  top5=99.39%  (9s)
#   -> new best (85.59%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  8/30] lr=9.84e-05  train=2.4009  val=1.0435  top1=87.49%  top5=99.46%  (8s)
#   -> new best (87.49%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  9/30] lr=9.65e-05  train=2.2498  val=0.9465  top1=88.85%  top5=99.46%  (8s)
#   -> new best (88.85%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 10/30] lr=9.39e-05  train=2.2206  val=0.8796  top1=90.35%  top5=99.32%  (9s)
#   -> new best (90.35%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 11/30] lr=9.05e-05  train=2.1864  val=0.8413  top1=90.62%  top5=99.39%  (9s)
#   -> new best (90.62%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 12/30] lr=8.66e-05  train=2.0909  val=0.7569  top1=90.75%  top5=99.59%  (8s)
#   -> new best (90.75%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 13/30] lr=8.21e-05  train=2.0482  val=0.8167  top1=91.43%  top5=99.39%  (9s)
#   -> new best (91.43%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 14/30] lr=7.70e-05  train=2.0555  val=0.7130  top1=91.09%  top5=99.52%  (8s)
# [ 15/30] lr=7.16e-05  train=1.9098  val=0.6630  top1=91.77%  top5=99.59%  (8s)
#   -> new best (91.77%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 16/30] lr=6.58e-05  train=1.9520  val=0.6487  top1=91.64%  top5=99.66%  (9s)
# [ 17/30] lr=5.98e-05  train=1.9769  val=0.7110  top1=91.57%  top5=99.46%  (9s)
# [ 18/30] lr=5.36e-05  train=1.9553  val=0.6155  top1=91.57%  top5=99.59%  (8s)
# [ 19/30] lr=4.74e-05  train=1.9810  val=0.7035  top1=91.16%  top5=99.59%  (8s)
# [ 20/30] lr=4.12e-05  train=1.9548  val=0.6609  top1=91.30%  top5=99.52%  (8s)
# [ 21/30] lr=3.52e-05  train=1.9795  val=0.6550  top1=91.71%  top5=99.59%  (8s)
# [ 22/30] lr=2.94e-05  train=1.9070  val=0.6168  top1=91.71%  top5=99.66%  (9s)
# [ 23/30] lr=2.40e-05  train=1.9846  val=0.5866  top1=92.11%  top5=99.59%  (8s)
#   -> new best (92.11%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 24/30] lr=1.89e-05  train=1.9640  val=0.7213  top1=91.37%  top5=99.46%  (8s)
# [ 25/30] lr=1.44e-05  train=1.9759  val=0.6410  top1=91.64%  top5=99.66%  (9s)
# [ 26/30] lr=1.05e-05  train=1.8753  val=0.5593  top1=92.45%  top5=99.66%  (8s)
#   -> new best (92.45%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 27/30] lr=7.12e-06  train=1.8849  val=0.6399  top1=91.98%  top5=99.66%  (8s)
# [ 28/30] lr=4.48e-06  train=1.8484  val=0.6456  top1=92.25%  top5=99.59%  (8s)
# [ 29/30] lr=2.56e-06  train=1.8986  val=0.5535  top1=92.25%  top5=99.73%  (8s)
# [ 30/30] lr=1.39e-06  train=1.8905  val=0.5944  top1=92.05%  top5=99.66%  (9s)
#
# Done.  Best val top-1: 92.45%
# Log  : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#
# === Finished shvit_s4 ===
#
#
# ============================================================
# Training shvit_s3  (wd=0.035)
# ============================================================
# Model: shvit_s3   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s3.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 13,812,886
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.6197  val=3.5703  top1=4.62%  top5=22.84%  (53s)
#   -> new best (4.62%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  2/30] lr=4.00e-05  train=3.5759  val=3.4469  top1=16.52%  top5=48.61%  (8s)
#   -> new best (16.52%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  3/30] lr=6.00e-05  train=3.4990  val=3.2458  top1=43.78%  top5=75.73%  (8s)
#   -> new best (43.78%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  4/30] lr=8.00e-05  train=3.3433  val=2.7775  top1=68.12%  top5=92.52%  (8s)
#   -> new best (68.12%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  5/30] lr=1.00e-04  train=3.0192  val=1.9056  top1=79.40%  top5=98.16%  (8s)
#   -> new best (79.40%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  6/30] lr=1.00e-04  train=2.7515  val=1.4815  top1=82.12%  top5=99.05%  (8s)
#   -> new best (82.12%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  7/30] lr=9.96e-05  train=2.4902  val=1.1674  top1=85.11%  top5=99.12%  (8s)
#   -> new best (85.11%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  8/30] lr=9.84e-05  train=2.3811  val=1.0097  top1=87.22%  top5=99.12%  (8s)
#   -> new best (87.22%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  9/30] lr=9.65e-05  train=2.2541  val=0.9288  top1=88.58%  top5=99.46%  (8s)
#   -> new best (88.58%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 10/30] lr=9.39e-05  train=2.2183  val=0.9034  top1=88.78%  top5=99.46%  (8s)
#   -> new best (88.78%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 11/30] lr=9.05e-05  train=2.2010  val=0.7982  top1=89.33%  top5=99.59%  (8s)
#   -> new best (89.33%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 12/30] lr=8.66e-05  train=2.0800  val=0.7261  top1=90.07%  top5=99.59%  (8s)
#   -> new best (90.07%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 13/30] lr=8.21e-05  train=2.0105  val=0.8183  top1=89.80%  top5=99.52%  (8s)
# [ 14/30] lr=7.70e-05  train=2.0459  val=0.6725  top1=91.16%  top5=99.59%  (8s)
#   -> new best (91.16%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 15/30] lr=7.16e-05  train=1.9273  val=0.6537  top1=91.23%  top5=99.52%  (8s)
#   -> new best (91.23%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 16/30] lr=6.58e-05  train=1.9366  val=0.6341  top1=92.39%  top5=99.59%  (8s)
#   -> new best (92.39%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 17/30] lr=5.98e-05  train=1.9760  val=0.6980  top1=91.50%  top5=99.59%  (8s)
# [ 18/30] lr=5.36e-05  train=1.9529  val=0.5881  top1=93.41%  top5=99.59%  (8s)
#   -> new best (93.41%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 19/30] lr=4.74e-05  train=1.9928  val=0.6696  top1=92.45%  top5=99.66%  (8s)
# [ 20/30] lr=4.12e-05  train=1.9507  val=0.6695  top1=92.32%  top5=99.52%  (8s)
# [ 21/30] lr=3.52e-05  train=2.0075  val=0.6463  top1=92.66%  top5=99.52%  (8s)
# [ 22/30] lr=2.94e-05  train=1.9049  val=0.6222  top1=92.73%  top5=99.59%  (8s)
# [ 23/30] lr=2.40e-05  train=2.0011  val=0.5771  top1=92.86%  top5=99.73%  (8s)
# [ 24/30] lr=1.89e-05  train=1.9514  val=0.7382  top1=92.32%  top5=99.59%  (8s)
# [ 25/30] lr=1.44e-05  train=1.9725  val=0.6501  top1=92.59%  top5=99.52%  (8s)
# [ 26/30] lr=1.05e-05  train=1.8812  val=0.5562  top1=92.93%  top5=99.66%  (8s)
# [ 27/30] lr=7.12e-06  train=1.9045  val=0.6556  top1=92.93%  top5=99.59%  (8s)
# [ 28/30] lr=4.48e-06  train=1.8362  val=0.6492  top1=92.66%  top5=99.66%  (8s)
# [ 29/30] lr=2.56e-06  train=1.8846  val=0.5331  top1=93.20%  top5=99.66%  (8s)
# [ 30/30] lr=1.39e-06  train=1.9256  val=0.5871  top1=92.73%  top5=99.66%  (8s)
#
# Done.  Best val top-1: 93.41%
# Log  : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#
# === Finished shvit_s3 ===
#
#
# ============================================================
# Training shvit_s2  (wd=0.032)
# ============================================================
# Model: shvit_s2   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s2.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 11,050,685
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.6193  val=3.5942  top1=3.87%  top5=18.15%  (55s)
#   -> new best (3.87%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  2/30] lr=4.00e-05  train=3.5709  val=3.4593  top1=12.51%  top5=40.38%  (8s)
#   -> new best (12.51%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  3/30] lr=6.00e-05  train=3.5046  val=3.2526  top1=33.11%  top5=70.56%  (8s)
#   -> new best (33.11%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  4/30] lr=8.00e-05  train=3.3394  val=2.7278  top1=63.02%  top5=93.00%  (8s)
#   -> new best (63.02%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  5/30] lr=1.00e-04  train=3.0727  val=1.9498  top1=75.73%  top5=97.35%  (8s)
#   -> new best (75.73%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  6/30] lr=1.00e-04  train=2.8215  val=1.5678  top1=80.69%  top5=98.44%  (8s)
#   -> new best (80.69%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  7/30] lr=9.96e-05  train=2.5928  val=1.3255  top1=83.41%  top5=98.57%  (7s)
#   -> new best (83.41%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  8/30] lr=9.84e-05  train=2.5256  val=1.1242  top1=86.34%  top5=98.84%  (8s)
#   -> new best (86.34%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  9/30] lr=9.65e-05  train=2.3666  val=1.0009  top1=85.66%  top5=99.18%  (7s)
# [ 10/30] lr=9.39e-05  train=2.3164  val=0.9056  top1=87.22%  top5=99.25%  (8s)
#   -> new best (87.22%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 11/30] lr=9.05e-05  train=2.2736  val=0.8545  top1=88.31%  top5=99.32%  (8s)
#   -> new best (88.31%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 12/30] lr=8.66e-05  train=2.1706  val=0.7613  top1=89.26%  top5=99.18%  (8s)
#   -> new best (89.26%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 13/30] lr=8.21e-05  train=2.1329  val=0.7957  top1=89.60%  top5=99.18%  (8s)
#   -> new best (89.60%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 14/30] lr=7.70e-05  train=2.1212  val=0.7090  top1=89.33%  top5=99.32%  (8s)
# [ 15/30] lr=7.16e-05  train=2.0019  val=0.6559  top1=89.46%  top5=99.25%  (8s)
# [ 16/30] lr=6.58e-05  train=2.0336  val=0.6700  top1=89.87%  top5=99.25%  (8s)
#   -> new best (89.87%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 17/30] lr=5.98e-05  train=2.0735  val=0.7051  top1=90.62%  top5=99.46%  (8s)
#   -> new best (90.62%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 18/30] lr=5.36e-05  train=2.0298  val=0.6129  top1=90.01%  top5=99.39%  (8s)
# [ 19/30] lr=4.74e-05  train=2.0520  val=0.6788  top1=90.62%  top5=99.46%  (8s)
# [ 20/30] lr=4.12e-05  train=2.0436  val=0.6579  top1=90.82%  top5=99.39%  (8s)
#   -> new best (90.82%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 21/30] lr=3.52e-05  train=2.0733  val=0.6525  top1=90.96%  top5=99.39%  (8s)
#   -> new best (90.96%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 22/30] lr=2.94e-05  train=2.0120  val=0.6324  top1=91.50%  top5=99.39%  (7s)
#   -> new best (91.50%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 23/30] lr=2.40e-05  train=2.0912  val=0.6113  top1=91.09%  top5=99.46%  (8s)
# [ 24/30] lr=1.89e-05  train=2.0445  val=0.7064  top1=90.96%  top5=99.39%  (7s)
# [ 25/30] lr=1.44e-05  train=2.0655  val=0.6546  top1=91.09%  top5=99.39%  (8s)
# [ 26/30] lr=1.05e-05  train=1.9470  val=0.5765  top1=91.23%  top5=99.46%  (7s)
# [ 27/30] lr=7.12e-06  train=1.9746  val=0.6732  top1=91.16%  top5=99.39%  (8s)
# [ 28/30] lr=4.48e-06  train=1.9281  val=0.6431  top1=91.37%  top5=99.52%  (7s)
# [ 29/30] lr=2.56e-06  train=1.9439  val=0.5710  top1=90.96%  top5=99.39%  (8s)
# [ 30/30] lr=1.39e-06  train=1.9947  val=0.5989  top1=91.30%  top5=99.52%  (8s)
#
# Done.  Best val top-1: 91.50%
# Log  : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#
# === Finished shvit_s2 ===
#
#
# ============================================================
# Training shvit_s1  (wd=0.025)
# ============================================================
# Model: shvit_s1   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s1.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 6,021,685
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=3.6192  val=3.6018  top1=4.01%  top5=16.66%  (54s)
#   -> new best (4.01%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  2/30] lr=4.00e-05  train=3.5889  val=3.5158  top1=9.04%  top5=26.85%  (7s)
#   -> new best (9.04%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  3/30] lr=6.00e-05  train=3.5393  val=3.3813  top1=19.24%  top5=49.35%  (8s)
#   -> new best (19.24%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  4/30] lr=8.00e-05  train=3.4484  val=3.1540  top1=38.95%  top5=79.67%  (8s)
#   -> new best (38.95%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  5/30] lr=1.00e-04  train=3.3110  val=2.6511  top1=62.34%  top5=93.54%  (8s)
#   -> new best (62.34%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  6/30] lr=1.00e-04  train=3.1224  val=2.1895  top1=67.98%  top5=96.40%  (8s)
#   -> new best (67.98%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  7/30] lr=9.96e-05  train=2.8901  val=1.8883  top1=75.39%  top5=97.89%  (8s)
#   -> new best (75.39%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  8/30] lr=9.84e-05  train=2.7877  val=1.6663  top1=78.86%  top5=98.37%  (8s)
#   -> new best (78.86%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  9/30] lr=9.65e-05  train=2.6291  val=1.4882  top1=80.01%  top5=99.05%  (8s)
#   -> new best (80.01%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 10/30] lr=9.39e-05  train=2.5699  val=1.3450  top1=83.14%  top5=98.91%  (8s)
#   -> new best (83.14%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 11/30] lr=9.05e-05  train=2.4932  val=1.2346  top1=84.64%  top5=98.84%  (8s)
#   -> new best (84.64%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 12/30] lr=8.66e-05  train=2.3731  val=1.1455  top1=86.54%  top5=98.91%  (7s)
#   -> new best (86.54%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 13/30] lr=8.21e-05  train=2.3440  val=1.0533  top1=87.02%  top5=99.05%  (7s)
#   -> new best (87.02%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 14/30] lr=7.70e-05  train=2.3090  val=0.9770  top1=87.08%  top5=99.18%  (8s)
#   -> new best (87.08%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 15/30] lr=7.16e-05  train=2.2024  val=0.9361  top1=87.56%  top5=99.18%  (8s)
#   -> new best (87.56%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 16/30] lr=6.58e-05  train=2.2136  val=0.8927  top1=88.17%  top5=98.98%  (7s)
#   -> new best (88.17%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 17/30] lr=5.98e-05  train=2.2378  val=0.8640  top1=89.06%  top5=98.98%  (8s)
#   -> new best (89.06%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 18/30] lr=5.36e-05  train=2.2096  val=0.8346  top1=89.46%  top5=99.05%  (8s)
#   -> new best (89.46%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 19/30] lr=4.74e-05  train=2.2088  val=0.8072  top1=89.33%  top5=99.12%  (8s)
# [ 20/30] lr=4.12e-05  train=2.1805  val=0.7895  top1=89.19%  top5=99.05%  (8s)
# [ 21/30] lr=3.52e-05  train=2.2327  val=0.7803  top1=89.26%  top5=99.12%  (7s)
# [ 22/30] lr=2.94e-05  train=2.1470  val=0.7600  top1=89.26%  top5=99.05%  (8s)
# [ 23/30] lr=2.40e-05  train=2.2136  val=0.7590  top1=89.94%  top5=99.18%  (8s)
#   -> new best (89.94%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 24/30] lr=1.89e-05  train=2.1841  val=0.7862  top1=89.67%  top5=99.18%  (8s)
# [ 25/30] lr=1.44e-05  train=2.1948  val=0.7502  top1=89.67%  top5=99.18%  (8s)
# [ 26/30] lr=1.05e-05  train=2.1246  val=0.7308  top1=90.01%  top5=99.18%  (8s)
#   -> new best (90.01%), saved to /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 27/30] lr=7.12e-06  train=2.1170  val=0.7460  top1=89.80%  top5=99.18%  (8s)
# [ 28/30] lr=4.48e-06  train=2.0789  val=0.7455  top1=89.87%  top5=99.18%  (8s)
# [ 29/30] lr=2.56e-06  train=2.1096  val=0.7224  top1=89.80%  top5=99.18%  (8s)
# [ 30/30] lr=1.39e-06  train=2.1015  val=0.7398  top1=89.94%  top5=99.12%  (8s)
#
# Done.  Best val top-1: 90.01%
# Log  : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#
# === Finished shvit_s1 ===
#
# All 4 SHViT variants done.

# %%
# Resume from a checkpoint if the session was interrupted
# !python /content/finetune_shvit_oxford_pets.py \
#     --shvit-dir  /content/SHViT \
#     --data-root  {DATA_ROOT} \
#     --output-dir "{OUTPUT_DIR}/shvit_s4" \
#     --resume     "{OUTPUT_DIR}/shvit_s4/checkpoint_010.pth" \
#     --epochs 30 \
#     --batch-size 64 \
#     --lr 1e-4 \
#     --num-workers 8

# %%
import os, urllib.request

# Recovery cell for the SHViT pretrained weights (shvit_s1..s4).
# Re-downloads ONLY variants whose file is missing or truncated (the
# original failure mode was a 0-byte file; genuine checkpoints are
# 100-300 MB, so anything under 100 MB is treated as broken).
#
# Side-effect: populates MODELS_TO_REDO with every variant we actually had
# to recover, so the next cell only retrains those. A healthy file leaves
# MODELS_TO_REDO empty, making the retrain cell a no-op.
MODELS_TO_REDO = []
MIN_VALID_MB = 100  # genuine file is ~229 MB

def _recover(model_name):
    path = f'{WEIGHTS_DIR}/{model_name}.pth'
    url  = f'https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth'

    if os.path.exists(path):
        size_mb = os.path.getsize(path) / 1e6
        if size_mb >= MIN_VALID_MB:
            print(f'{model_name}.pth looks healthy ({size_mb:.2f} MB) - skipping recovery.')
            return False
        print(f'{model_name}.pth looks broken ({size_mb:.2f} MB) - re-downloading.')
        os.remove(path)
    else:
        print(f'{model_name}.pth not found - downloading.')

    os.makedirs(WEIGHTS_DIR, exist_ok=True)
    print(f'  from {url}')
    urllib.request.urlretrieve(url, path)
    print(f'  done: {os.path.getsize(path)/1e6:.2f} MB')
    return True

# Check all four SHViT variants
for _name in ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']:
    if _recover(_name):
        MODELS_TO_REDO.append(_name)

print('\nMODELS_TO_REDO =', MODELS_TO_REDO)
# Out:
# shvit_s1.pth looks healthy (102.12 MB) - skipping recovery.
# shvit_s2.pth looks healthy (184.67 MB) - skipping recovery.
# shvit_s3.pth looks healthy (229.01 MB) - skipping recovery.
# shvit_s4.pth looks healthy (266.73 MB) - skipping recovery.
#
# MODELS_TO_REDO = []

# %%
# Retrain every variant that the recovery cell (Cell 15) actually had to
# re-download. If MODELS_TO_REDO is empty, nothing happens.
if not MODELS_TO_REDO:
    print('No variants need retraining (MODELS_TO_REDO is empty).')

for model_name in MODELS_TO_REDO:
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'

    # !python /content/finetune_shvit_food101.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir {model_output_dir} \
        --split-file /content/train_val_split_seed42.json \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8
# Out:
# No variants need retraining (MODELS_TO_REDO is empty).

# %% [markdown]
# ## 5. Evaluate the best checkpoint

# %%
MODEL = 'shvit_s4'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_oxford_pets.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s4   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 16,156,097
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 92.45%   top-5: 99.66%

# %%
MODEL = 'shvit_s3'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_oxford_pets.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s3   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 13,812,886
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 93.41%   top-5: 99.59%

# %%
MODEL = 'shvit_s2'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_oxford_pets.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s2   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 11,050,685
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 91.50%   top-5: 99.39%

# %%
MODEL = 'shvit_s1'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_oxford_pets.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s1   Device: cuda
# [oxford_pets] images already present: /content/oxford_pets_local/oxford_pets/images
# [oxford_pets] split already present: /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Reading split from /content/oxford_pets_local/oxford_pets/split_zhou_OxfordPets.json
# Oxford Pets split: 3,676 train  1,471 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_OxfordPets/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 6,021,685
# /content/finetune_shvit_oxford_pets.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_oxford_pets.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 90.01%   top-5: 99.18%

# %% [markdown]
# ## 6. Plot training curves

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

MODELS = ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']
COLORS = {'shvit_s1': 'tab:blue', 'shvit_s2': 'tab:orange',
          'shvit_s3': 'tab:green', 'shvit_s4': 'tab:red'}

fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))

summary = []
for model_name in MODELS:
    csv_path = f'{OUTPUT_DIR}/{model_name}/training_log.csv'
    if not os.path.exists(csv_path):
        print(f'[skip] no log for {model_name}')
        continue

    df = pd.read_csv(csv_path)
    color = COLORS[model_name]

    axes[0].plot(df['epoch'], df['train_loss'], label=f'{model_name} train', color=color)
    axes[0].plot(df['epoch'], df['val_loss'],   label=f'{model_name} val',
                 color=color, linestyle='--', alpha=0.7)

    axes[1].plot(df['epoch'], df['val_top1'] * 100, label=f'{model_name} top-1', color=color)
    axes[1].plot(df['epoch'], df['val_top5'] * 100, label=f'{model_name} top-5',
                 color=color, linestyle='--', alpha=0.7)

    axes[2].plot(df['epoch'], df['lr'].astype(float), label=model_name, color=color)

    best = df.loc[df['val_top1'].idxmax()]
    summary.append((model_name, best['val_top1']*100, best['val_top5']*100, int(best['epoch'])))

axes[0].set_title('Loss');           axes[0].set_xlabel('epoch')
axes[0].legend(fontsize=8, ncol=2);  axes[0].grid(True)

axes[1].set_title('Val Accuracy (%)'); axes[1].set_xlabel('epoch')
axes[1].legend(fontsize=8, ncol=2);    axes[1].grid(True)

axes[2].set_title('Learning Rate');    axes[2].set_xlabel('epoch')
axes[2].set_yscale('log');             axes[2].legend(fontsize=8); axes[2].grid(True)

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/training_curves_all.png', dpi=120)
plt.show()

print('\nBest val accuracy per model:')
print(f'{"model":<12} {"top-1":>8} {"top-5":>8} {"epoch":>6}')
for name, t1, t5, ep in summary:
    print(f'{name:<12} {t1:>7.2f}% {t5:>7.2f}% {ep:>6}')
# Out:
# Best val accuracy per model:
# model           top-1    top-5  epoch
# shvit_s1       90.01%   99.18%     26
# shvit_s2       91.50%   99.39%     22
# shvit_s3       93.41%   99.59%     18
# shvit_s4       92.45%   99.66%     26

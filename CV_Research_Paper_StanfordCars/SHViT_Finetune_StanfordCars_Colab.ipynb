# %% [markdown]
# # Stage 3 — Fine-tuning SHViT on Stanford Cars
#
# This notebook fine-tunes pretrained SHViT models (S1..S4) on Stanford Cars
# using `finetune_shvit_stanford_cars.py`. Data preprocessing follows
# Tip-Adapter (`splits.py`, CLIP normalization, bicubic resize).
#
# **Before running:** `Runtime → Change runtime type → T4 GPU`
#
# ### What this notebook does
# 1. Verifies GPU, mounts Drive (optional), prepares paths
# 2. Clones SHViT + this project repo, installs deps
# 3. Downloads SHViT pretrained weights (S1..S4)
# 4. Runs `finetune_shvit_stanford_cars.py` for each variant
# 5. Plots training curves
#
# All outputs land under `<OUT_ROOT>/Stage 3: fine-tuning SHViT/<variant>/`.

# %% [markdown]
# ## 0. GPU check

# %%
import torch
print('PyTorch :', torch.__version__)
print('CUDA    :', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU     :', torch.cuda.get_device_name(0))
# Out:
# PyTorch : 2.11.0+cu128
# CUDA    : True
# GPU     : NVIDIA A100-SXM4-80GB

# %% [markdown]
# ## 1. (Optional) Mount Drive
#
# Persist the dataset, weights, and checkpoints across sessions.

# %%
USE_DRIVE = True

OUT_ROOT = '/content/CV_Research_Paper_StanfordCars'

if USE_DRIVE:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_ROOT   = '/content/drive/MyDrive/stanford_cars_data'
    WEIGHTS_DIR = '/content/drive/MyDrive/shvit_weights'
    OUT_ROOT    = '/content/drive/MyDrive/CV_Research_Paper_StanfordCars'
else:
    DATA_ROOT   = '/content/stanford_cars_data'
    WEIGHTS_DIR = '/content/weights'

OUTPUT_DIR = f'{OUT_ROOT}/Stage 3: fine-tuning SHViT'
WEIGHTS_PATH = f'{WEIGHTS_DIR}/shvit_s4.pth'

import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(DATA_ROOT, exist_ok=True)
os.makedirs(WEIGHTS_DIR, exist_ok=True)

print('Data       :', DATA_ROOT)
print('Weights    :', WEIGHTS_PATH)
print('Output root:', OUT_ROOT)
print('Output dir :', OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Data       : /content/drive/MyDrive/stanford_cars_data
# Weights    : /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# Output root: /content/drive/MyDrive/CV_Research_Paper_StanfordCars
# Output dir : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT

# %%
# Optional: copy the dataset to local SSD for faster I/O.
import shutil, os, time
src = '/content/drive/MyDrive/stanford_cars_data'
dst = '/content/stanford_cars_local'

if USE_DRIVE and not os.path.exists(dst) and os.path.isdir(src):
    print('Copying dataset to local SSD...')
    t0 = time.time()
    shutil.copytree(src, dst)
    print(f'done in {time.time()-t0:.0f}s')
    DATA_ROOT = dst
elif os.path.exists(dst):
    DATA_ROOT = dst
print('DATA_ROOT now:', DATA_ROOT)
# Out:
# Copying dataset to local SSD...
# done in 1s
# DATA_ROOT now: /content/stanford_cars_local

# %% [markdown]
# ## 2. Clone repos and install dependencies

# %%
import os, shutil

if not os.path.isdir('/content/SHViT'):
    # !git clone https://github.com/ysj9909/SHViT.git /content/SHViT

REPO = '/content/Vision_Project_spring_26'
if not os.path.isdir(REPO):
    # !git clone -b Vision_Project_spring_26_StanfordCars \
        https://github.com/saif-farid-tech/Vision_Project_spring_26.git {REPO}

for fname in [
    'Stage 3: fine-tuning SHViT/finetune_shvit_stanford_cars.py',
    'splits.py',
    'metrics.py',
    'augmentation.py',
    'prepare_stanford_cars.py',
]:
    shutil.copy(f'{REPO}/{fname}', f'/content/{os.path.basename(fname)}')
    print('Copied:', os.path.basename(fname))

DATASETS_DST = '/content/datasets'
if os.path.isdir(DATASETS_DST):
    shutil.rmtree(DATASETS_DST)
shutil.copytree(f'{REPO}/datasets', DATASETS_DST)
print('Vendored datasets/ package.')
# Out:
# Cloning into '/content/SHViT'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (152/152), done.
# remote: Total 183 (delta 84), reused 82 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 168.52 KiB | 12.96 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Cloning into '/content/Vision_Project_spring_26'...
# remote: Enumerating objects: 790, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 790 (delta 154), reused 158 (delta 124), pack-reused 570 (from 1)
# Receiving objects: 100% (790/790), 444.26 MiB | 19.03 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Copied: finetune_shvit_stanford_cars.py
# Copied: splits.py
# Copied: metrics.py
# Copied: augmentation.py
# Copied: prepare_stanford_cars.py
# Vendored datasets/ package.

# %%
# Install SHViT deps (timm pinned, --no-deps so torch isn't downgraded)
# plus gdown for the optional CoOp split download.
# !pip install -q timm==0.5.4 --no-deps
# !pip install -q einops==0.4.1 easydict gdown
print('Dependencies installed.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 30.1 MB/s eta 0:00:00
# Dependencies installed.

# %% [markdown]
# ## 3. Download SHViT-S4 pretrained weights

# %%
os.makedirs(WEIGHTS_DIR, exist_ok=True)
if not os.path.exists(WEIGHTS_PATH):
    # !wget -q --show-progress \
        https://github.com/ysj9909/SHViT/releases/download/v1.0/shvit_s4.pth \
        -O {WEIGHTS_PATH}
size_mb = os.path.getsize(WEIGHTS_PATH) / 1e6
print(f'Checkpoint: {size_mb:.1f} MB  ->  {WEIGHTS_PATH}')

# Also pre-download the Stanford Cars split + images so the first training run is fast
# !python /content/prepare_stanford_cars.py --root {DATA_ROOT}
# Out:
# Checkpoint: 266.7 MB  ->  /content/drive/MyDrive/shvit_weights/shvit_s4.pth
# [stanford_cars] attempting Stanford Cars download via torchvision into /content/stanford_cars_local ...
# [stanford_cars] torchvision download for split=train failed: The original URL is broken so the StanfordCars dataset cannot be downloaded anymore.
# [stanford_cars] torchvision download for split=test failed: The original URL is broken so the StanfordCars dataset cannot be downloaded anymore.
# [stanford_cars] cloning GitHub mirror https://github.com/jhpohovey/StanfordCars-Dataset.git ...
# Cloning into '/content/stanford_cars_local/tmptqhg27m0/StanfordCars-Dataset'...
# remote: Enumerating objects: 16163, done.
# remote: Counting objects: 100% (16163/16163), done.
# remote: Compressing objects: 100% (16163/16163), done.
# remote: Total 16163 (delta 0), reused 16160 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16163/16163), 1.82 GiB | 19.29 MiB/s, done.
# Updating files: 100% (16196/16196), done.
# [stanford_cars] dataset ready at /content/stanford_cars_local/stanford_cars
# [stanford_cars] trying official split download via gdown: https://drive.google.com/uc?id=1ObCFbaAgVu0I-k_Au-gIUcefirdAuizT
# Downloading...
# From: https://drive.google.com/uc?id=1ObCFbaAgVu0I-k_Au-gIUcefirdAuizT
# To: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# 100% 1.86M/1.86M [00:00<00:00, 201MB/s]
# [stanford_cars] official split saved to /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
#
# Done. Dataset root: /content/stanford_cars_local/stanford_cars
#   classes : 196
#   train   : 6,509
#   val     : 1,635
#   test    : 8,041

# %% [markdown]
# ## 4. Fine-tune SHViT on Stanford Cars
#
# Stanford Cars is ~2 GB (16,185 images). Each epoch on a T4 takes
# roughly 1–2 minutes with batch 64 — 30 epochs ≈ 45–60 minutes per variant.

# %%
# Quick smoke-test: 2 epochs to verify everything runs
# !python /content/finetune_shvit_stanford_cars.py \
    --shvit-dir  /content/SHViT \
    --finetune   {WEIGHTS_PATH} \
    --data-root  {DATA_ROOT} \
    --output-dir "{OUTPUT_DIR}/shvit_s4_smoke" \
    --epochs 2 \
    --batch-size 64 \
    --lr 1e-4 \
    --num-workers 8
# Out:
# Model: shvit_s4   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,227,488
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 2 epochs (starting at 0)
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/2] lr=2.00e-05  train=5.2925  val=5.2843  top1=0.67%  top5=2.81%  (63s)
#   -> new best (0.67%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
# [  2/2] lr=4.00e-05  train=5.2898  val=5.2745  top1=0.80%  top5=3.06%  (16s)
#   -> new best (0.80%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth
#
# Done.  Best val top-1: 0.80%
# Log  : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4_smoke/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4_smoke/best.pth

# %%
# Train all 4 SHViT variants sequentially.
MODELS = ['shvit_s4', 'shvit_s3', 'shvit_s2', 'shvit_s1']

# Per-variant weight decay from the SHViT paper (Table 7).
WEIGHT_DECAY = {
    'shvit_s1': 0.025,
    'shvit_s2': 0.032,
    'shvit_s3': 0.035,
    'shvit_s4': 0.050,
}

for model_name in MODELS:
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'

    if not os.path.exists(weights_path):
        print(f'\n=== Downloading {model_name} pretrained weights ===')
        # !wget -q --show-progress \
            https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth \
            -O {weights_path}

    print(f'\n{"="*60}')
    print(f'Training {model_name}  (wd={WEIGHT_DECAY[model_name]})')
    print(f'{"="*60}')

    # !python /content/finetune_shvit_stanford_cars.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir "{model_output_dir}" \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8

    print(f'\n=== Finished {model_name} ===\n')

print('All 4 SHViT variants done.')
# Out:
# ============================================================
# Training shvit_s4  (wd=0.05)
# ============================================================
# Model: shvit_s4   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s4.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 16,227,488
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=5.2924  val=5.2843  top1=0.92%  top5=2.87%  (62s)
#   -> new best (0.92%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  2/30] lr=4.00e-05  train=5.2877  val=5.2742  top1=0.67%  top5=2.81%  (16s)
# [  3/30] lr=6.00e-05  train=5.2785  val=5.2533  top1=0.86%  top5=4.34%  (16s)
# [  4/30] lr=8.00e-05  train=5.2626  val=5.2191  top1=2.20%  top5=6.85%  (16s)
#   -> new best (2.20%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  5/30] lr=1.00e-04  train=5.2405  val=5.1575  top1=3.91%  top5=11.13%  (16s)
#   -> new best (3.91%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  6/30] lr=1.00e-04  train=5.2023  val=5.0354  top1=7.09%  top5=18.41%  (17s)
#   -> new best (7.09%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  7/30] lr=9.96e-05  train=5.1232  val=4.7890  top1=8.13%  top5=24.22%  (17s)
#   -> new best (8.13%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  8/30] lr=9.84e-05  train=5.0328  val=4.6353  top1=10.03%  top5=29.60%  (16s)
#   -> new best (10.03%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [  9/30] lr=9.65e-05  train=4.9413  val=4.4622  top1=12.48%  top5=36.33%  (16s)
#   -> new best (12.48%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 10/30] lr=9.39e-05  train=4.8811  val=4.2897  top1=14.68%  top5=40.49%  (16s)
#   -> new best (14.68%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 11/30] lr=9.05e-05  train=4.7908  val=4.1241  top1=17.68%  top5=46.97%  (16s)
#   -> new best (17.68%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 12/30] lr=8.66e-05  train=4.7532  val=3.9853  top1=20.00%  top5=50.52%  (16s)
#   -> new best (20.00%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 13/30] lr=8.21e-05  train=4.6598  val=3.8534  top1=21.22%  top5=53.70%  (17s)
#   -> new best (21.22%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 14/30] lr=7.70e-05  train=4.6344  val=3.7247  top1=25.14%  top5=56.64%  (16s)
#   -> new best (25.14%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 15/30] lr=7.16e-05  train=4.5180  val=3.5876  top1=27.58%  top5=59.63%  (17s)
#   -> new best (27.58%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 16/30] lr=6.58e-05  train=4.4845  val=3.4919  top1=30.58%  top5=62.51%  (16s)
#   -> new best (30.58%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 17/30] lr=5.98e-05  train=4.4124  val=3.3977  top1=32.72%  top5=65.63%  (16s)
#   -> new best (32.72%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 18/30] lr=5.36e-05  train=4.3917  val=3.3068  top1=33.94%  top5=66.85%  (17s)
#   -> new best (33.94%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 19/30] lr=4.74e-05  train=4.3313  val=3.2514  top1=37.31%  top5=67.95%  (17s)
#   -> new best (37.31%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 20/30] lr=4.12e-05  train=4.2651  val=3.1691  top1=37.37%  top5=68.87%  (17s)
#   -> new best (37.37%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 21/30] lr=3.52e-05  train=4.3128  val=3.1526  top1=37.80%  top5=70.76%  (16s)
#   -> new best (37.80%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 22/30] lr=2.94e-05  train=4.2823  val=3.0897  top1=38.96%  top5=71.38%  (16s)
#   -> new best (38.96%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 23/30] lr=2.40e-05  train=4.2253  val=3.0454  top1=39.57%  top5=71.93%  (16s)
#   -> new best (39.57%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 24/30] lr=1.89e-05  train=4.2344  val=3.0260  top1=40.43%  top5=72.29%  (16s)
#   -> new best (40.43%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 25/30] lr=1.44e-05  train=4.2262  val=2.9902  top1=40.67%  top5=73.15%  (16s)
#   -> new best (40.67%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 26/30] lr=1.05e-05  train=4.2619  val=3.0010  top1=41.41%  top5=73.21%  (16s)
#   -> new best (41.41%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
# [ 27/30] lr=7.12e-06  train=4.2950  val=2.9965  top1=40.61%  top5=73.82%  (16s)
# [ 28/30] lr=4.48e-06  train=4.1771  val=2.9817  top1=40.92%  top5=73.52%  (16s)
# [ 29/30] lr=2.56e-06  train=4.1359  val=2.9884  top1=41.41%  top5=73.58%  (16s)
# [ 30/30] lr=1.39e-06  train=4.1898  val=2.9612  top1=41.65%  top5=73.52%  (17s)
#   -> new best (41.65%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#
# Done.  Best val top-1: 41.65%
# Log  : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#
# === Finished shvit_s4 ===
#
#
# ============================================================
# Training shvit_s3  (wd=0.035)
# ============================================================
# Model: shvit_s3   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s3.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 13,884,277
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=5.2955  val=5.2882  top1=0.49%  top5=2.63%  (60s)
#   -> new best (0.49%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  2/30] lr=4.00e-05  train=5.2894  val=5.2773  top1=0.61%  top5=2.87%  (16s)
#   -> new best (0.61%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  3/30] lr=6.00e-05  train=5.2781  val=5.2480  top1=0.86%  top5=5.14%  (15s)
#   -> new best (0.86%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  4/30] lr=8.00e-05  train=5.2588  val=5.2184  top1=2.26%  top5=7.65%  (16s)
#   -> new best (2.26%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  5/30] lr=1.00e-04  train=5.2350  val=5.1485  top1=4.22%  top5=11.93%  (16s)
#   -> new best (4.22%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  6/30] lr=1.00e-04  train=5.1964  val=5.0147  top1=7.28%  top5=18.90%  (15s)
#   -> new best (7.28%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  7/30] lr=9.96e-05  train=5.1102  val=4.7756  top1=8.44%  top5=25.69%  (16s)
#   -> new best (8.44%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  8/30] lr=9.84e-05  train=5.0195  val=4.5859  top1=10.28%  top5=30.64%  (15s)
#   -> new best (10.28%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [  9/30] lr=9.65e-05  train=4.9195  val=4.4423  top1=13.33%  top5=35.23%  (16s)
#   -> new best (13.33%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 10/30] lr=9.39e-05  train=4.8745  val=4.2849  top1=15.35%  top5=40.67%  (16s)
#   -> new best (15.35%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 11/30] lr=9.05e-05  train=4.7856  val=4.1163  top1=17.31%  top5=44.46%  (15s)
#   -> new best (17.31%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 12/30] lr=8.66e-05  train=4.7537  val=4.0094  top1=19.63%  top5=47.40%  (15s)
#   -> new best (19.63%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 13/30] lr=8.21e-05  train=4.6983  val=3.8949  top1=21.35%  top5=52.23%  (16s)
#   -> new best (21.35%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 14/30] lr=7.70e-05  train=4.6660  val=3.8176  top1=23.98%  top5=54.50%  (16s)
#   -> new best (23.98%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 15/30] lr=7.16e-05  train=4.5602  val=3.6555  top1=27.16%  top5=57.25%  (16s)
#   -> new best (27.16%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 16/30] lr=6.58e-05  train=4.5135  val=3.5390  top1=28.93%  top5=60.61%  (15s)
#   -> new best (28.93%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 17/30] lr=5.98e-05  train=4.4451  val=3.4356  top1=30.58%  top5=61.77%  (16s)
#   -> new best (30.58%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 18/30] lr=5.36e-05  train=4.4284  val=3.3614  top1=32.66%  top5=64.95%  (16s)
#   -> new best (32.66%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 19/30] lr=4.74e-05  train=4.3514  val=3.2968  top1=35.47%  top5=66.97%  (16s)
#   -> new best (35.47%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 20/30] lr=4.12e-05  train=4.2999  val=3.2201  top1=35.96%  top5=67.03%  (16s)
#   -> new best (35.96%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 21/30] lr=3.52e-05  train=4.3346  val=3.1704  top1=37.13%  top5=68.44%  (16s)
#   -> new best (37.13%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 22/30] lr=2.94e-05  train=4.3135  val=3.1437  top1=37.61%  top5=69.17%  (16s)
#   -> new best (37.61%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 23/30] lr=2.40e-05  train=4.2595  val=3.1167  top1=38.17%  top5=69.66%  (16s)
#   -> new best (38.17%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 24/30] lr=1.89e-05  train=4.2709  val=3.1033  top1=38.90%  top5=70.40%  (16s)
#   -> new best (38.90%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 25/30] lr=1.44e-05  train=4.2578  val=3.0869  top1=39.51%  top5=71.80%  (16s)
#   -> new best (39.51%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 26/30] lr=1.05e-05  train=4.2804  val=3.0688  top1=39.94%  top5=70.83%  (16s)
#   -> new best (39.94%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 27/30] lr=7.12e-06  train=4.3183  val=3.0640  top1=40.18%  top5=71.56%  (15s)
#   -> new best (40.18%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 28/30] lr=4.48e-06  train=4.2177  val=3.0595  top1=40.49%  top5=72.05%  (15s)
#   -> new best (40.49%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
# [ 29/30] lr=2.56e-06  train=4.1746  val=3.0556  top1=40.37%  top5=71.74%  (15s)
# [ 30/30] lr=1.39e-06  train=4.2163  val=3.0605  top1=40.37%  top5=72.05%  (16s)
#
# Done.  Best val top-1: 40.49%
# Log  : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#
# === Finished shvit_s3 ===
#
#
# ============================================================
# Training shvit_s2  (wd=0.032)
# ============================================================
# Model: shvit_s2   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s2.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 11,122,076
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=5.2894  val=5.2851  top1=0.86%  top5=2.94%  (62s)
#   -> new best (0.86%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  2/30] lr=4.00e-05  train=5.2872  val=5.2706  top1=0.80%  top5=3.61%  (15s)
# [  3/30] lr=6.00e-05  train=5.2752  val=5.2429  top1=1.28%  top5=5.87%  (16s)
#   -> new best (1.28%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  4/30] lr=8.00e-05  train=5.2613  val=5.1969  top1=2.39%  top5=8.50%  (16s)
#   -> new best (2.39%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  5/30] lr=1.00e-04  train=5.2232  val=5.1007  top1=4.22%  top5=13.76%  (15s)
#   -> new best (4.22%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  6/30] lr=1.00e-04  train=5.1792  val=4.9944  top1=5.38%  top5=18.78%  (16s)
#   -> new best (5.38%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  7/30] lr=9.96e-05  train=5.1158  val=4.8342  top1=6.24%  top5=23.61%  (16s)
#   -> new best (6.24%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  8/30] lr=9.84e-05  train=5.0559  val=4.7271  top1=8.20%  top5=25.93%  (16s)
#   -> new best (8.20%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [  9/30] lr=9.65e-05  train=4.9854  val=4.5692  top1=11.74%  top5=31.07%  (16s)
#   -> new best (11.74%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 10/30] lr=9.39e-05  train=4.9377  val=4.4410  top1=14.68%  top5=37.43%  (15s)
#   -> new best (14.68%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 11/30] lr=9.05e-05  train=4.8550  val=4.3190  top1=15.72%  top5=40.80%  (15s)
#   -> new best (15.72%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 12/30] lr=8.66e-05  train=4.8335  val=4.2180  top1=18.10%  top5=43.36%  (16s)
#   -> new best (18.10%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 13/30] lr=8.21e-05  train=4.7711  val=4.1014  top1=20.67%  top5=47.40%  (17s)
#   -> new best (20.67%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 14/30] lr=7.70e-05  train=4.7451  val=3.9974  top1=22.14%  top5=50.70%  (16s)
#   -> new best (22.14%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 15/30] lr=7.16e-05  train=4.6645  val=3.8841  top1=22.69%  top5=53.46%  (16s)
#   -> new best (22.69%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 16/30] lr=6.58e-05  train=4.6234  val=3.7864  top1=25.26%  top5=55.84%  (16s)
#   -> new best (25.26%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 17/30] lr=5.98e-05  train=4.5533  val=3.6794  top1=26.42%  top5=59.14%  (16s)
#   -> new best (26.42%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 18/30] lr=5.36e-05  train=4.5372  val=3.6111  top1=28.99%  top5=60.80%  (16s)
#   -> new best (28.99%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 19/30] lr=4.74e-05  train=4.4818  val=3.5180  top1=31.01%  top5=62.87%  (16s)
#   -> new best (31.01%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 20/30] lr=4.12e-05  train=4.4275  val=3.4774  top1=31.80%  top5=64.28%  (15s)
#   -> new best (31.80%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 21/30] lr=3.52e-05  train=4.4565  val=3.4310  top1=32.17%  top5=65.20%  (16s)
#   -> new best (32.17%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 22/30] lr=2.94e-05  train=4.4481  val=3.3890  top1=34.01%  top5=65.87%  (16s)
#   -> new best (34.01%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 23/30] lr=2.40e-05  train=4.3845  val=3.3439  top1=34.25%  top5=67.34%  (16s)
#   -> new best (34.25%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 24/30] lr=1.89e-05  train=4.3862  val=3.3484  top1=34.86%  top5=68.07%  (16s)
#   -> new best (34.86%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 25/30] lr=1.44e-05  train=4.3816  val=3.3121  top1=34.68%  top5=68.56%  (15s)
# [ 26/30] lr=1.05e-05  train=4.4230  val=3.2838  top1=35.84%  top5=68.93%  (16s)
#   -> new best (35.84%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
# [ 27/30] lr=7.12e-06  train=4.4395  val=3.2931  top1=35.54%  top5=68.20%  (15s)
# [ 28/30] lr=4.48e-06  train=4.3389  val=3.2896  top1=35.72%  top5=68.50%  (16s)
# [ 29/30] lr=2.56e-06  train=4.3010  val=3.2708  top1=35.23%  top5=68.56%  (16s)
# [ 30/30] lr=1.39e-06  train=4.3534  val=3.2786  top1=35.47%  top5=69.24%  (16s)
#
# Done.  Best val top-1: 35.84%
# Log  : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#
# === Finished shvit_s2 ===
#
#
# ============================================================
# Training shvit_s1  (wd=0.025)
# ============================================================
# Model: shvit_s1   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/shvit_weights/shvit_s1.pth
#   Removed (shape mismatch) : ['head.l.weight', 'head.l.bias']
#   Missing keys           : ['head.l.weight', 'head.l.bias']
# Trainable parameters: 6,072,724
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
#
# Fine-tuning for 30 epochs (starting at 0)
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# [  1/30] lr=2.00e-05  train=5.2935  val=5.2894  top1=0.24%  top5=2.08%  (61s)
#   -> new best (0.24%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  2/30] lr=4.00e-05  train=5.2865  val=5.2793  top1=0.55%  top5=2.87%  (16s)
#   -> new best (0.55%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  3/30] lr=6.00e-05  train=5.2803  val=5.2619  top1=0.49%  top5=2.94%  (16s)
# [  4/30] lr=8.00e-05  train=5.2704  val=5.2471  top1=0.67%  top5=4.40%  (15s)
#   -> new best (0.67%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  5/30] lr=1.00e-04  train=5.2504  val=5.1970  top1=2.69%  top5=9.97%  (16s)
#   -> new best (2.69%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  6/30] lr=1.00e-04  train=5.2149  val=5.0802  top1=5.38%  top5=15.90%  (16s)
#   -> new best (5.38%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  7/30] lr=9.96e-05  train=5.1432  val=4.9005  top1=6.06%  top5=21.22%  (16s)
#   -> new best (6.06%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  8/30] lr=9.84e-05  train=5.0734  val=4.8001  top1=8.20%  top5=24.65%  (16s)
#   -> new best (8.20%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [  9/30] lr=9.65e-05  train=5.0050  val=4.6685  top1=10.34%  top5=28.56%  (16s)
#   -> new best (10.34%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 10/30] lr=9.39e-05  train=4.9704  val=4.5734  top1=11.44%  top5=31.19%  (16s)
#   -> new best (11.44%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 11/30] lr=9.05e-05  train=4.9130  val=4.4777  top1=12.84%  top5=34.80%  (16s)
#   -> new best (12.84%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 12/30] lr=8.66e-05  train=4.8939  val=4.3954  top1=14.31%  top5=38.41%  (16s)
#   -> new best (14.31%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 13/30] lr=8.21e-05  train=4.8416  val=4.3079  top1=14.92%  top5=40.61%  (15s)
#   -> new best (14.92%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 14/30] lr=7.70e-05  train=4.8381  val=4.2309  top1=16.15%  top5=41.65%  (16s)
#   -> new best (16.15%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 15/30] lr=7.16e-05  train=4.7688  val=4.1665  top1=17.80%  top5=43.49%  (16s)
#   -> new best (17.80%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 16/30] lr=6.58e-05  train=4.7498  val=4.1237  top1=19.39%  top5=44.71%  (16s)
#   -> new best (19.39%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 17/30] lr=5.98e-05  train=4.7128  val=4.0581  top1=19.69%  top5=47.28%  (15s)
#   -> new best (19.69%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 18/30] lr=5.36e-05  train=4.7108  val=3.9936  top1=19.82%  top5=47.83%  (16s)
#   -> new best (19.82%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 19/30] lr=4.74e-05  train=4.6517  val=3.9487  top1=20.98%  top5=49.79%  (16s)
#   -> new best (20.98%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 20/30] lr=4.12e-05  train=4.6301  val=3.9024  top1=21.59%  top5=50.64%  (16s)
#   -> new best (21.59%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 21/30] lr=3.52e-05  train=4.6378  val=3.8885  top1=22.14%  top5=51.07%  (16s)
#   -> new best (22.14%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 22/30] lr=2.94e-05  train=4.6261  val=3.8473  top1=22.69%  top5=51.68%  (16s)
#   -> new best (22.69%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 23/30] lr=2.40e-05  train=4.5852  val=3.8221  top1=23.12%  top5=53.03%  (16s)
#   -> new best (23.12%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 24/30] lr=1.89e-05  train=4.5974  val=3.8040  top1=23.12%  top5=52.97%  (16s)
# [ 25/30] lr=1.44e-05  train=4.5970  val=3.7883  top1=23.30%  top5=54.07%  (16s)
#   -> new best (23.30%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 26/30] lr=1.05e-05  train=4.6160  val=3.7599  top1=23.24%  top5=54.31%  (16s)
# [ 27/30] lr=7.12e-06  train=4.6410  val=3.8121  top1=23.49%  top5=52.29%  (16s)
#   -> new best (23.49%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 28/30] lr=4.48e-06  train=4.5695  val=3.7901  top1=23.73%  top5=53.09%  (16s)
#   -> new best (23.73%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
# [ 29/30] lr=2.56e-06  train=4.5339  val=3.7590  top1=23.61%  top5=53.64%  (16s)
# [ 30/30] lr=1.39e-06  train=4.5660  val=3.7587  top1=24.04%  top5=54.01%  (16s)
#   -> new best (24.04%), saved to /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#
# Done.  Best val top-1: 24.04%
# Log  : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/training_log.csv
# Best : /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#
# === Finished shvit_s1 ===
#
# All 4 SHViT variants done.

# %%
# Resume from a checkpoint if the session was interrupted
# !python /content/finetune_shvit_stanford_cars.py \
#     --shvit-dir  /content/SHViT \
#     --data-root  {DATA_ROOT} \
#     --output-dir "{OUTPUT_DIR}/shvit_s4" \
#     --resume     "{OUTPUT_DIR}/shvit_s4/checkpoint_010.pth" \
#     --epochs 30 \
#     --batch-size 64 \
#     --lr 1e-4 \
#     --num-workers 8

# %%
import os, urllib.request

# Recovery cell for the SHViT pretrained weights (shvit_s1..s4).
# Re-downloads ONLY variants whose file is missing or truncated (the
# original failure mode was a 0-byte file; genuine checkpoints are
# 100-300 MB, so anything under 100 MB is treated as broken).
#
# Side-effect: populates MODELS_TO_REDO with every variant we actually had
# to recover, so the next cell only retrains those. A healthy file leaves
# MODELS_TO_REDO empty, making the retrain cell a no-op.
MODELS_TO_REDO = []
MIN_VALID_MB = 100  # genuine file is ~229 MB

def _recover(model_name):
    path = f'{WEIGHTS_DIR}/{model_name}.pth'
    url  = f'https://github.com/ysj9909/SHViT/releases/download/v1.0/{model_name}.pth'

    if os.path.exists(path):
        size_mb = os.path.getsize(path) / 1e6
        if size_mb >= MIN_VALID_MB:
            print(f'{model_name}.pth looks healthy ({size_mb:.2f} MB) - skipping recovery.')
            return False
        print(f'{model_name}.pth looks broken ({size_mb:.2f} MB) - re-downloading.')
        os.remove(path)
    else:
        print(f'{model_name}.pth not found - downloading.')

    os.makedirs(WEIGHTS_DIR, exist_ok=True)
    print(f'  from {url}')
    urllib.request.urlretrieve(url, path)
    print(f'  done: {os.path.getsize(path)/1e6:.2f} MB')
    return True

# Check all four SHViT variants
for _name in ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']:
    if _recover(_name):
        MODELS_TO_REDO.append(_name)

print('\nMODELS_TO_REDO =', MODELS_TO_REDO)
# Out:
# shvit_s1.pth looks healthy (102.12 MB) - skipping recovery.
# shvit_s2.pth looks healthy (184.67 MB) - skipping recovery.
# shvit_s3.pth looks healthy (229.01 MB) - skipping recovery.
# shvit_s4.pth looks healthy (266.73 MB) - skipping recovery.
#
# MODELS_TO_REDO = []

# %%
# Retrain every variant that the recovery cell (Cell 15) actually had to
# re-download. If MODELS_TO_REDO is empty, nothing happens.
if not MODELS_TO_REDO:
    print('No variants need retraining (MODELS_TO_REDO is empty).')

for model_name in MODELS_TO_REDO:
    weights_path = f'{WEIGHTS_DIR}/{model_name}.pth'
    model_output_dir = f'{OUTPUT_DIR}/{model_name}'

    # !python /content/finetune_shvit_food101.py \
        --model      {model_name} \
        --shvit-dir  /content/SHViT \
        --finetune   {weights_path} \
        --data-root  {DATA_ROOT} \
        --output-dir {model_output_dir} \
        --split-file /content/train_val_split_seed42.json \
        --epochs 30 \
        --batch-size 64 \
        --lr 1e-4 \
        --warmup-epochs 5 \
        --weight-decay {WEIGHT_DECAY[model_name]} \
        --clip-grad 0.02 \
        --save-freq 10 \
        --num-workers 8
# Out:
# No variants need retraining (MODELS_TO_REDO is empty).

# %% [markdown]
# ## 5. Evaluate the best checkpoint

# %%
MODEL = 'shvit_s4'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_stanford_cars.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s4   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s4/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 16,227,488
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 41.65%   top-5: 73.52%

# %%
MODEL = 'shvit_s3'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_stanford_cars.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s3   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s3/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 13,884,277
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 40.49%   top-5: 72.05%

# %%
MODEL = 'shvit_s2'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_stanford_cars.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s2   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s2/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 11,122,076
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 35.84%   top-5: 68.93%

# %%
MODEL = 'shvit_s1'
MODEL_DIR = f'{OUTPUT_DIR}/{MODEL}'

# !python /content/finetune_shvit_stanford_cars.py \
    --model      {MODEL} \
    --shvit-dir  /content/SHViT \
    --finetune   "{MODEL_DIR}/best.pth" \
    --data-root  {DATA_ROOT} \
    --output-dir "{MODEL_DIR}" \
    --eval
# Out:
# Model: shvit_s1   Device: cuda
# [stanford_cars] images already present: /content/stanford_cars_local/stanford_cars
# [stanford_cars] split already present: /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Reading split from /content/stanford_cars_local/stanford_cars/split_zhou_StanfordCars.json
# Stanford Cars split: 6,509 train  1,635 val
# Pretrained weights loaded from /content/drive/MyDrive/CV_Research_Paper_StanfordCars/Stage 3: fine-tuning SHViT/shvit_s1/best.pth
#   Removed (shape mismatch) : []
# Trainable parameters: 6,072,724
# /content/finetune_shvit_stanford_cars.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /content/finetune_shvit_stanford_cars.py:214: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Eval  top-1: 24.04%   top-5: 54.01%

# %% [markdown]
# ## 6. Plot training curves

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

MODELS = ['shvit_s1', 'shvit_s2', 'shvit_s3', 'shvit_s4']
COLORS = {'shvit_s1': 'tab:blue', 'shvit_s2': 'tab:orange',
          'shvit_s3': 'tab:green', 'shvit_s4': 'tab:red'}

fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))

summary = []
for model_name in MODELS:
    csv_path = f'{OUTPUT_DIR}/{model_name}/training_log.csv'
    if not os.path.exists(csv_path):
        print(f'[skip] no log for {model_name}')
        continue

    df = pd.read_csv(csv_path)
    color = COLORS[model_name]

    axes[0].plot(df['epoch'], df['train_loss'], label=f'{model_name} train', color=color)
    axes[0].plot(df['epoch'], df['val_loss'],   label=f'{model_name} val',
                 color=color, linestyle='--', alpha=0.7)

    axes[1].plot(df['epoch'], df['val_top1'] * 100, label=f'{model_name} top-1', color=color)
    axes[1].plot(df['epoch'], df['val_top5'] * 100, label=f'{model_name} top-5',
                 color=color, linestyle='--', alpha=0.7)

    axes[2].plot(df['epoch'], df['lr'].astype(float), label=model_name, color=color)

    best = df.loc[df['val_top1'].idxmax()]
    summary.append((model_name, best['val_top1']*100, best['val_top5']*100, int(best['epoch'])))

axes[0].set_title('Loss');           axes[0].set_xlabel('epoch')
axes[0].legend(fontsize=8, ncol=2);  axes[0].grid(True)

axes[1].set_title('Val Accuracy (%)'); axes[1].set_xlabel('epoch')
axes[1].legend(fontsize=8, ncol=2);    axes[1].grid(True)

axes[2].set_title('Learning Rate');    axes[2].set_xlabel('epoch')
axes[2].set_yscale('log');             axes[2].legend(fontsize=8); axes[2].grid(True)

plt.tight_layout()
plt.savefig(f'{OUTPUT_DIR}/training_curves_all.png', dpi=120)
plt.show()

print('\nBest val accuracy per model:')
print(f'{"model":<12} {"top-1":>8} {"top-5":>8} {"epoch":>6}')
for name, t1, t5, ep in summary:
    print(f'{name:<12} {t1:>7.2f}% {t5:>7.2f}% {ep:>6}')
# Out:
# Best val accuracy per model:
# model           top-1    top-5  epoch
# shvit_s1       24.04%   54.01%     30
# shvit_s2       35.84%   68.93%     26
# shvit_s3       40.49%   72.05%     28
# shvit_s4       41.65%   73.52%     30
